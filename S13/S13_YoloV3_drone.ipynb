# %%
# !git clone https://github.com/gbrao018/eva4.git
# Out:
# Cloning into 'eva4'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 1694 (delta 5), reused 12 (delta 5), pack-reused 1682
# Receiving objects: 100% (1694/1694), 78.36 MiB | 42.55 MiB/s, done.
# Resolving deltas: 100% (323/323), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
ls
# Out:
# eva4/  gdrive/  sample_data/

# %%
cd eva4/YoloV3
# Out:
# /content/eva4/YoloV3

# %%
cp

# %%
# !ls
# Out:
#  cfg	     README.md	       test.py		  utils
#  data	     results.json      ting		  vim.exe.stackdump
#  detect.py   results.png       train_batch0.png
#  models.py   results.txt       train.py
#  output      test_batch0.png  'ubdivisions=1'

# %%
cp /content/gdrive/My\ Drive/eva-04/S13/weights/last1_1.pt  /content/eva4/YoloV3/weights/

# %%
cp /content/gdrive/My\ Drive/eva-04/S13/weights/yolov3-spp-ultralytics1_1.pt /content/eva4/YoloV3/weights/

# %%
# Out:
# cp: target '/content/eva4/YoloV3/weights/yolov3-spp-ultralytics.pt' is not a directory

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-25 07:59:08.625613: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 5661.86it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 108.39it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 20 --cache --cfg cfg/yolov3-custom.cfg --epochs 50 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=20, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=50, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-25 08:02:00.475334: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (318 found, 0 missing, 33 empty, 0 duplicate, for 351 images): 100% 351/351 [00:00<00:00, 10418.38it/s]
# Caching images (0.2GB): 100% 351/351 [00:02<00:00, 125.73it/s]
# Reading image shapes: 100% 351/351 [00:00<00:00, 1240.18it/s]
# ...

# %%
cp /content/eva4/YoloV3/weights/last.pt /content/gdrive/My\ Drive/eva-04/S13/weights/last_200.pt

# %%
cp /content/eva4/YoloV3/weights/yolov3-spp-ultralytics.pt /content/gdrive/My\ Drive/eva-04/S13/weights/yolov3-spp-ultralytics_200.pt

# %%
# !python train.py --data data/customdata/custom.data --batch 20 --cache --cfg cfg/yolov3-custom.cfg --epochs 100 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=20, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=100, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-25 08:32:18.891869: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (318 found, 0 missing, 33 empty, 0 duplicate, for 351 images): 100% 351/351 [00:00<00:00, 11502.11it/s]
# Caching images (0.2GB): 100% 351/351 [00:02<00:00, 133.40it/s]
# ...

# %%
cp /content/eva4/YoloV3/weights/last.pt /content/gdrive/My\ Drive/eva-04/S13/weights/last_300.pt

# %%
cp /content/eva4/YoloV3/weights/yolov3-spp-ultralytics.pt /content/gdrive/My\ Drive/eva-04/S13/weights/yolov3-spp-ultralytics_300.pt

# %%
# !python train.py --data data/customdata/custom.data --batch 20 --cache --cfg cfg/yolov3-custom.cfg --epochs 50 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=20, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=50, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-25 09:33:30.659055: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (318 found, 0 missing, 33 empty, 0 duplicate, for 351 images): 100% 351/351 [00:00<00:00, 8774.59it/s]
# Caching images (0.2GB): 100% 351/351 [00:02<00:00, 124.68it/s]
# ...

# %%
cp /content/eva4/YoloV3/weights/last.pt /content/gdrive/My\ Drive/eva-04/S13/weights/last_350.pt

# %%
cp /content/eva4/YoloV3/weights/yolov3-spp-ultralytics.pt /content/gdrive/My\ Drive/eva-04/S13/weights/yolov3-spp-ultralytics_350.pt

# %%
# !python detect.py --conf-thres 0.1 --output out_drone
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_drone', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/488 data/customdata/images/8.jpg: 384x512 1 drones, Done. (0.019s)
# image 2/488 data/customdata/images/drone001.jpg: 384x512 1 drones, Done. (0.017s)
# image 3/488 data/customdata/images/drone002.jpg: 320x512 1 drones, Done. (0.017s)
# image 4/488 data/customdata/images/drone002.png: 320x512 1 drones, Done. (0.016s)
# image 5/488 data/customdata/images/drone003.jpg: 320x512 1 drones, Done. (0.016s)
# image 6/488 data/customdata/images/drone004.jpg: 384x512 1 drones, Done. (0.018s)
# ...

# %%
cp /content/eva4/YoloV3/out_drone/drone*.jpg /content/gdrive/My\ Drive/eva-04/S13/out_drone

# %%
#221 to 364 , we do not have annotations and they are like test set
Image(filename='out_drone/drone307.jpg', width=600)

# %%
Image(filename='out_drone/drone131.jpg', width=600)

# %%
Image(filename='out_drone/drone135.jpg', width=600)

# %%
Image(filename='out_drone/drone123.jpg', width=600)

# %%
Image(filename='out_drone/drone122.jpg', width=600)

# %%
Image(filename='out_drone/drone115.jpg', width=600)

# %%
Image(filename='out_drone/drone114.jpg', width=600)

# %%
Image(filename='out_drone/drone112.jpg', width=600)

# %%
Image(filename='out_drone/drone111.jpg', width=600)

# %%
Image(filename='out_drone/drone110.jpg', width=600)

# %%
Image(filename='out_drone/drone108.jpg', width=600)

# %%
Image(filename='ganji_yolo_out/drone007.jpg', width=600)

# %%
Image(filename='ganji_yolo_out/drone008.jpg', width=600)

# %%
Image(filename='ganji_yolo_out/drone009.jpg', width=600)

# %%
Image(filename='ganji_yolo_out/drone010.jpg', width=600)

# %%
Image(filename='out_drone/drone012.jpg', width=600)
