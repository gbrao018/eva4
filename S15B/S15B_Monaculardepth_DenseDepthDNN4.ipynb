# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# #File Index calculation. Basically given the index, Custom dataset should able to fetch the file from corresponding folders

# %%
import numpy as np
import cv2
import io
import os
import torch
from torch.utils.data import DataLoader, Dataset
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor
from torchvision import transforms
import zipfile
import torchvision.datasets.folder
from PIL import Image
import sys
#sys.path.append('/content/gdrive/My Drive/eva-04/S15A')

import cv2
import numpy as np
import glob
import numpy as np
from google.colab.patches import cv2_imshow
from PIL import Image
import matplotlib.pyplot as plt

import argparse
import time
import csv

import numpy as np
import torch
import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data
#import  models

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(device)

# This is the common class for both test and train data sets. Based on indexes, this class serves the sample.
# we deal with a folder at a time.
#fg_bg and bg are the input. classes are masks 
#example
#root = Dataset150
#bg_file = bg1.jpg
#bg_folder = Dataset150/bg150_1
#fgbg_folder = Dataset150/fgbg150_1
#mask_fgbgbg_folder = Dataset150/mask_fgbg150_1


class BackgroundSubtraction_Dataset_Test(Dataset):

  def __init__(self, root, size, test = False, files=[], transform=ToTensor()):
    'Initialization'
    self.m_root = root
    self.m_bg_folder = os.path.join(self.m_root, "bg150")
    self.m_transform = transform
    self.m_file_dict = dict()
    self.m_index_path_dict = dict()
    self.m_size = size
    self.m_files = files
    self.m_btest = test 
    #self.prepare_indexes224()
  
  
  #bg1
  #   /fg_1
  #      /depth
  #           1.jpg
  #           40.jpg  
  #      /mask_
  #      /overlay
  #   /fg_2
  #     /depth
  #     /mask_
  #     /overlay
  def prepare_indexes224(self):
    bg_folder = "bg"
    fg_folder = "fg_"
    mask_folder = "mask"
    depth_folder = "depth"
    overlay_folder = "overlay"
    bg_index = 1
    fg_index = 1
    file_index = 1 # 1 to 40
    #index_file_dict = dict()

    for i in range(1,4002):
      
      #overlay_file = bg_folder + str(bg_index) + "/" + fg_folder + str(fg_index) + "/"+  "overlay" + "/" + file_index + ".jpg"
      
      path_dir = bg_folder + str(bg_index) + "/" + fg_folder + str(fg_index)
      self.m_index_path_dict[i] = path_dir
      print(i,self.m_index_path_dict[i],file_index)
      
      if file_index == 40:
        file_index = 1 # reset
        fg_index = fg_index + 1 # fg_index increases . next folder
      else:
        file_index = file_index + 1
      
      #file_index = file_index % 40      
      if i % 4000 == 0: # every 4k bg change
        bg_index = bg_index + 1
        file_index = 1 # reset
        fg_index =  1 # fg_index starts from 1. reset
      
      #fgbg_file = bg + str(bg_index) + "_" + str(row) + "_" + str(column)+ "_" + fg + "_"+ str(fg_index)+".jpg"  
  
     
  def __len__(self):
    'Denotes the total number of samples'
    #return len(self.m_files)
    #return len(self.m_size)
    return self.m_size

  def __getitem__(self, idx):

    #index = idx + 4001
    index = idx + 1
    #print("idx=",idx,"index=",index)
    'Generates one sample of data'
    # Select sample
    #file_name = self.m_index_dict.get(index)
    bg_folder ="bg"
    fgbg_folder = "bg"
    fg_folder ="fg_"

    overlay_folder = "overlay"
    mask_folder = "mask"
    depth_folder = "depth"

    bg_index = index // 4000 # each fg can hold till 4000
    if index % 4000 != 0:
      bg_index = bg_index + 1

    # each fg can hold till 40
    fg_index = index // 40
    if index % 40 != 0:
      fg_index = fg_index + 1
  
    fg_index = fg_index % 100 # max cap for fg_index
    if fg_index == 0:
      fg_index =  100 

    file_index = index % 40
    if file_index == 0:
        file_index = 40
    
    fgbg_folder = fgbg_folder + str(bg_index)
    fg_folder = fg_folder + str(fg_index)
    filename = str(file_index)+".jpg"
    #print("filename=",filename)

    #find the bg file:
    bg_path = os.path.join(self.m_root,bg_folder)
    bg_file_name = bg_folder + str(bg_index) + ".jpg"
    bg_file = os.path.join(bg_path,bg_file_name) # bg file
    
    # get fgbg image paths for overlay,depth,mask
    fgbg_path = os.path.join(self.m_root, fgbg_folder)
    fg_folder = os.path.join(fgbg_path,fg_folder)
    overlay_folder = os.path.join(fg_folder,overlay_folder)
    depth_folder = os.path.join(fg_folder,depth_folder) 
    mask_folder = os.path.join(fg_folder,mask_folder)
    overlay_file = os.path.join(overlay_folder,filename) # overlay file
    depth_file = os.path.join(depth_folder,filename) # depth file
    mask_file = os.path.join(mask_folder,filename) # mask file

    # Take all images
    bg_image = Image.open(bg_file).convert('RGB') # even grey scale images will be converted to RGB with 3 channels
    bg_image = bg_image.resize((32,32)) 
    overlay_image = Image.open(overlay_file).convert('RGB') # even grey scale images will be converted to RGB with 3 channels
    overlay_image = overlay_image.resize((32,32)) 
    #depth_image = Image.open(depth_file).convert('RGB') # even grey scale images will be converted to RGB with 3 channels
    #mask_image = Image.open(mask_file).convert('RGB')
    depth_image = Image.open(depth_file) # even grey scale images will be converted to RGB with 3 channels
    depth_image = depth_image.resize((64,64)) 
    mask_image = Image.open(mask_file)
    mask_image = mask_image.resize((64,64)) 
    # Take all images

    try:
      if self.m_transform:
        bg_image = self.m_transform(bg_image)
        overlay_image = self.m_transform(overlay_image)
        tr = transforms.ToTensor()
        mask_image = tr(mask_image)
        depth_image = tr(depth_image)
    except:
      print('Error while transform:', overlay_file, bg_image.shape,overlay_image.shape,mask_image.shape)
    input_array = []
    input_array.append(bg_image)
    input_array.append(overlay_image)
    input_array.append(depth_image)
    input_array.append(mask_image)
    input_array.append(filename)

    return input_array

    #return [bg_image,overlay_image, depth_image,mask_image]
# Out:
# cuda

# %%
# !mkdir Dataset_224

# %%
cd Dataset_224/
# Out:
# /content/Dataset_224

# %%
# !unzip "/content/gdrive/My Drive/eva-04/S15A/Dataset_224.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: bg44/fg_76/mask/31.jpg
#   inflating: bg44/fg_76/mask/8.jpg
#   inflating: bg44/fg_76/mask/9.jpg
#   inflating: bg44/fg_76/mask/6.jpg
#   inflating: bg44/fg_76/mask/37.jpg
#   inflating: bg44/fg_76/mask/32.jpg
#   inflating: bg44/fg_76/mask/29.jpg
#   inflating: bg44/fg_76/mask/39.jpg
#   inflating: bg44/fg_76/mask/38.jpg
#   inflating: bg44/fg_76/mask/24.jpg
#   inflating: bg44/fg_76/mask/11.jpg
#   inflating: bg44/fg_76/mask/23.jpg
#   inflating: bg44/fg_76/mask/5.jpg
#   inflating: bg44/fg_76/mask/33.jpg
#   inflating: bg44/fg_76/mask/10.jpg
#   inflating: bg44/fg_76/mask/1.jpg
#   inflating: bg44/fg_76/mask/3.jpg
#   inflating: bg44/fg_76/mask/16.jpg
#   inflating: bg44/fg_76/mask/20.jpg
#   inflating: bg44/fg_76/mask/17.jpg
#   inflating: bg44/fg_76/mask/40.jpg
#   inflating: bg44/fg_76/mask/15.jpg
#   inflating: bg44/fg_76/mask/14.jpg
#   inflating: bg44/fg_76/mask/27.jpg
#   inflating: bg44/fg_76/mask/36.jpg
#   inflating: bg44/fg_76/mask/19.jpg
#   inflating: bg44/fg_76/mask/21.jpg
#   inflating: bg44/fg_76/mask/2.jpg
#   inflating: bg44/fg_76/mask/28.jpg
#   inflating: bg44/fg_76/mask/7.jpg
#   inflating: bg44/fg_76/mask/13.jpg
#   inflating: bg44/fg_76/mask/30.jpg
#   inflating: bg44/fg_76/mask/4.jpg
#   inflating: bg44/fg_76/mask/35.jpg
#   inflating: bg44/fg_76/mask/22.jpg
#   inflating: bg44/fg_76/mask/34.jpg
#   inflating: bg44/fg_76/mask/26.jpg
#   inflating: bg44/fg_76/mask/25.jpg
#   inflating: bg44/fg_76/mask/18.jpg
#   inflating: bg44/fg_76/overlay/12.jpg
#   inflating: bg44/fg_76/overlay/31.jpg
#   inflating: bg44/fg_76/overlay/8.jpg
#   inflating: bg44/fg_76/overlay/9.jpg
#   inflating: bg44/fg_76/overlay/6.jpg
#   inflating: bg44/fg_76/overlay/37.jpg
#   inflating: bg44/fg_76/overlay/32.jpg
#   inflating: bg44/fg_76/overlay/29.jpg
#   inflating: bg44/fg_76/overlay/39.jpg
#   inflating: bg44/fg_76/overlay/38.jpg
#   inflating: bg44/fg_76/overlay/24.jpg
#   inflating: bg44/fg_76/overlay/11.jpg
#   inflating: bg44/fg_76/overlay/23.jpg
#   inflating: bg44/fg_76/overlay/5.jpg
#   inflating: bg44/fg_76/overlay/33.jpg
#   inflating: bg44/fg_76/overlay/10.jpg
#   inflating: bg44/fg_76/overlay/1.jpg
#   inflating: bg44/fg_76/overlay/3.jpg
#   inflating: bg44/fg_76/overlay/16.jpg
#   inflating: bg44/fg_76/overlay/20.jpg
#   inflating: bg44/fg_76/overlay/17.jpg
#   inflating: bg44/fg_76/overlay/40.jpg
#   inflating: bg44/fg_76/overlay/15.jpg
#   inflating: bg44/fg_76/overlay/14.jpg
#   inflating: bg44/fg_76/overlay/27.jpg
#   inflating: bg44/fg_76/overlay/36.jpg
#   inflating: bg44/fg_76/overlay/19.jpg
#   inflating: bg44/fg_76/overlay/21.jpg
#   inflating: bg44/fg_76/overlay/2.jpg
#   inflating: bg44/fg_76/overlay/28.jpg
#   inflating: bg44/fg_76/overlay/7.jpg
#   inflating: bg44/fg_76/overlay/13.jpg
#   inflating: bg44/fg_76/overlay/30.jpg
#   inflating: bg44/fg_76/overlay/4.jpg
#   inflating: bg44/fg_76/overlay/35.jpg
#   inflating: bg44/fg_76/overlay/22.jpg
#   inflating: bg44/fg_76/overlay/34.jpg
#   inflating: bg44/fg_76/overlay/26.jpg
#   inflating: bg44/fg_76/overlay/25.jpg
#   inflating: bg44/fg_76/overlay/18.jpg
#    creating: bg44/fg_44/depth/
#    creating: bg44/fg_44/mask/
#    creating: bg44/fg_44/overlay/
#   inflating: bg44/fg_44/depth/12.jpg
#   inflating: bg44/fg_44/depth/31.jpg
#   inflating: bg44/fg_44/depth/8.jpg
#   inflating: bg44/fg_44/depth/9.jpg
#   inflating: bg44/fg_44/depth/6.jpg
#   inflating: bg44/fg_44/depth/37.jpg
#   inflating: bg44/fg_44/depth/32.jpg
#   inflating: bg44/fg_44/depth/29.jpg
#   inflating: bg44/fg_44/depth/39.jpg
#   inflating: bg44/fg_44/depth/38.jpg
#   inflating: bg44/fg_44/depth/24.jpg
#   inflating: bg44/fg_44/depth/11.jpg
#   inflating: bg44/fg_44/depth/23.jpg
#   inflating: bg44/fg_44/depth/5.jpg
#   inflating: bg44/fg_44/depth/33.jpg
#   inflating: bg44/fg_44/depth/10.jpg
#   inflating: bg44/fg_44/depth/1.jpg
#   inflating: bg44/fg_44/depth/3.jpg
#   inflating: bg44/fg_44/depth/16.jpg
#   inflating: bg44/fg_44/depth/20.jpg
#   inflating: bg44/fg_44/depth/17.jpg
#   inflating: bg44/fg_44/depth/40.jpg
#   inflating: bg44/fg_44/depth/15.jpg
#   inflating: bg44/fg_44/depth/14.jpg
#   inflating: bg44/fg_44/depth/27.jpg
#   inflating: bg44/fg_44/depth/36.jpg
#   inflating: bg44/fg_44/depth/19.jpg
#   inflating: bg44/fg_44/depth/21.jpg
#   inflating: bg44/fg_44/depth/2.jpg
#   inflating: bg44/fg_44/depth/28.jpg
#   inflating: bg44/fg_44/depth/7.jpg
#   inflating: bg44/fg_44/depth/13.jpg
#   inflating: bg44/fg_44/depth/30.jpg
#   inflating: bg44/fg_44/depth/4.jpg
#   inflating: bg44/fg_44/depth/35.jpg
#   inflating: bg44/fg_44/depth/22.jpg
#   inflating: bg44/fg_44/depth/34.jpg
#   inflating: bg44/fg_44/depth/26.jpg
#   inflating: bg44/fg_44/depth/25.jpg
#   inflating: bg44/fg_44/depth/18.jpg
#   inflating: bg44/fg_44/mask/12.jpg
#   inflating: bg44/fg_44/mask/31.jpg
#   inflating: bg44/fg_44/mask/8.jpg
#   inflating: bg44/fg_44/mask/9.jpg
#   inflating: bg44/fg_44/mask/6.jpg
#   inflating: bg44/fg_44/mask/37.jpg
#   inflating: bg44/fg_44/mask/32.jpg
#   inflating: bg44/fg_44/mask/29.jpg
#   inflating: bg44/fg_44/mask/39.jpg
#   inflating: bg44/fg_44/mask/38.jpg
#   inflating: bg44/fg_44/mask/24.jpg
#   inflating: bg44/fg_44/mask/11.jpg
#   inflating: bg44/fg_44/mask/23.jpg
#   inflating: bg44/fg_44/mask/5.jpg
#   inflating: bg44/fg_44/mask/33.jpg
#   inflating: bg44/fg_44/mask/10.jpg
#   inflating: bg44/fg_44/mask/1.jpg
#   inflating: bg44/fg_44/mask/3.jpg
#   inflating: bg44/fg_44/mask/16.jpg
#   inflating: bg44/fg_44/mask/20.jpg
#   inflating: bg44/fg_44/mask/17.jpg
#   inflating: bg44/fg_44/mask/40.jpg
#   inflating: bg44/fg_44/mask/15.jpg
#   inflating: bg44/fg_44/mask/14.jpg
#   inflating: bg44/fg_44/mask/27.jpg
#   inflating: bg44/fg_44/mask/36.jpg
#   inflating: bg44/fg_44/mask/19.jpg
#   inflating: bg44/fg_44/mask/21.jpg
#   inflating: bg44/fg_44/mask/2.jpg
#   inflating: bg44/fg_44/mask/28.jpg
#   inflating: bg44/fg_44/mask/7.jpg
#   inflating: bg44/fg_44/mask/13.jpg
#   inflating: bg44/fg_44/mask/30.jpg
#   inflating: bg44/fg_44/mask/4.jpg
#   inflating: bg44/fg_44/mask/35.jpg
#   inflating: bg44/fg_44/mask/22.jpg
#   inflating: bg44/fg_44/mask/34.jpg
#   inflating: bg44/fg_44/mask/26.jpg
#   inflating: bg44/fg_44/mask/25.jpg
#   inflating: bg44/fg_44/mask/18.jpg
#   inflating: bg44/fg_44/overlay/12.jpg
#   inflating: bg44/fg_44/overlay/31.jpg
#   inflating: bg44/fg_44/overlay/8.jpg
#   inflating: bg44/fg_44/overlay/9.jpg
#   inflating: bg44/fg_44/overlay/6.jpg
#   inflating: bg44/fg_44/overlay/37.jpg
#   inflating: bg44/fg_44/overlay/32.jpg
#   inflating: bg44/fg_44/overlay/29.jpg
#   inflating: bg44/fg_44/overlay/39.jpg
#   inflating: bg44/fg_44/overlay/38.jpg
#   inflating: bg44/fg_44/overlay/24.jpg
#   inflating: bg44/fg_44/overlay/11.jpg
#   inflating: bg44/fg_44/overlay/23.jpg
#   inflating: bg44/fg_44/overlay/5.jpg
#   inflating: bg44/fg_44/overlay/33.jpg
#   inflating: bg44/fg_44/overlay/10.jpg
#   inflating: bg44/fg_44/overlay/1.jpg
#   inflating: bg44/fg_44/overlay/3.jpg
#   inflating: bg44/fg_44/overlay/16.jpg
#   inflating: bg44/fg_44/overlay/20.jpg
#   inflating: bg44/fg_44/overlay/17.jpg
#   inflating: bg44/fg_44/overlay/40.jpg
#   inflating: bg44/fg_44/overlay/15.jpg
#   inflating: bg44/fg_44/overlay/14.jpg
#   inflating: bg44/fg_44/overlay/27.jpg
#   inflating: bg44/fg_44/overlay/36.jpg
#   inflating: bg44/fg_44/overlay/19.jpg
#   inflating: bg44/fg_44/overlay/21.jpg
#   inflating: bg44/fg_44/overlay/2.jpg
#   inflating: bg44/fg_44/overlay/28.jpg
#   inflating: bg44/fg_44/overlay/7.jpg
#   inflating: bg44/fg_44/overlay/13.jpg
#   inflating: bg44/fg_44/overlay/30.jpg
#   inflating: bg44/fg_44/overlay/4.jpg
#   inflating: bg44/fg_44/overlay/35.jpg
#   inflating: bg44/fg_44/overlay/22.jpg
#   inflating: bg44/fg_44/overlay/34.jpg
#   inflating: bg44/fg_44/overlay/26.jpg
#   inflating: bg44/fg_44/overlay/25.jpg
#   inflating: bg44/fg_44/overlay/18.jpg
#    creating: bg44/fg_49/depth/
#    creating: bg44/fg_49/mask/
#    creating: bg44/fg_49/overlay/
#   inflating: bg44/fg_49/depth/12.jpg
#   inflating: bg44/fg_49/depth/31.jpg
#   inflating: bg44/fg_49/depth/8.jpg
#   inflating: bg44/fg_49/depth/9.jpg
#   inflating: bg44/fg_49/depth/6.jpg
#   inflating: bg44/fg_49/depth/37.jpg
#   inflating: bg44/fg_49/depth/32.jpg
#   inflating: bg44/fg_49/depth/29.jpg
#   inflating: bg44/fg_49/depth/39.jpg
#   inflating: bg44/fg_49/depth/38.jpg
#   inflating: bg44/fg_49/depth/24.jpg
#   inflating: bg44/fg_49/depth/11.jpg
#   inflating: bg44/fg_49/depth/23.jpg
#   inflating: bg44/fg_49/depth/5.jpg
#   inflating: bg44/fg_49/depth/33.jpg
#   inflating: bg44/fg_49/depth/10.jpg
#   inflating: bg44/fg_49/depth/1.jpg
#   inflating: bg44/fg_49/depth/3.jpg
#   inflating: bg44/fg_49/depth/16.jpg
#   inflating: bg44/fg_49/depth/20.jpg
#   inflating: bg44/fg_49/depth/17.jpg
#   inflating: bg44/fg_49/depth/40.jpg
#   inflating: bg44/fg_49/depth/15.jpg
#   inflating: bg44/fg_49/depth/14.jpg
#   inflating: bg44/fg_49/depth/27.jpg
#   inflating: bg44/fg_49/depth/36.jpg
#   inflating: bg44/fg_49/depth/19.jpg
#   inflating: bg44/fg_49/depth/21.jpg
#   inflating: bg44/fg_49/depth/2.jpg
#   inflating: bg44/fg_49/depth/28.jpg
#   inflating: bg44/fg_49/depth/7.jpg
#   inflating: bg44/fg_49/depth/13.jpg
#   inflating: bg44/fg_49/depth/30.jpg
#   inflating: bg44/fg_49/depth/4.jpg
#   inflating: bg44/fg_49/depth/35.jpg
#   inflating: bg44/fg_49/depth/22.jpg
#   inflating: bg44/fg_49/depth/34.jpg
#   inflating: bg44/fg_49/depth/26.jpg
#   inflating: bg44/fg_49/depth/25.jpg
#   inflating: bg44/fg_49/depth/18.jpg
#   inflating: bg44/fg_49/mask/12.jpg
#   inflating: bg44/fg_49/mask/31.jpg
#   inflating: bg44/fg_49/mask/8.jpg
#   inflating: bg44/fg_49/mask/9.jpg
#   inflating: bg44/fg_49/mask/6.jpg
#   inflating: bg44/fg_49/mask/37.jpg
#   inflating: bg44/fg_49/mask/32.jpg
#   inflating: bg44/fg_49/mask/29.jpg
#   inflating: bg44/fg_49/mask/39.jpg
#   inflating: bg44/fg_49/mask/38.jpg
#   inflating: bg44/fg_49/mask/24.jpg
#   inflating: bg44/fg_49/mask/11.jpg
#   inflating: bg44/fg_49/mask/23.jpg
#   inflating: bg44/fg_49/mask/5.jpg
#   inflating: bg44/fg_49/mask/33.jpg
#   inflating: bg44/fg_49/mask/10.jpg
#   inflating: bg44/fg_49/mask/1.jpg
#   inflating: bg44/fg_49/mask/3.jpg
#   inflating: bg44/fg_49/mask/16.jpg
#   inflating: bg44/fg_49/mask/20.jpg
#   inflating: bg44/fg_49/mask/17.jpg
#   inflating: bg44/fg_49/mask/40.jpg
#   inflating: bg44/fg_49/mask/15.jpg
#   inflating: bg44/fg_49/mask/14.jpg
#   inflating: bg44/fg_49/mask/27.jpg
#   inflating: bg44/fg_49/mask/36.jpg
#   inflating: bg44/fg_49/mask/19.jpg
#   inflating: bg44/fg_49/mask/21.jpg
#   inflating: bg44/fg_49/mask/2.jpg
#   inflating: bg44/fg_49/mask/28.jpg
#   inflating: bg44/fg_49/mask/7.jpg
#   inflating: bg44/fg_49/mask/13.jpg
#   inflating: bg44/fg_49/mask/30.jpg
#   inflating: bg44/fg_49/mask/4.jpg
#   inflating: bg44/fg_49/mask/35.jpg
#   inflating: bg44/fg_49/mask/22.jpg
#   inflating: bg44/fg_49/mask/34.jpg
#   inflating: bg44/fg_49/mask/26.jpg
#   inflating: bg44/fg_49/mask/25.jpg
#   inflating: bg44/fg_49/mask/18.jpg
#   inflating: bg44/fg_49/overlay/12.jpg
#   inflating: bg44/fg_49/overlay/31.jpg
#   inflating: bg44/fg_49/overlay/8.jpg
#   inflating: bg44/fg_49/overlay/9.jpg
#   inflating: bg44/fg_49/overlay/6.jpg
#   inflating: bg44/fg_49/overlay/37.jpg
#   inflating: bg44/fg_49/overlay/32.jpg
#   inflating: bg44/fg_49/overlay/29.jpg
#   inflating: bg44/fg_49/overlay/39.jpg
#   inflating: bg44/fg_49/overlay/38.jpg
#   inflating: bg44/fg_49/overlay/24.jpg
#   inflating: bg44/fg_49/overlay/11.jpg
#   inflating: bg44/fg_49/overlay/23.jpg
#   inflating: bg44/fg_49/overlay/5.jpg
#   inflating: bg44/fg_49/overlay/33.jpg
#   inflating: bg44/fg_49/overlay/10.jpg
#   inflating: bg44/fg_49/overlay/1.jpg
#   inflating: bg44/fg_49/overlay/3.jpg
#   inflating: bg44/fg_49/overlay/16.jpg
#   inflating: bg44/fg_49/overlay/20.jpg
#   inflating: bg44/fg_49/overlay/17.jpg
#   inflating: bg44/fg_49/overlay/40.jpg
#   inflating: bg44/fg_49/overlay/15.jpg
#   inflating: bg44/fg_49/overlay/14.jpg
#   inflating: bg44/fg_49/overlay/27.jpg
#   inflating: bg44/fg_49/overlay/36.jpg
#   inflating: bg44/fg_49/overlay/19.jpg
#   inflating: bg44/fg_49/overlay/21.jpg
#   inflating: bg44/fg_49/overlay/2.jpg
#   inflating: bg44/fg_49/overlay/28.jpg
#   inflating: bg44/fg_49/overlay/7.jpg
#   inflating: bg44/fg_49/overlay/13.jpg
#   inflating: bg44/fg_49/overlay/30.jpg
#   inflating: bg44/fg_49/overlay/4.jpg
#   inflating: bg44/fg_49/overlay/35.jpg
#   inflating: bg44/fg_49/overlay/22.jpg
#   inflating: bg44/fg_49/overlay/34.jpg
#   inflating: bg44/fg_49/overlay/26.jpg
#   inflating: bg44/fg_49/overlay/25.jpg
#   inflating: bg44/fg_49/overlay/18.jpg
#    creating: bg44/fg_68/depth/
#    creating: bg44/fg_68/mask/
#    creating: bg44/fg_68/overlay/
#   inflating: bg44/fg_68/depth/12.jpg
#   inflating: bg44/fg_68/depth/31.jpg
#   inflating: bg44/fg_68/depth/8.jpg
#   inflating: bg44/fg_68/depth/9.jpg
#   inflating: bg44/fg_68/depth/6.jpg
#   inflating: bg44/fg_68/depth/37.jpg
#   inflating: bg44/fg_68/depth/32.jpg
#   inflating: bg44/fg_68/depth/29.jpg
#   inflating: bg44/fg_68/depth/39.jpg
#   inflating: bg44/fg_68/depth/38.jpg
#   inflating: bg44/fg_68/depth/24.jpg
#   inflating: bg44/fg_68/depth/11.jpg
#   inflating: bg44/fg_68/depth/23.jpg
#   inflating: bg44/fg_68/depth/5.jpg
#   inflating: bg44/fg_68/depth/33.jpg
#   inflating: bg44/fg_68/depth/10.jpg
#   inflating: bg44/fg_68/depth/1.jpg
#   inflating: bg44/fg_68/depth/3.jpg
#   inflating: bg44/fg_68/depth/16.jpg
#   inflating: bg44/fg_68/depth/20.jpg
#   inflating: bg44/fg_68/depth/17.jpg
#   inflating: bg44/fg_68/depth/40.jpg
#   inflating: bg44/fg_68/depth/15.jpg
#   inflating: bg44/fg_68/depth/14.jpg
#   inflating: bg44/fg_68/depth/27.jpg
#   inflating: bg44/fg_68/depth/36.jpg
#   inflating: bg44/fg_68/depth/19.jpg
#   inflating: bg44/fg_68/depth/21.jpg
#   inflating: bg44/fg_68/depth/2.jpg
#   inflating: bg44/fg_68/depth/28.jpg
#   inflating: bg44/fg_68/depth/7.jpg
#   inflating: bg44/fg_68/depth/13.jpg
#   inflating: bg44/fg_68/depth/30.jpg
#   inflating: bg44/fg_68/depth/4.jpg
#   inflating: bg44/fg_68/depth/35.jpg
#   inflating: bg44/fg_68/depth/22.jpg
#   inflating: bg44/fg_68/depth/34.jpg
#   inflating: bg44/fg_68/depth/26.jpg
#   inflating: bg44/fg_68/depth/25.jpg
#   inflating: bg44/fg_68/depth/18.jpg
#   inflating: bg44/fg_68/mask/12.jpg
#   inflating: bg44/fg_68/mask/31.jpg
#   inflating: bg44/fg_68/mask/8.jpg
#   inflating: bg44/fg_68/mask/9.jpg
#   inflating: bg44/fg_68/mask/6.jpg
#   inflating: bg44/fg_68/mask/37.jpg
#   inflating: bg44/fg_68/mask/32.jpg
#   inflating: bg44/fg_68/mask/29.jpg
#   inflating: bg44/fg_68/mask/39.jpg
#   inflating: bg44/fg_68/mask/38.jpg
#   inflating: bg44/fg_68/mask/24.jpg
#   inflating: bg44/fg_68/mask/11.jpg
#   inflating: bg44/fg_68/mask/23.jpg
#   inflating: bg44/fg_68/mask/5.jpg
#   inflating: bg44/fg_68/mask/33.jpg
#   inflating: bg44/fg_68/mask/10.jpg
#   inflating: bg44/fg_68/mask/1.jpg
#   inflating: bg44/fg_68/mask/3.jpg
#   inflating: bg44/fg_68/mask/16.jpg
#   inflating: bg44/fg_68/mask/20.jpg
#   inflating: bg44/fg_68/mask/17.jpg
#   inflating: bg44/fg_68/mask/40.jpg
#   inflating: bg44/fg_68/mask/15.jpg
#   inflating: bg44/fg_68/mask/14.jpg
#   inflating: bg44/fg_68/mask/27.jpg
#   inflating: bg44/fg_68/mask/36.jpg
#   inflating: bg44/fg_68/mask/19.jpg
#   inflating: bg44/fg_68/mask/21.jpg
#   inflating: bg44/fg_68/mask/2.jpg
#   inflating: bg44/fg_68/mask/28.jpg
#   inflating: bg44/fg_68/mask/7.jpg
#   inflating: bg44/fg_68/mask/13.jpg
#   inflating: bg44/fg_68/mask/30.jpg
#   inflating: bg44/fg_68/mask/4.jpg
#   inflating: bg44/fg_68/mask/35.jpg
#   inflating: bg44/fg_68/mask/22.jpg
#   inflating: bg44/fg_68/mask/34.jpg
#   inflating: bg44/fg_68/mask/26.jpg
#   inflating: bg44/fg_68/mask/25.jpg
#   inflating: bg44/fg_68/mask/18.jpg
#   inflating: bg44/fg_68/overlay/12.jpg
#   inflating: bg44/fg_68/overlay/31.jpg
#   inflating: bg44/fg_68/overlay/8.jpg
#   inflating: bg44/fg_68/overlay/9.jpg
#   inflating: bg44/fg_68/overlay/6.jpg
#   inflating: bg44/fg_68/overlay/37.jpg
#   inflating: bg44/fg_68/overlay/32.jpg
#   inflating: bg44/fg_68/overlay/29.jpg
#   inflating: bg44/fg_68/overlay/39.jpg
#   inflating: bg44/fg_68/overlay/38.jpg
#   inflating: bg44/fg_68/overlay/24.jpg
#   inflating: bg44/fg_68/overlay/11.jpg
#   inflating: bg44/fg_68/overlay/23.jpg
#   inflating: bg44/fg_68/overlay/5.jpg
#   inflating: bg44/fg_68/overlay/33.jpg
#   inflating: bg44/fg_68/overlay/10.jpg
#   inflating: bg44/fg_68/overlay/1.jpg
#   inflating: bg44/fg_68/overlay/3.jpg
#   inflating: bg44/fg_68/overlay/16.jpg
#   inflating: bg44/fg_68/overlay/20.jpg
#   inflating: bg44/fg_68/overlay/17.jpg
#   inflating: bg44/fg_68/overlay/40.jpg
#   inflating: bg44/fg_68/overlay/15.jpg
#   inflating: bg44/fg_68/overlay/14.jpg
#   inflating: bg44/fg_68/overlay/27.jpg
#   inflating: bg44/fg_68/overlay/36.jpg
#   inflating: bg44/fg_68/overlay/19.jpg
#   inflating: bg44/fg_68/overlay/21.jpg
#   inflating: bg44/fg_68/overlay/2.jpg
#   inflating: bg44/fg_68/overlay/28.jpg
#   inflating: bg44/fg_68/overlay/7.jpg
#   inflating: bg44/fg_68/overlay/13.jpg
#   inflating: bg44/fg_68/overlay/30.jpg
#   inflating: bg44/fg_68/overlay/4.jpg
#   inflating: bg44/fg_68/overlay/35.jpg
#   inflating: bg44/fg_68/overlay/22.jpg
#   inflating: bg44/fg_68/overlay/34.jpg
#   inflating: bg44/fg_68/overlay/26.jpg
#   inflating: bg44/fg_68/overlay/25.jpg
#   inflating: bg44/fg_68/overlay/18.jpg
#    creating: bg44/fg_65/depth/
#    creating: bg44/fg_65/mask/
#    creating: bg44/fg_65/overlay/
#   inflating: bg44/fg_65/depth/12.jpg
#   inflating: bg44/fg_65/depth/31.jpg
#   inflating: bg44/fg_65/depth/8.jpg
#   inflating: bg44/fg_65/depth/9.jpg
#   inflating: bg44/fg_65/depth/6.jpg
#   inflating: bg44/fg_65/depth/37.jpg
#   inflating: bg44/fg_65/depth/32.jpg
#   inflating: bg44/fg_65/depth/29.jpg
#   inflating: bg44/fg_65/depth/39.jpg
#   inflating: bg44/fg_65/depth/38.jpg
#   inflating: bg44/fg_65/depth/24.jpg
#   inflating: bg44/fg_65/depth/11.jpg
#   inflating: bg44/fg_65/depth/23.jpg
#   inflating: bg44/fg_65/depth/5.jpg
#   inflating: bg44/fg_65/depth/33.jpg
#   inflating: bg44/fg_65/depth/10.jpg
#   inflating: bg44/fg_65/depth/1.jpg
#   inflating: bg44/fg_65/depth/3.jpg
#   inflating: bg44/fg_65/depth/16.jpg
#   inflating: bg44/fg_65/depth/20.jpg
#   inflating: bg44/fg_65/depth/17.jpg
#   inflating: bg44/fg_65/depth/40.jpg
#   inflating: bg44/fg_65/depth/15.jpg
#   inflating: bg44/fg_65/depth/14.jpg
#   inflating: bg44/fg_65/depth/27.jpg
#   inflating: bg44/fg_65/depth/36.jpg
#   inflating: bg44/fg_65/depth/19.jpg
#   inflating: bg44/fg_65/depth/21.jpg
#   inflating: bg44/fg_65/depth/2.jpg
#   inflating: bg44/fg_65/depth/28.jpg
#   inflating: bg44/fg_65/depth/7.jpg
#   inflating: bg44/fg_65/depth/13.jpg
#   inflating: bg44/fg_65/depth/30.jpg
#   inflating: bg44/fg_65/depth/4.jpg
#   inflating: bg44/fg_65/depth/35.jpg
#   inflating: bg44/fg_65/depth/22.jpg
#   inflating: bg44/fg_65/depth/34.jpg
#   inflating: bg44/fg_65/depth/26.jpg
#   inflating: bg44/fg_65/depth/25.jpg
#   inflating: bg44/fg_65/depth/18.jpg
#   inflating: bg44/fg_65/mask/12.jpg
#   inflating: bg44/fg_65/mask/31.jpg
#   inflating: bg44/fg_65/mask/8.jpg
#   inflating: bg44/fg_65/mask/9.jpg
#   inflating: bg44/fg_65/mask/6.jpg
#   inflating: bg44/fg_65/mask/37.jpg
#   inflating: bg44/fg_65/mask/32.jpg
#   inflating: bg44/fg_65/mask/29.jpg
#   inflating: bg44/fg_65/mask/39.jpg
#   inflating: bg44/fg_65/mask/38.jpg
#   inflating: bg44/fg_65/mask/24.jpg
#   inflating: bg44/fg_65/mask/11.jpg
#   inflating: bg44/fg_65/mask/23.jpg
#   inflating: bg44/fg_65/mask/5.jpg
#   inflating: bg44/fg_65/mask/33.jpg
#   inflating: bg44/fg_65/mask/10.jpg
#   inflating: bg44/fg_65/mask/1.jpg
#   inflating: bg44/fg_65/mask/3.jpg
#   inflating: bg44/fg_65/mask/16.jpg
#   inflating: bg44/fg_65/mask/20.jpg
#   inflating: bg44/fg_65/mask/17.jpg
#   inflating: bg44/fg_65/mask/40.jpg
#   inflating: bg44/fg_65/mask/15.jpg
#   inflating: bg44/fg_65/mask/14.jpg
#   inflating: bg44/fg_65/mask/27.jpg
#   inflating: bg44/fg_65/mask/36.jpg
#   inflating: bg44/fg_65/mask/19.jpg
#   inflating: bg44/fg_65/mask/21.jpg
#   inflating: bg44/fg_65/mask/2.jpg
#   inflating: bg44/fg_65/mask/28.jpg
#   inflating: bg44/fg_65/mask/7.jpg
#   inflating: bg44/fg_65/mask/13.jpg
#   inflating: bg44/fg_65/mask/30.jpg
#   inflating: bg44/fg_65/mask/4.jpg
#   inflating: bg44/fg_65/mask/35.jpg
#   inflating: bg44/fg_65/mask/22.jpg
#   inflating: bg44/fg_65/mask/34.jpg
#   inflating: bg44/fg_65/mask/26.jpg
#   inflating: bg44/fg_65/mask/25.jpg
#   inflating: bg44/fg_65/mask/18.jpg
#   inflating: bg44/fg_65/overlay/12.jpg
#   inflating: bg44/fg_65/overlay/31.jpg
#   inflating: bg44/fg_65/overlay/8.jpg
#   inflating: bg44/fg_65/overlay/9.jpg
#   inflating: bg44/fg_65/overlay/6.jpg
#   inflating: bg44/fg_65/overlay/37.jpg
#   inflating: bg44/fg_65/overlay/32.jpg
#   inflating: bg44/fg_65/overlay/29.jpg
#   inflating: bg44/fg_65/overlay/39.jpg
#   inflating: bg44/fg_65/overlay/38.jpg
#   inflating: bg44/fg_65/overlay/24.jpg
#   inflating: bg44/fg_65/overlay/11.jpg
#   inflating: bg44/fg_65/overlay/23.jpg
#   inflating: bg44/fg_65/overlay/5.jpg
#   inflating: bg44/fg_65/overlay/33.jpg
#   inflating: bg44/fg_65/overlay/10.jpg
#   inflating: bg44/fg_65/overlay/1.jpg
#   inflating: bg44/fg_65/overlay/3.jpg
#   inflating: bg44/fg_65/overlay/16.jpg
#   inflating: bg44/fg_65/overlay/20.jpg
#   inflating: bg44/fg_65/overlay/17.jpg
#   inflating: bg44/fg_65/overlay/40.jpg
#   inflating: bg44/fg_65/overlay/15.jpg
#   inflating: bg44/fg_65/overlay/14.jpg
#   inflating: bg44/fg_65/overlay/27.jpg
#   inflating: bg44/fg_65/overlay/36.jpg
#   inflating: bg44/fg_65/overlay/19.jpg
#   inflating: bg44/fg_65/overlay/21.jpg
#   inflating: bg44/fg_65/overlay/2.jpg
#   inflating: bg44/fg_65/overlay/28.jpg
#   inflating: bg44/fg_65/overlay/7.jpg
#   inflating: bg44/fg_65/overlay/13.jpg
#   inflating: bg44/fg_65/overlay/30.jpg
#   inflating: bg44/fg_65/overlay/4.jpg
#   inflating: bg44/fg_65/overlay/35.jpg
#   inflating: bg44/fg_65/overlay/22.jpg
#   inflating: bg44/fg_65/overlay/34.jpg
#   inflating: bg44/fg_65/overlay/26.jpg
#   inflating: bg44/fg_65/overlay/25.jpg
#   inflating: bg44/fg_65/overlay/18.jpg
#    creating: bg44/fg_34/depth/
#    creating: bg44/fg_34/mask/
#    creating: bg44/fg_34/overlay/
#   inflating: bg44/fg_34/depth/12.jpg
#   inflating: bg44/fg_34/depth/31.jpg
#   inflating: bg44/fg_34/depth/8.jpg
#   inflating: bg44/fg_34/depth/9.jpg
#   inflating: bg44/fg_34/depth/6.jpg
#   inflating: bg44/fg_34/depth/37.jpg
#   inflating: bg44/fg_34/depth/32.jpg
#   inflating: bg44/fg_34/depth/29.jpg
#   inflating: bg44/fg_34/depth/39.jpg
#   inflating: bg44/fg_34/depth/38.jpg
#   inflating: bg44/fg_34/depth/24.jpg
#   inflating: bg44/fg_34/depth/11.jpg
#   inflating: bg44/fg_34/depth/23.jpg
#   inflating: bg44/fg_34/depth/5.jpg
#   inflating: bg44/fg_34/depth/33.jpg
#   inflating: bg44/fg_34/depth/10.jpg
#   inflating: bg44/fg_34/depth/1.jpg
#   inflating: bg44/fg_34/depth/3.jpg
#   inflating: bg44/fg_34/depth/16.jpg
#   inflating: bg44/fg_34/depth/20.jpg
#   inflating: bg44/fg_34/depth/17.jpg
#   inflating: bg44/fg_34/depth/40.jpg
#   inflating: bg44/fg_34/depth/15.jpg
#   inflating: bg44/fg_34/depth/14.jpg
#   inflating: bg44/fg_34/depth/27.jpg
#   inflating: bg44/fg_34/depth/36.jpg
#   inflating: bg44/fg_34/depth/19.jpg
#   inflating: bg44/fg_34/depth/21.jpg
#   inflating: bg44/fg_34/depth/2.jpg
#   inflating: bg44/fg_34/depth/28.jpg
#   inflating: bg44/fg_34/depth/7.jpg
#   inflating: bg44/fg_34/depth/13.jpg
#   inflating: bg44/fg_34/depth/30.jpg
#   inflating: bg44/fg_34/depth/4.jpg
#   inflating: bg44/fg_34/depth/35.jpg
#   inflating: bg44/fg_34/depth/22.jpg
#   inflating: bg44/fg_34/depth/34.jpg
#   inflating: bg44/fg_34/depth/26.jpg
#   inflating: bg44/fg_34/depth/25.jpg
#   inflating: bg44/fg_34/depth/18.jpg
#   inflating: bg44/fg_34/mask/12.jpg
#   inflating: bg44/fg_34/mask/31.jpg
#   inflating: bg44/fg_34/mask/8.jpg
#   inflating: bg44/fg_34/mask/9.jpg
#   inflating: bg44/fg_34/mask/6.jpg
#   inflating: bg44/fg_34/mask/37.jpg
#   inflating: bg44/fg_34/mask/32.jpg
#   inflating: bg44/fg_34/mask/29.jpg
#   inflating: bg44/fg_34/mask/39.jpg
#   inflating: bg44/fg_34/mask/38.jpg
#   inflating: bg44/fg_34/mask/24.jpg
#   inflating: bg44/fg_34/mask/11.jpg
#   inflating: bg44/fg_34/mask/23.jpg
#   inflating: bg44/fg_34/mask/5.jpg
#   inflating: bg44/fg_34/mask/33.jpg
#   inflating: bg44/fg_34/mask/10.jpg
#   inflating: bg44/fg_34/mask/1.jpg
#   inflating: bg44/fg_34/mask/3.jpg
#   inflating: bg44/fg_34/mask/16.jpg
#   inflating: bg44/fg_34/mask/20.jpg
#   inflating: bg44/fg_34/mask/17.jpg
#   inflating: bg44/fg_34/mask/40.jpg
#   inflating: bg44/fg_34/mask/15.jpg
#   inflating: bg44/fg_34/mask/14.jpg
#   inflating: bg44/fg_34/mask/27.jpg
#   inflating: bg44/fg_34/mask/36.jpg
#   inflating: bg44/fg_34/mask/19.jpg
#   inflating: bg44/fg_34/mask/21.jpg
#   inflating: bg44/fg_34/mask/2.jpg
#   inflating: bg44/fg_34/mask/28.jpg
#   inflating: bg44/fg_34/mask/7.jpg
#   inflating: bg44/fg_34/mask/13.jpg
#   inflating: bg44/fg_34/mask/30.jpg
#   inflating: bg44/fg_34/mask/4.jpg
#   inflating: bg44/fg_34/mask/35.jpg
#   inflating: bg44/fg_34/mask/22.jpg
#   inflating: bg44/fg_34/mask/34.jpg
#   inflating: bg44/fg_34/mask/26.jpg
#   inflating: bg44/fg_34/mask/25.jpg
#   inflating: bg44/fg_34/mask/18.jpg
#   inflating: bg44/fg_34/overlay/12.jpg
#   inflating: bg44/fg_34/overlay/31.jpg
#   inflating: bg44/fg_34/overlay/8.jpg
#   inflating: bg44/fg_34/overlay/9.jpg
#   inflating: bg44/fg_34/overlay/6.jpg
#   inflating: bg44/fg_34/overlay/37.jpg
#   inflating: bg44/fg_34/overlay/32.jpg
#   inflating: bg44/fg_34/overlay/29.jpg
#   inflating: bg44/fg_34/overlay/39.jpg
#   inflating: bg44/fg_34/overlay/38.jpg
#   inflating: bg44/fg_34/overlay/24.jpg
#   inflating: bg44/fg_34/overlay/11.jpg
#   inflating: bg44/fg_34/overlay/23.jpg
#   inflating: bg44/fg_34/overlay/5.jpg
#   inflating: bg44/fg_34/overlay/33.jpg
#   inflating: bg44/fg_34/overlay/10.jpg
#   inflating: bg44/fg_34/overlay/1.jpg
#   inflating: bg44/fg_34/overlay/3.jpg
#   inflating: bg44/fg_34/overlay/16.jpg
#   inflating: bg44/fg_34/overlay/20.jpg
#   inflating: bg44/fg_34/overlay/17.jpg
#   inflating: bg44/fg_34/overlay/40.jpg
#   inflating: bg44/fg_34/overlay/15.jpg
#   inflating: bg44/fg_34/overlay/14.jpg
#   inflating: bg44/fg_34/overlay/27.jpg
#   inflating: bg44/fg_34/overlay/36.jpg
#   inflating: bg44/fg_34/overlay/19.jpg
#   inflating: bg44/fg_34/overlay/21.jpg
#   inflating: bg44/fg_34/overlay/2.jpg
#   inflating: bg44/fg_34/overlay/28.jpg
#   inflating: bg44/fg_34/overlay/7.jpg
#   inflating: bg44/fg_34/overlay/13.jpg
#   inflating: bg44/fg_34/overlay/30.jpg
#   inflating: bg44/fg_34/overlay/4.jpg
#   inflating: bg44/fg_34/overlay/35.jpg
#   inflating: bg44/fg_34/overlay/22.jpg
#   inflating: bg44/fg_34/overlay/34.jpg
#   inflating: bg44/fg_34/overlay/26.jpg
#   inflating: bg44/fg_34/overlay/25.jpg
#   inflating: bg44/fg_34/overlay/18.jpg
#    creating: bg44/fg_85/depth/
#    creating: bg44/fg_85/mask/
#    creating: bg44/fg_85/overlay/
#   inflating: bg44/fg_85/depth/12.jpg
#   inflating: bg44/fg_85/depth/31.jpg
#   inflating: bg44/fg_85/depth/8.jpg
#   inflating: bg44/fg_85/depth/9.jpg
#   inflating: bg44/fg_85/depth/6.jpg
#   inflating: bg44/fg_85/depth/37.jpg
#   inflating: bg44/fg_85/depth/32.jpg
#   inflating: bg44/fg_85/depth/29.jpg
#   inflating: bg44/fg_85/depth/39.jpg
#   inflating: bg44/fg_85/depth/38.jpg
#   inflating: bg44/fg_85/depth/24.jpg
#   inflating: bg44/fg_85/depth/11.jpg
#   inflating: bg44/fg_85/depth/23.jpg
#   inflating: bg44/fg_85/depth/5.jpg
#   inflating: bg44/fg_85/depth/33.jpg
#   inflating: bg44/fg_85/depth/10.jpg
#   inflating: bg44/fg_85/depth/1.jpg
#   inflating: bg44/fg_85/depth/3.jpg
#   inflating: bg44/fg_85/depth/16.jpg
#   inflating: bg44/fg_85/depth/20.jpg
#   inflating: bg44/fg_85/depth/17.jpg
#   inflating: bg44/fg_85/depth/40.jpg
#   inflating: bg44/fg_85/depth/15.jpg
#   inflating: bg44/fg_85/depth/14.jpg
#   inflating: bg44/fg_85/depth/27.jpg
#   inflating: bg44/fg_85/depth/36.jpg
#   inflating: bg44/fg_85/depth/19.jpg
#   inflating: bg44/fg_85/depth/21.jpg
#   inflating: bg44/fg_85/depth/2.jpg
#   inflating: bg44/fg_85/depth/28.jpg
#   inflating: bg44/fg_85/depth/7.jpg
#   inflating: bg44/fg_85/depth/13.jpg
#   inflating: bg44/fg_85/depth/30.jpg
#   inflating: bg44/fg_85/depth/4.jpg
#   inflating: bg44/fg_85/depth/35.jpg
#   inflating: bg44/fg_85/depth/22.jpg
#   inflating: bg44/fg_85/depth/34.jpg
#   inflating: bg44/fg_85/depth/26.jpg
#   inflating: bg44/fg_85/depth/25.jpg
#   inflating: bg44/fg_85/depth/18.jpg
#   inflating: bg44/fg_85/mask/12.jpg
#   inflating: bg44/fg_85/mask/31.jpg
#   inflating: bg44/fg_85/mask/8.jpg
#   inflating: bg44/fg_85/mask/9.jpg
#   inflating: bg44/fg_85/mask/6.jpg
#   inflating: bg44/fg_85/mask/37.jpg
#   inflating: bg44/fg_85/mask/32.jpg
#   inflating: bg44/fg_85/mask/29.jpg
#   inflating: bg44/fg_85/mask/39.jpg
#   inflating: bg44/fg_85/mask/38.jpg
#   inflating: bg44/fg_85/mask/24.jpg
#   inflating: bg44/fg_85/mask/11.jpg
#   inflating: bg44/fg_85/mask/23.jpg
#   inflating: bg44/fg_85/mask/5.jpg
#   inflating: bg44/fg_85/mask/33.jpg
#   inflating: bg44/fg_85/mask/10.jpg
#   inflating: bg44/fg_85/mask/1.jpg
#   inflating: bg44/fg_85/mask/3.jpg
#   inflating: bg44/fg_85/mask/16.jpg
#   inflating: bg44/fg_85/mask/20.jpg
#   inflating: bg44/fg_85/mask/17.jpg
#   inflating: bg44/fg_85/mask/40.jpg
#   inflating: bg44/fg_85/mask/15.jpg
#   inflating: bg44/fg_85/mask/14.jpg
#   inflating: bg44/fg_85/mask/27.jpg
#   inflating: bg44/fg_85/mask/36.jpg
#   inflating: bg44/fg_85/mask/19.jpg
#   inflating: bg44/fg_85/mask/21.jpg
#   inflating: bg44/fg_85/mask/2.jpg
#   inflating: bg44/fg_85/mask/28.jpg
#   inflating: bg44/fg_85/mask/7.jpg
#   inflating: bg44/fg_85/mask/13.jpg
#   inflating: bg44/fg_85/mask/30.jpg
#   inflating: bg44/fg_85/mask/4.jpg
#   inflating: bg44/fg_85/mask/35.jpg
#   inflating: bg44/fg_85/mask/22.jpg
#   inflating: bg44/fg_85/mask/34.jpg
#   inflating: bg44/fg_85/mask/26.jpg
#   inflating: bg44/fg_85/mask/25.jpg
#   inflating: bg44/fg_85/mask/18.jpg
#   inflating: bg44/fg_85/overlay/12.jpg
#   inflating: bg44/fg_85/overlay/31.jpg
#   inflating: bg44/fg_85/overlay/8.jpg
#   inflating: bg44/fg_85/overlay/9.jpg
#   inflating: bg44/fg_85/overlay/6.jpg
#   inflating: bg44/fg_85/overlay/37.jpg
#   inflating: bg44/fg_85/overlay/32.jpg
#   inflating: bg44/fg_85/overlay/29.jpg
#   inflating: bg44/fg_85/overlay/39.jpg
#   inflating: bg44/fg_85/overlay/38.jpg
#   inflating: bg44/fg_85/overlay/24.jpg
#   inflating: bg44/fg_85/overlay/11.jpg
#   inflating: bg44/fg_85/overlay/23.jpg
#   inflating: bg44/fg_85/overlay/5.jpg
#   inflating: bg44/fg_85/overlay/33.jpg
#   inflating: bg44/fg_85/overlay/10.jpg
#   inflating: bg44/fg_85/overlay/1.jpg
#   inflating: bg44/fg_85/overlay/3.jpg
#   inflating: bg44/fg_85/overlay/16.jpg
#   inflating: bg44/fg_85/overlay/20.jpg
#   inflating: bg44/fg_85/overlay/17.jpg
#   inflating: bg44/fg_85/overlay/40.jpg
#   inflating: bg44/fg_85/overlay/15.jpg
#   inflating: bg44/fg_85/overlay/14.jpg
#   inflating: bg44/fg_85/overlay/27.jpg
#   inflating: bg44/fg_85/overlay/36.jpg
#   inflating: bg44/fg_85/overlay/19.jpg
#   inflating: bg44/fg_85/overlay/21.jpg
#   inflating: bg44/fg_85/overlay/2.jpg
#   inflating: bg44/fg_85/overlay/28.jpg
#   inflating: bg44/fg_85/overlay/7.jpg
#   inflating: bg44/fg_85/overlay/13.jpg
#   inflating: bg44/fg_85/overlay/30.jpg
#   inflating: bg44/fg_85/overlay/4.jpg
#   inflating: bg44/fg_85/overlay/35.jpg
#   inflating: bg44/fg_85/overlay/22.jpg
#   inflating: bg44/fg_85/overlay/34.jpg
#   inflating: bg44/fg_85/overlay/26.jpg
#   inflating: bg44/fg_85/overlay/25.jpg
#   inflating: bg44/fg_85/overlay/18.jpg
#    creating: bg44/fg_83/depth/
#    creating: bg44/fg_83/mask/
#    creating: bg44/fg_83/overlay/
#   inflating: bg44/fg_83/depth/12.jpg
#   inflating: bg44/fg_83/depth/31.jpg
#   inflating: bg44/fg_83/depth/8.jpg
#   inflating: bg44/fg_83/depth/9.jpg
#   inflating: bg44/fg_83/depth/6.jpg
#   inflating: bg44/fg_83/depth/37.jpg
#   inflating: bg44/fg_83/depth/32.jpg
#   inflating: bg44/fg_83/depth/29.jpg
#   inflating: bg44/fg_83/depth/39.jpg
#   inflating: bg44/fg_83/depth/38.jpg
#   inflating: bg44/fg_83/depth/24.jpg
#   inflating: bg44/fg_83/depth/11.jpg
#   inflating: bg44/fg_83/depth/23.jpg
#   inflating: bg44/fg_83/depth/5.jpg
#   inflating: bg44/fg_83/depth/33.jpg
#   inflating: bg44/fg_83/depth/10.jpg
#   inflating: bg44/fg_83/depth/1.jpg
#   inflating: bg44/fg_83/depth/3.jpg
#   inflating: bg44/fg_83/depth/16.jpg
#   inflating: bg44/fg_83/depth/20.jpg
#   inflating: bg44/fg_83/depth/17.jpg
#   inflating: bg44/fg_83/depth/40.jpg
#   inflating: bg44/fg_83/depth/15.jpg
#   inflating: bg44/fg_83/depth/14.jpg
#   inflating: bg44/fg_83/depth/27.jpg
#   inflating: bg44/fg_83/depth/36.jpg
#   inflating: bg44/fg_83/depth/19.jpg
#   inflating: bg44/fg_83/depth/21.jpg
#   inflating: bg44/fg_83/depth/2.jpg
#   inflating: bg44/fg_83/depth/28.jpg
#   inflating: bg44/fg_83/depth/7.jpg
#   inflating: bg44/fg_83/depth/13.jpg
#   inflating: bg44/fg_83/depth/30.jpg
#   inflating: bg44/fg_83/depth/4.jpg
#   inflating: bg44/fg_83/depth/35.jpg
#   inflating: bg44/fg_83/depth/22.jpg
#   inflating: bg44/fg_83/depth/34.jpg
#   inflating: bg44/fg_83/depth/26.jpg
#   inflating: bg44/fg_83/depth/25.jpg
#   inflating: bg44/fg_83/depth/18.jpg
#   inflating: bg44/fg_83/mask/12.jpg
#   inflating: bg44/fg_83/mask/31.jpg
#   inflating: bg44/fg_83/mask/8.jpg
#   inflating: bg44/fg_83/mask/9.jpg
#   inflating: bg44/fg_83/mask/6.jpg
#   inflating: bg44/fg_83/mask/37.jpg
#   inflating: bg44/fg_83/mask/32.jpg
#   inflating: bg44/fg_83/mask/29.jpg
#   inflating: bg44/fg_83/mask/39.jpg
#   inflating: bg44/fg_83/mask/38.jpg
#   inflating: bg44/fg_83/mask/24.jpg
#   inflating: bg44/fg_83/mask/11.jpg
#   inflating: bg44/fg_83/mask/23.jpg
#   inflating: bg44/fg_83/mask/5.jpg
#   inflating: bg44/fg_83/mask/33.jpg
#   inflating: bg44/fg_83/mask/10.jpg
#   inflating: bg44/fg_83/mask/1.jpg
#   inflating: bg44/fg_83/mask/3.jpg
#   inflating: bg44/fg_83/mask/16.jpg
#   inflating: bg44/fg_83/mask/20.jpg
#   inflating: bg44/fg_83/mask/17.jpg
#   inflating: bg44/fg_83/mask/40.jpg
#   inflating: bg44/fg_83/mask/15.jpg
#   inflating: bg44/fg_83/mask/14.jpg
#   inflating: bg44/fg_83/mask/27.jpg
#   inflating: bg44/fg_83/mask/36.jpg
#   inflating: bg44/fg_83/mask/19.jpg
#   inflating: bg44/fg_83/mask/21.jpg
#   inflating: bg44/fg_83/mask/2.jpg
#   inflating: bg44/fg_83/mask/28.jpg
#   inflating: bg44/fg_83/mask/7.jpg
#   inflating: bg44/fg_83/mask/13.jpg
#   inflating: bg44/fg_83/mask/30.jpg
#   inflating: bg44/fg_83/mask/4.jpg
#   inflating: bg44/fg_83/mask/35.jpg
#   inflating: bg44/fg_83/mask/22.jpg
#   inflating: bg44/fg_83/mask/34.jpg
#   inflating: bg44/fg_83/mask/26.jpg
#   inflating: bg44/fg_83/mask/25.jpg
#   inflating: bg44/fg_83/mask/18.jpg
#   inflating: bg44/fg_83/overlay/12.jpg
#   inflating: bg44/fg_83/overlay/31.jpg
#   inflating: bg44/fg_83/overlay/8.jpg
#   inflating: bg44/fg_83/overlay/9.jpg
#   inflating: bg44/fg_83/overlay/6.jpg
#   inflating: bg44/fg_83/overlay/37.jpg
#   inflating: bg44/fg_83/overlay/32.jpg
#   inflating: bg44/fg_83/overlay/29.jpg
#   inflating: bg44/fg_83/overlay/39.jpg
#   inflating: bg44/fg_83/overlay/38.jpg
#   inflating: bg44/fg_83/overlay/24.jpg
#   inflating: bg44/fg_83/overlay/11.jpg
#   inflating: bg44/fg_83/overlay/23.jpg
#   inflating: bg44/fg_83/overlay/5.jpg
#   inflating: bg44/fg_83/overlay/33.jpg
#   inflating: bg44/fg_83/overlay/10.jpg
#   inflating: bg44/fg_83/overlay/1.jpg
#   inflating: bg44/fg_83/overlay/3.jpg
#   inflating: bg44/fg_83/overlay/16.jpg
#   inflating: bg44/fg_83/overlay/20.jpg
#   inflating: bg44/fg_83/overlay/17.jpg
#   inflating: bg44/fg_83/overlay/40.jpg
#   inflating: bg44/fg_83/overlay/15.jpg
#   inflating: bg44/fg_83/overlay/14.jpg
#   inflating: bg44/fg_83/overlay/27.jpg
#   inflating: bg44/fg_83/overlay/36.jpg
#   inflating: bg44/fg_83/overlay/19.jpg
#   inflating: bg44/fg_83/overlay/21.jpg
#   inflating: bg44/fg_83/overlay/2.jpg
#   inflating: bg44/fg_83/overlay/28.jpg
#   inflating: bg44/fg_83/overlay/7.jpg
#   inflating: bg44/fg_83/overlay/13.jpg
#   inflating: bg44/fg_83/overlay/30.jpg
#   inflating: bg44/fg_83/overlay/4.jpg
#   inflating: bg44/fg_83/overlay/35.jpg
#   inflating: bg44/fg_83/overlay/22.jpg
#   inflating: bg44/fg_83/overlay/34.jpg
#   inflating: bg44/fg_83/overlay/26.jpg
#   inflating: bg44/fg_83/overlay/25.jpg
#   inflating: bg44/fg_83/overlay/18.jpg
#    creating: bg44/fg_81/depth/
#    creating: bg44/fg_81/mask/
#    creating: bg44/fg_81/overlay/
#   inflating: bg44/fg_81/depth/12.jpg
#   inflating: bg44/fg_81/depth/31.jpg
#   inflating: bg44/fg_81/depth/8.jpg
#   inflating: bg44/fg_81/depth/9.jpg
#   inflating: bg44/fg_81/depth/6.jpg
#   inflating: bg44/fg_81/depth/37.jpg
#   inflating: bg44/fg_81/depth/32.jpg
#   inflating: bg44/fg_81/depth/29.jpg
#   inflating: bg44/fg_81/depth/39.jpg
#   inflating: bg44/fg_81/depth/38.jpg
#   inflating: bg44/fg_81/depth/24.jpg
#   inflating: bg44/fg_81/depth/11.jpg
#   inflating: bg44/fg_81/depth/23.jpg
#   inflating: bg44/fg_81/depth/5.jpg
#   inflating: bg44/fg_81/depth/33.jpg
#   inflating: bg44/fg_81/depth/10.jpg
#   inflating: bg44/fg_81/depth/1.jpg
#   inflating: bg44/fg_81/depth/3.jpg
#   inflating: bg44/fg_81/depth/16.jpg
#   inflating: bg44/fg_81/depth/20.jpg
#   inflating: bg44/fg_81/depth/17.jpg
#   inflating: bg44/fg_81/depth/40.jpg
#   inflating: bg44/fg_81/depth/15.jpg
#   inflating: bg44/fg_81/depth/14.jpg
#   inflating: bg44/fg_81/depth/27.jpg
#   inflating: bg44/fg_81/depth/36.jpg
#   inflating: bg44/fg_81/depth/19.jpg
#   inflating: bg44/fg_81/depth/21.jpg
#   inflating: bg44/fg_81/depth/2.jpg
#   inflating: bg44/fg_81/depth/28.jpg
#   inflating: bg44/fg_81/depth/7.jpg
#   inflating: bg44/fg_81/depth/13.jpg
#   inflating: bg44/fg_81/depth/30.jpg
#   inflating: bg44/fg_81/depth/4.jpg
#   inflating: bg44/fg_81/depth/35.jpg
#   inflating: bg44/fg_81/depth/22.jpg
#   inflating: bg44/fg_81/depth/34.jpg
#   inflating: bg44/fg_81/depth/26.jpg
#   inflating: bg44/fg_81/depth/25.jpg
#   inflating: bg44/fg_81/depth/18.jpg
#   inflating: bg44/fg_81/mask/12.jpg
#   inflating: bg44/fg_81/mask/31.jpg
#   inflating: bg44/fg_81/mask/8.jpg
#   inflating: bg44/fg_81/mask/9.jpg
#   inflating: bg44/fg_81/mask/6.jpg
#   inflating: bg44/fg_81/mask/37.jpg
#   inflating: bg44/fg_81/mask/32.jpg
#   inflating: bg44/fg_81/mask/29.jpg
#   inflating: bg44/fg_81/mask/39.jpg
#   inflating: bg44/fg_81/mask/38.jpg
#   inflating: bg44/fg_81/mask/24.jpg
#   inflating: bg44/fg_81/mask/11.jpg
#   inflating: bg44/fg_81/mask/23.jpg
#   inflating: bg44/fg_81/mask/5.jpg
#   inflating: bg44/fg_81/mask/33.jpg
#   inflating: bg44/fg_81/mask/10.jpg
#   inflating: bg44/fg_81/mask/1.jpg
#   inflating: bg44/fg_81/mask/3.jpg
#   inflating: bg44/fg_81/mask/16.jpg
#   inflating: bg44/fg_81/mask/20.jpg
#   inflating: bg44/fg_81/mask/17.jpg
#   inflating: bg44/fg_81/mask/40.jpg
#   inflating: bg44/fg_81/mask/15.jpg
#   inflating: bg44/fg_81/mask/14.jpg
#   inflating: bg44/fg_81/mask/27.jpg
#   inflating: bg44/fg_81/mask/36.jpg
#   inflating: bg44/fg_81/mask/19.jpg
#   inflating: bg44/fg_81/mask/21.jpg
#   inflating: bg44/fg_81/mask/2.jpg
#   inflating: bg44/fg_81/mask/28.jpg
#   inflating: bg44/fg_81/mask/7.jpg
#   inflating: bg44/fg_81/mask/13.jpg
#   inflating: bg44/fg_81/mask/30.jpg
#   inflating: bg44/fg_81/mask/4.jpg
#   inflating: bg44/fg_81/mask/35.jpg
#   inflating: bg44/fg_81/mask/22.jpg
#   inflating: bg44/fg_81/mask/34.jpg
#   inflating: bg44/fg_81/mask/26.jpg
#   inflating: bg44/fg_81/mask/25.jpg
#   inflating: bg44/fg_81/mask/18.jpg
#   inflating: bg44/fg_81/overlay/12.jpg
#   inflating: bg44/fg_81/overlay/31.jpg
#   inflating: bg44/fg_81/overlay/8.jpg
#   inflating: bg44/fg_81/overlay/9.jpg
#   inflating: bg44/fg_81/overlay/6.jpg
#   inflating: bg44/fg_81/overlay/37.jpg
#   inflating: bg44/fg_81/overlay/32.jpg
#   inflating: bg44/fg_81/overlay/29.jpg
#   inflating: bg44/fg_81/overlay/39.jpg
#   inflating: bg44/fg_81/overlay/38.jpg
#   inflating: bg44/fg_81/overlay/24.jpg
#   inflating: bg44/fg_81/overlay/11.jpg
#   inflating: bg44/fg_81/overlay/23.jpg
#   inflating: bg44/fg_81/overlay/5.jpg
#   inflating: bg44/fg_81/overlay/33.jpg
#   inflating: bg44/fg_81/overlay/10.jpg
#   inflating: bg44/fg_81/overlay/1.jpg
#   inflating: bg44/fg_81/overlay/3.jpg
#   inflating: bg44/fg_81/overlay/16.jpg
#   inflating: bg44/fg_81/overlay/20.jpg
#   inflating: bg44/fg_81/overlay/17.jpg
#   inflating: bg44/fg_81/overlay/40.jpg
#   inflating: bg44/fg_81/overlay/15.jpg
#   inflating: bg44/fg_81/overlay/14.jpg
#   inflating: bg44/fg_81/overlay/27.jpg
#   inflating: bg44/fg_81/overlay/36.jpg
#   inflating: bg44/fg_81/overlay/19.jpg
#   inflating: bg44/fg_81/overlay/21.jpg
#   inflating: bg44/fg_81/overlay/2.jpg
#   inflating: bg44/fg_81/overlay/28.jpg
#   inflating: bg44/fg_81/overlay/7.jpg
#   inflating: bg44/fg_81/overlay/13.jpg
#   inflating: bg44/fg_81/overlay/30.jpg
#   inflating: bg44/fg_81/overlay/4.jpg
#   inflating: bg44/fg_81/overlay/35.jpg
#   inflating: bg44/fg_81/overlay/22.jpg
#   inflating: bg44/fg_81/overlay/34.jpg
#   inflating: bg44/fg_81/overlay/26.jpg
#   inflating: bg44/fg_81/overlay/25.jpg
#   inflating: bg44/fg_81/overlay/18.jpg
#    creating: bg44/fg_11/depth/
#    creating: bg44/fg_11/mask/
#    creating: bg44/fg_11/overlay/
#   inflating: bg44/fg_11/depth/12.jpg
#   inflating: bg44/fg_11/depth/31.jpg
#   inflating: bg44/fg_11/depth/8.jpg
#   inflating: bg44/fg_11/depth/9.jpg
#   inflating: bg44/fg_11/depth/6.jpg
#   inflating: bg44/fg_11/depth/37.jpg
#   inflating: bg44/fg_11/depth/32.jpg
#   inflating: bg44/fg_11/depth/29.jpg
#   inflating: bg44/fg_11/depth/39.jpg
#   inflating: bg44/fg_11/depth/38.jpg
#   inflating: bg44/fg_11/depth/24.jpg
#   inflating: bg44/fg_11/depth/11.jpg
#   inflating: bg44/fg_11/depth/23.jpg
#   inflating: bg44/fg_11/depth/5.jpg
#   inflating: bg44/fg_11/depth/33.jpg
#   inflating: bg44/fg_11/depth/10.jpg
#   inflating: bg44/fg_11/depth/1.jpg
#   inflating: bg44/fg_11/depth/3.jpg
#   inflating: bg44/fg_11/depth/16.jpg
#   inflating: bg44/fg_11/depth/20.jpg
#   inflating: bg44/fg_11/depth/17.jpg
#   inflating: bg44/fg_11/depth/40.jpg
#   inflating: bg44/fg_11/depth/15.jpg
#   inflating: bg44/fg_11/depth/14.jpg
#   inflating: bg44/fg_11/depth/27.jpg
#   inflating: bg44/fg_11/depth/36.jpg
#   inflating: bg44/fg_11/depth/19.jpg
#   inflating: bg44/fg_11/depth/21.jpg
#   inflating: bg44/fg_11/depth/2.jpg
#   inflating: bg44/fg_11/depth/28.jpg
#   inflating: bg44/fg_11/depth/7.jpg
#   inflating: bg44/fg_11/depth/13.jpg
#   inflating: bg44/fg_11/depth/30.jpg
#   inflating: bg44/fg_11/depth/4.jpg
#   inflating: bg44/fg_11/depth/35.jpg
#   inflating: bg44/fg_11/depth/22.jpg
#   inflating: bg44/fg_11/depth/34.jpg
#   inflating: bg44/fg_11/depth/26.jpg
#   inflating: bg44/fg_11/depth/25.jpg
#   inflating: bg44/fg_11/depth/18.jpg
#   inflating: bg44/fg_11/mask/12.jpg
#   inflating: bg44/fg_11/mask/31.jpg
#   inflating: bg44/fg_11/mask/8.jpg
#   inflating: bg44/fg_11/mask/9.jpg
#   inflating: bg44/fg_11/mask/6.jpg
#   inflating: bg44/fg_11/mask/37.jpg
#   inflating: bg44/fg_11/mask/32.jpg
#   inflating: bg44/fg_11/mask/29.jpg
#   inflating: bg44/fg_11/mask/39.jpg
#   inflating: bg44/fg_11/mask/38.jpg
#   inflating: bg44/fg_11/mask/24.jpg
#   inflating: bg44/fg_11/mask/11.jpg
#   inflating: bg44/fg_11/mask/23.jpg
#   inflating: bg44/fg_11/mask/5.jpg
#   inflating: bg44/fg_11/mask/33.jpg
#   inflating: bg44/fg_11/mask/10.jpg
#   inflating: bg44/fg_11/mask/1.jpg
#   inflating: bg44/fg_11/mask/3.jpg
#   inflating: bg44/fg_11/mask/16.jpg
#   inflating: bg44/fg_11/mask/20.jpg
#   inflating: bg44/fg_11/mask/17.jpg
#   inflating: bg44/fg_11/mask/40.jpg
#   inflating: bg44/fg_11/mask/15.jpg
#   inflating: bg44/fg_11/mask/14.jpg
#   inflating: bg44/fg_11/mask/27.jpg
#   inflating: bg44/fg_11/mask/36.jpg
#   inflating: bg44/fg_11/mask/19.jpg
#   inflating: bg44/fg_11/mask/21.jpg
#   inflating: bg44/fg_11/mask/2.jpg
#   inflating: bg44/fg_11/mask/28.jpg
#   inflating: bg44/fg_11/mask/7.jpg
#   inflating: bg44/fg_11/mask/13.jpg
#   inflating: bg44/fg_11/mask/30.jpg
#   inflating: bg44/fg_11/mask/4.jpg
#   inflating: bg44/fg_11/mask/35.jpg
#   inflating: bg44/fg_11/mask/22.jpg
#   inflating: bg44/fg_11/mask/34.jpg
#   inflating: bg44/fg_11/mask/26.jpg
#   inflating: bg44/fg_11/mask/25.jpg
#   inflating: bg44/fg_11/mask/18.jpg
#   inflating: bg44/fg_11/overlay/12.jpg
#   inflating: bg44/fg_11/overlay/31.jpg
#   inflating: bg44/fg_11/overlay/8.jpg
#   inflating: bg44/fg_11/overlay/9.jpg
#   inflating: bg44/fg_11/overlay/6.jpg
#   inflating: bg44/fg_11/overlay/37.jpg
#   inflating: bg44/fg_11/overlay/32.jpg
#   inflating: bg44/fg_11/overlay/29.jpg
#   inflating: bg44/fg_11/overlay/39.jpg
#   inflating: bg44/fg_11/overlay/38.jpg
#   inflating: bg44/fg_11/overlay/24.jpg
#   inflating: bg44/fg_11/overlay/11.jpg
#   inflating: bg44/fg_11/overlay/23.jpg
#   inflating: bg44/fg_11/overlay/5.jpg
#   inflating: bg44/fg_11/overlay/33.jpg
#   inflating: bg44/fg_11/overlay/10.jpg
#   inflating: bg44/fg_11/overlay/1.jpg
#   inflating: bg44/fg_11/overlay/3.jpg
#   inflating: bg44/fg_11/overlay/16.jpg
#   inflating: bg44/fg_11/overlay/20.jpg
#   inflating: bg44/fg_11/overlay/17.jpg
#   inflating: bg44/fg_11/overlay/40.jpg
#   inflating: bg44/fg_11/overlay/15.jpg
#   inflating: bg44/fg_11/overlay/14.jpg
#   inflating: bg44/fg_11/overlay/27.jpg
#   inflating: bg44/fg_11/overlay/36.jpg
#   inflating: bg44/fg_11/overlay/19.jpg
#   inflating: bg44/fg_11/overlay/21.jpg
#   inflating: bg44/fg_11/overlay/2.jpg
#   inflating: bg44/fg_11/overlay/28.jpg
#   inflating: bg44/fg_11/overlay/7.jpg
#   inflating: bg44/fg_11/overlay/13.jpg
#   inflating: bg44/fg_11/overlay/30.jpg
#   inflating: bg44/fg_11/overlay/4.jpg
#   inflating: bg44/fg_11/overlay/35.jpg
#   inflating: bg44/fg_11/overlay/22.jpg
#   inflating: bg44/fg_11/overlay/34.jpg
#   inflating: bg44/fg_11/overlay/26.jpg
#   inflating: bg44/fg_11/overlay/25.jpg
#   inflating: bg44/fg_11/overlay/18.jpg
#    creating: bg44/fg_75/depth/
#    creating: bg44/fg_75/mask/
#    creating: bg44/fg_75/overlay/
#   inflating: bg44/fg_75/depth/12.jpg
#   inflating: bg44/fg_75/depth/31.jpg
#   inflating: bg44/fg_75/depth/8.jpg
#   inflating: bg44/fg_75/depth/9.jpg
#   inflating: bg44/fg_75/depth/6.jpg
#   inflating: bg44/fg_75/depth/37.jpg
#   inflating: bg44/fg_75/depth/32.jpg
#   inflating: bg44/fg_75/depth/29.jpg
#   inflating: bg44/fg_75/depth/39.jpg
#   inflating: bg44/fg_75/depth/38.jpg
#   inflating: bg44/fg_75/depth/24.jpg
#   inflating: bg44/fg_75/depth/11.jpg
#   inflating: bg44/fg_75/depth/23.jpg
#   inflating: bg44/fg_75/depth/5.jpg
#   inflating: bg44/fg_75/depth/33.jpg
#   inflating: bg44/fg_75/depth/10.jpg
#   inflating: bg44/fg_75/depth/1.jpg
#   inflating: bg44/fg_75/depth/3.jpg
#   inflating: bg44/fg_75/depth/16.jpg
#   inflating: bg44/fg_75/depth/20.jpg
#   inflating: bg44/fg_75/depth/17.jpg
#   inflating: bg44/fg_75/depth/40.jpg
#   inflating: bg44/fg_75/depth/15.jpg
#   inflating: bg44/fg_75/depth/14.jpg
#   inflating: bg44/fg_75/depth/27.jpg
#   inflating: bg44/fg_75/depth/36.jpg
#   inflating: bg44/fg_75/depth/19.jpg
#   inflating: bg44/fg_75/depth/21.jpg
#   inflating: bg44/fg_75/depth/2.jpg
#   inflating: bg44/fg_75/depth/28.jpg
#   inflating: bg44/fg_75/depth/7.jpg
#   inflating: bg44/fg_75/depth/13.jpg
#   inflating: bg44/fg_75/depth/30.jpg
#   inflating: bg44/fg_75/depth/4.jpg
#   inflating: bg44/fg_75/depth/35.jpg
#   inflating: bg44/fg_75/depth/22.jpg
#   inflating: bg44/fg_75/depth/34.jpg
#   inflating: bg44/fg_75/depth/26.jpg
#   inflating: bg44/fg_75/depth/25.jpg
#   inflating: bg44/fg_75/depth/18.jpg
# ...
#   inflating: bg44/fg_45/overlay/31.jpg
#   inflating: bg44/fg_45/overlay/8.jpg
#   inflating: bg44/fg_45/overlay/9.jpg
#   inflating: bg44/fg_45/overlay/6.jpg
#   inflating: bg44/fg_45/overlay/37.jpg
#   inflating: bg44/fg_45/overlay/32.jpg
#   inflating: bg44/fg_45/overlay/29.jpg
#   inflating: bg44/fg_45/overlay/39.jpg
#   inflating: bg44/fg_45/overlay/38.jpg
#   inflating: bg44/fg_45/overlay/24.jpg
#   inflating: bg44/fg_45/overlay/11.jpg
#   inflating: bg44/fg_45/overlay/23.jpg
#   inflating: bg44/fg_45/overlay/5.jpg
#   inflating: bg44/fg_45/overlay/33.jpg
#   inflating: bg44/fg_45/overlay/10.jpg
#   inflating: bg44/fg_45/overlay/1.jpg
#   inflating: bg44/fg_45/overlay/3.jpg
#   inflating: bg44/fg_45/overlay/16.jpg
#   inflating: bg44/fg_45/overlay/20.jpg
#   inflating: bg44/fg_45/overlay/17.jpg
#   inflating: bg44/fg_45/overlay/40.jpg
#   inflating: bg44/fg_45/overlay/15.jpg
#   inflating: bg44/fg_45/overlay/14.jpg
#   inflating: bg44/fg_45/overlay/27.jpg
#   inflating: bg44/fg_45/overlay/36.jpg
#   inflating: bg44/fg_45/overlay/19.jpg
#   inflating: bg44/fg_45/overlay/21.jpg
#   inflating: bg44/fg_45/overlay/2.jpg
#   inflating: bg44/fg_45/overlay/28.jpg
#   inflating: bg44/fg_45/overlay/7.jpg
#   inflating: bg44/fg_45/overlay/13.jpg
#   inflating: bg44/fg_45/overlay/30.jpg
#   inflating: bg44/fg_45/overlay/4.jpg
#   inflating: bg44/fg_45/overlay/35.jpg
#   inflating: bg44/fg_45/overlay/22.jpg
#   inflating: bg44/fg_45/overlay/34.jpg
#   inflating: bg44/fg_45/overlay/26.jpg
#   inflating: bg44/fg_45/overlay/25.jpg
#   inflating: bg44/fg_45/overlay/18.jpg
#    creating: bg44/fg_87/depth/
#    creating: bg44/fg_87/mask/
#    creating: bg44/fg_87/overlay/
#   inflating: bg44/fg_87/depth/12.jpg
#   inflating: bg44/fg_87/depth/31.jpg
#   inflating: bg44/fg_87/depth/8.jpg
#   inflating: bg44/fg_87/depth/9.jpg
#   inflating: bg44/fg_87/depth/6.jpg
#   inflating: bg44/fg_87/depth/37.jpg
#   inflating: bg44/fg_87/depth/32.jpg
#   inflating: bg44/fg_87/depth/29.jpg
#   inflating: bg44/fg_87/depth/39.jpg
#   inflating: bg44/fg_87/depth/38.jpg
#   inflating: bg44/fg_87/depth/24.jpg
#   inflating: bg44/fg_87/depth/11.jpg
#   inflating: bg44/fg_87/depth/23.jpg
#   inflating: bg44/fg_87/depth/5.jpg
#   inflating: bg44/fg_87/depth/33.jpg
#   inflating: bg44/fg_87/depth/10.jpg
#   inflating: bg44/fg_87/depth/1.jpg
#   inflating: bg44/fg_87/depth/3.jpg
#   inflating: bg44/fg_87/depth/16.jpg
#   inflating: bg44/fg_87/depth/20.jpg
#   inflating: bg44/fg_87/depth/17.jpg
#   inflating: bg44/fg_87/depth/40.jpg
#   inflating: bg44/fg_87/depth/15.jpg
#   inflating: bg44/fg_87/depth/14.jpg
#   inflating: bg44/fg_87/depth/27.jpg
#   inflating: bg44/fg_87/depth/36.jpg
#   inflating: bg44/fg_87/depth/19.jpg
#   inflating: bg44/fg_87/depth/21.jpg
#   inflating: bg44/fg_87/depth/2.jpg
#   inflating: bg44/fg_87/depth/28.jpg
#   inflating: bg44/fg_87/depth/7.jpg
#   inflating: bg44/fg_87/depth/13.jpg
#   inflating: bg44/fg_87/depth/30.jpg
#   inflating: bg44/fg_87/depth/4.jpg
#   inflating: bg44/fg_87/depth/35.jpg
#   inflating: bg44/fg_87/depth/22.jpg
#   inflating: bg44/fg_87/depth/34.jpg
#   inflating: bg44/fg_87/depth/26.jpg
#   inflating: bg44/fg_87/depth/25.jpg
#   inflating: bg44/fg_87/depth/18.jpg
#   inflating: bg44/fg_87/mask/12.jpg
#   inflating: bg44/fg_87/mask/31.jpg
#   inflating: bg44/fg_87/mask/8.jpg
#   inflating: bg44/fg_87/mask/9.jpg
#   inflating: bg44/fg_87/mask/6.jpg
#   inflating: bg44/fg_87/mask/37.jpg
#   inflating: bg44/fg_87/mask/32.jpg
#   inflating: bg44/fg_87/mask/29.jpg
#   inflating: bg44/fg_87/mask/39.jpg
#   inflating: bg44/fg_87/mask/38.jpg
#   inflating: bg44/fg_87/mask/24.jpg
#   inflating: bg44/fg_87/mask/11.jpg
#   inflating: bg44/fg_87/mask/23.jpg
#   inflating: bg44/fg_87/mask/5.jpg
#   inflating: bg44/fg_87/mask/33.jpg
#   inflating: bg44/fg_87/mask/10.jpg
#   inflating: bg44/fg_87/mask/1.jpg
#   inflating: bg44/fg_87/mask/3.jpg
#   inflating: bg44/fg_87/mask/16.jpg
#   inflating: bg44/fg_87/mask/20.jpg
#   inflating: bg44/fg_87/mask/17.jpg
#   inflating: bg44/fg_87/mask/40.jpg
#   inflating: bg44/fg_87/mask/15.jpg
#   inflating: bg44/fg_87/mask/14.jpg
#   inflating: bg44/fg_87/mask/27.jpg
#   inflating: bg44/fg_87/mask/36.jpg
#   inflating: bg44/fg_87/mask/19.jpg
#   inflating: bg44/fg_87/mask/21.jpg
#   inflating: bg44/fg_87/mask/2.jpg
#   inflating: bg44/fg_87/mask/28.jpg
#   inflating: bg44/fg_87/mask/7.jpg
#   inflating: bg44/fg_87/mask/13.jpg
#   inflating: bg44/fg_87/mask/30.jpg
#   inflating: bg44/fg_87/mask/4.jpg
#   inflating: bg44/fg_87/mask/35.jpg
#   inflating: bg44/fg_87/mask/22.jpg
#   inflating: bg44/fg_87/mask/34.jpg
#   inflating: bg44/fg_87/mask/26.jpg
#   inflating: bg44/fg_87/mask/25.jpg
#   inflating: bg44/fg_87/mask/18.jpg
#   inflating: bg44/fg_87/overlay/12.jpg
#   inflating: bg44/fg_87/overlay/31.jpg
#   inflating: bg44/fg_87/overlay/8.jpg
#   inflating: bg44/fg_87/overlay/9.jpg
#   inflating: bg44/fg_87/overlay/6.jpg
#   inflating: bg44/fg_87/overlay/37.jpg
#   inflating: bg44/fg_87/overlay/32.jpg
#   inflating: bg44/fg_87/overlay/29.jpg
#   inflating: bg44/fg_87/overlay/39.jpg
#   inflating: bg44/fg_87/overlay/38.jpg
#   inflating: bg44/fg_87/overlay/24.jpg
#   inflating: bg44/fg_87/overlay/11.jpg
#   inflating: bg44/fg_87/overlay/23.jpg
#   inflating: bg44/fg_87/overlay/5.jpg
#   inflating: bg44/fg_87/overlay/33.jpg
#   inflating: bg44/fg_87/overlay/10.jpg
#   inflating: bg44/fg_87/overlay/1.jpg
#   inflating: bg44/fg_87/overlay/3.jpg
#   inflating: bg44/fg_87/overlay/16.jpg
#   inflating: bg44/fg_87/overlay/20.jpg
#   inflating: bg44/fg_87/overlay/17.jpg
#   inflating: bg44/fg_87/overlay/40.jpg
#   inflating: bg44/fg_87/overlay/15.jpg
#   inflating: bg44/fg_87/overlay/14.jpg
#   inflating: bg44/fg_87/overlay/27.jpg
#   inflating: bg44/fg_87/overlay/36.jpg
#   inflating: bg44/fg_87/overlay/19.jpg
#   inflating: bg44/fg_87/overlay/21.jpg
#   inflating: bg44/fg_87/overlay/2.jpg
#   inflating: bg44/fg_87/overlay/28.jpg
#   inflating: bg44/fg_87/overlay/7.jpg
#   inflating: bg44/fg_87/overlay/13.jpg
#   inflating: bg44/fg_87/overlay/30.jpg
#   inflating: bg44/fg_87/overlay/4.jpg
#   inflating: bg44/fg_87/overlay/35.jpg
#   inflating: bg44/fg_87/overlay/22.jpg
#   inflating: bg44/fg_87/overlay/34.jpg
#   inflating: bg44/fg_87/overlay/26.jpg
#   inflating: bg44/fg_87/overlay/25.jpg
#   inflating: bg44/fg_87/overlay/18.jpg
#    creating: bg44/fg_51/depth/
#    creating: bg44/fg_51/mask/
#    creating: bg44/fg_51/overlay/
#   inflating: bg44/fg_51/depth/12.jpg
#   inflating: bg44/fg_51/depth/31.jpg
#   inflating: bg44/fg_51/depth/8.jpg
#   inflating: bg44/fg_51/depth/9.jpg
#   inflating: bg44/fg_51/depth/6.jpg
#   inflating: bg44/fg_51/depth/37.jpg
#   inflating: bg44/fg_51/depth/32.jpg
#   inflating: bg44/fg_51/depth/29.jpg
#   inflating: bg44/fg_51/depth/39.jpg
#   inflating: bg44/fg_51/depth/38.jpg
#   inflating: bg44/fg_51/depth/24.jpg
#   inflating: bg44/fg_51/depth/11.jpg
#   inflating: bg44/fg_51/depth/23.jpg
#   inflating: bg44/fg_51/depth/5.jpg
#   inflating: bg44/fg_51/depth/33.jpg
#   inflating: bg44/fg_51/depth/10.jpg
#   inflating: bg44/fg_51/depth/1.jpg
#   inflating: bg44/fg_51/depth/3.jpg
#   inflating: bg44/fg_51/depth/16.jpg
#   inflating: bg44/fg_51/depth/20.jpg
#   inflating: bg44/fg_51/depth/17.jpg
#   inflating: bg44/fg_51/depth/40.jpg
#   inflating: bg44/fg_51/depth/15.jpg
#   inflating: bg44/fg_51/depth/14.jpg
#   inflating: bg44/fg_51/depth/27.jpg
#   inflating: bg44/fg_51/depth/36.jpg
#   inflating: bg44/fg_51/depth/19.jpg
#   inflating: bg44/fg_51/depth/21.jpg
#   inflating: bg44/fg_51/depth/2.jpg
#   inflating: bg44/fg_51/depth/28.jpg
#   inflating: bg44/fg_51/depth/7.jpg
#   inflating: bg44/fg_51/depth/13.jpg
#   inflating: bg44/fg_51/depth/30.jpg
#   inflating: bg44/fg_51/depth/4.jpg
#   inflating: bg44/fg_51/depth/35.jpg
#   inflating: bg44/fg_51/depth/22.jpg
#   inflating: bg44/fg_51/depth/34.jpg
#   inflating: bg44/fg_51/depth/26.jpg
#   inflating: bg44/fg_51/depth/25.jpg
#   inflating: bg44/fg_51/depth/18.jpg
#   inflating: bg44/fg_51/mask/12.jpg
#   inflating: bg44/fg_51/mask/31.jpg
#   inflating: bg44/fg_51/mask/8.jpg
#   inflating: bg44/fg_51/mask/9.jpg
#   inflating: bg44/fg_51/mask/6.jpg
#   inflating: bg44/fg_51/mask/37.jpg
#   inflating: bg44/fg_51/mask/32.jpg
#   inflating: bg44/fg_51/mask/29.jpg
#   inflating: bg44/fg_51/mask/39.jpg
#   inflating: bg44/fg_51/mask/38.jpg
#   inflating: bg44/fg_51/mask/24.jpg
#   inflating: bg44/fg_51/mask/11.jpg
#   inflating: bg44/fg_51/mask/23.jpg
#   inflating: bg44/fg_51/mask/5.jpg
#   inflating: bg44/fg_51/mask/33.jpg
#   inflating: bg44/fg_51/mask/10.jpg
#   inflating: bg44/fg_51/mask/1.jpg
#   inflating: bg44/fg_51/mask/3.jpg
#   inflating: bg44/fg_51/mask/16.jpg
#   inflating: bg44/fg_51/mask/20.jpg
#   inflating: bg44/fg_51/mask/17.jpg
#   inflating: bg44/fg_51/mask/40.jpg
#   inflating: bg44/fg_51/mask/15.jpg
#   inflating: bg44/fg_51/mask/14.jpg
#   inflating: bg44/fg_51/mask/27.jpg
#   inflating: bg44/fg_51/mask/36.jpg
#   inflating: bg44/fg_51/mask/19.jpg
#   inflating: bg44/fg_51/mask/21.jpg
#   inflating: bg44/fg_51/mask/2.jpg
#   inflating: bg44/fg_51/mask/28.jpg
#   inflating: bg44/fg_51/mask/7.jpg
#   inflating: bg44/fg_51/mask/13.jpg
#   inflating: bg44/fg_51/mask/30.jpg
#   inflating: bg44/fg_51/mask/4.jpg
#   inflating: bg44/fg_51/mask/35.jpg
#   inflating: bg44/fg_51/mask/22.jpg
#   inflating: bg44/fg_51/mask/34.jpg
#   inflating: bg44/fg_51/mask/26.jpg
#   inflating: bg44/fg_51/mask/25.jpg
#   inflating: bg44/fg_51/mask/18.jpg
#   inflating: bg44/fg_51/overlay/12.jpg
#   inflating: bg44/fg_51/overlay/31.jpg
#   inflating: bg44/fg_51/overlay/8.jpg
#   inflating: bg44/fg_51/overlay/9.jpg
#   inflating: bg44/fg_51/overlay/6.jpg
#   inflating: bg44/fg_51/overlay/37.jpg
#   inflating: bg44/fg_51/overlay/32.jpg
#   inflating: bg44/fg_51/overlay/29.jpg
#   inflating: bg44/fg_51/overlay/39.jpg
#   inflating: bg44/fg_51/overlay/38.jpg
#   inflating: bg44/fg_51/overlay/24.jpg
#   inflating: bg44/fg_51/overlay/11.jpg
#   inflating: bg44/fg_51/overlay/23.jpg
#   inflating: bg44/fg_51/overlay/5.jpg
#   inflating: bg44/fg_51/overlay/33.jpg
#   inflating: bg44/fg_51/overlay/10.jpg
#   inflating: bg44/fg_51/overlay/1.jpg
#   inflating: bg44/fg_51/overlay/3.jpg
#   inflating: bg44/fg_51/overlay/16.jpg
#   inflating: bg44/fg_51/overlay/20.jpg
#   inflating: bg44/fg_51/overlay/17.jpg
#   inflating: bg44/fg_51/overlay/40.jpg
#   inflating: bg44/fg_51/overlay/15.jpg
#   inflating: bg44/fg_51/overlay/14.jpg
#   inflating: bg44/fg_51/overlay/27.jpg
#   inflating: bg44/fg_51/overlay/36.jpg
#   inflating: bg44/fg_51/overlay/19.jpg
#   inflating: bg44/fg_51/overlay/21.jpg
#   inflating: bg44/fg_51/overlay/2.jpg
#   inflating: bg44/fg_51/overlay/28.jpg
#   inflating: bg44/fg_51/overlay/7.jpg
#   inflating: bg44/fg_51/overlay/13.jpg
#   inflating: bg44/fg_51/overlay/30.jpg
#   inflating: bg44/fg_51/overlay/4.jpg
#   inflating: bg44/fg_51/overlay/35.jpg
#   inflating: bg44/fg_51/overlay/22.jpg
#   inflating: bg44/fg_51/overlay/34.jpg
#   inflating: bg44/fg_51/overlay/26.jpg
#   inflating: bg44/fg_51/overlay/25.jpg
#   inflating: bg44/fg_51/overlay/18.jpg
#    creating: bg44/fg_86/depth/
#    creating: bg44/fg_86/mask/
#    creating: bg44/fg_86/overlay/
#   inflating: bg44/fg_86/depth/12.jpg
#   inflating: bg44/fg_86/depth/31.jpg
#   inflating: bg44/fg_86/depth/8.jpg
#   inflating: bg44/fg_86/depth/9.jpg
#   inflating: bg44/fg_86/depth/6.jpg
#   inflating: bg44/fg_86/depth/37.jpg
#   inflating: bg44/fg_86/depth/32.jpg
#   inflating: bg44/fg_86/depth/29.jpg
#   inflating: bg44/fg_86/depth/39.jpg
#   inflating: bg44/fg_86/depth/38.jpg
#   inflating: bg44/fg_86/depth/24.jpg
#   inflating: bg44/fg_86/depth/11.jpg
#   inflating: bg44/fg_86/depth/23.jpg
#   inflating: bg44/fg_86/depth/5.jpg
#   inflating: bg44/fg_86/depth/33.jpg
#   inflating: bg44/fg_86/depth/10.jpg
#   inflating: bg44/fg_86/depth/1.jpg
#   inflating: bg44/fg_86/depth/3.jpg
#   inflating: bg44/fg_86/depth/16.jpg
#   inflating: bg44/fg_86/depth/20.jpg
#   inflating: bg44/fg_86/depth/17.jpg
#   inflating: bg44/fg_86/depth/40.jpg
#   inflating: bg44/fg_86/depth/15.jpg
#   inflating: bg44/fg_86/depth/14.jpg
#   inflating: bg44/fg_86/depth/27.jpg
#   inflating: bg44/fg_86/depth/36.jpg
#   inflating: bg44/fg_86/depth/19.jpg
#   inflating: bg44/fg_86/depth/21.jpg
#   inflating: bg44/fg_86/depth/2.jpg
#   inflating: bg44/fg_86/depth/28.jpg
#   inflating: bg44/fg_86/depth/7.jpg
#   inflating: bg44/fg_86/depth/13.jpg
#   inflating: bg44/fg_86/depth/30.jpg
#   inflating: bg44/fg_86/depth/4.jpg
#   inflating: bg44/fg_86/depth/35.jpg
#   inflating: bg44/fg_86/depth/22.jpg
#   inflating: bg44/fg_86/depth/34.jpg
#   inflating: bg44/fg_86/depth/26.jpg
#   inflating: bg44/fg_86/depth/25.jpg
#   inflating: bg44/fg_86/depth/18.jpg
#   inflating: bg44/fg_86/mask/12.jpg
#   inflating: bg44/fg_86/mask/31.jpg
#   inflating: bg44/fg_86/mask/8.jpg
#   inflating: bg44/fg_86/mask/9.jpg
#   inflating: bg44/fg_86/mask/6.jpg
#   inflating: bg44/fg_86/mask/37.jpg
#   inflating: bg44/fg_86/mask/32.jpg
#   inflating: bg44/fg_86/mask/29.jpg
#   inflating: bg44/fg_86/mask/39.jpg
#   inflating: bg44/fg_86/mask/38.jpg
#   inflating: bg44/fg_86/mask/24.jpg
#   inflating: bg44/fg_86/mask/11.jpg
#   inflating: bg44/fg_86/mask/23.jpg
#   inflating: bg44/fg_86/mask/5.jpg
#   inflating: bg44/fg_86/mask/33.jpg
#   inflating: bg44/fg_86/mask/10.jpg
#   inflating: bg44/fg_86/mask/1.jpg
#   inflating: bg44/fg_86/mask/3.jpg
#   inflating: bg44/fg_86/mask/16.jpg
#   inflating: bg44/fg_86/mask/20.jpg
#   inflating: bg44/fg_86/mask/17.jpg
#   inflating: bg44/fg_86/mask/40.jpg
#   inflating: bg44/fg_86/mask/15.jpg
#   inflating: bg44/fg_86/mask/14.jpg
#   inflating: bg44/fg_86/mask/27.jpg
#   inflating: bg44/fg_86/mask/36.jpg
#   inflating: bg44/fg_86/mask/19.jpg
#   inflating: bg44/fg_86/mask/21.jpg
#   inflating: bg44/fg_86/mask/2.jpg
#   inflating: bg44/fg_86/mask/28.jpg
#   inflating: bg44/fg_86/mask/7.jpg
#   inflating: bg44/fg_86/mask/13.jpg
#   inflating: bg44/fg_86/mask/30.jpg
#   inflating: bg44/fg_86/mask/4.jpg
#   inflating: bg44/fg_86/mask/35.jpg
#   inflating: bg44/fg_86/mask/22.jpg
#   inflating: bg44/fg_86/mask/34.jpg
#   inflating: bg44/fg_86/mask/26.jpg
#   inflating: bg44/fg_86/mask/25.jpg
#   inflating: bg44/fg_86/mask/18.jpg
#   inflating: bg44/fg_86/overlay/12.jpg
#   inflating: bg44/fg_86/overlay/31.jpg
#   inflating: bg44/fg_86/overlay/8.jpg
#   inflating: bg44/fg_86/overlay/9.jpg
#   inflating: bg44/fg_86/overlay/6.jpg
#   inflating: bg44/fg_86/overlay/37.jpg
#   inflating: bg44/fg_86/overlay/32.jpg
#   inflating: bg44/fg_86/overlay/29.jpg
#   inflating: bg44/fg_86/overlay/39.jpg
#   inflating: bg44/fg_86/overlay/38.jpg
#   inflating: bg44/fg_86/overlay/24.jpg
#   inflating: bg44/fg_86/overlay/11.jpg
#   inflating: bg44/fg_86/overlay/23.jpg
#   inflating: bg44/fg_86/overlay/5.jpg
#   inflating: bg44/fg_86/overlay/33.jpg
#   inflating: bg44/fg_86/overlay/10.jpg
#   inflating: bg44/fg_86/overlay/1.jpg
#   inflating: bg44/fg_86/overlay/3.jpg
#   inflating: bg44/fg_86/overlay/16.jpg
#   inflating: bg44/fg_86/overlay/20.jpg
#   inflating: bg44/fg_86/overlay/17.jpg
#   inflating: bg44/fg_86/overlay/40.jpg
#   inflating: bg44/fg_86/overlay/15.jpg
#   inflating: bg44/fg_86/overlay/14.jpg
#   inflating: bg44/fg_86/overlay/27.jpg
#   inflating: bg44/fg_86/overlay/36.jpg
#   inflating: bg44/fg_86/overlay/19.jpg
#   inflating: bg44/fg_86/overlay/21.jpg
#   inflating: bg44/fg_86/overlay/2.jpg
#   inflating: bg44/fg_86/overlay/28.jpg
#   inflating: bg44/fg_86/overlay/7.jpg
#   inflating: bg44/fg_86/overlay/13.jpg
#   inflating: bg44/fg_86/overlay/30.jpg
#   inflating: bg44/fg_86/overlay/4.jpg
#   inflating: bg44/fg_86/overlay/35.jpg
#   inflating: bg44/fg_86/overlay/22.jpg
#   inflating: bg44/fg_86/overlay/34.jpg
#   inflating: bg44/fg_86/overlay/26.jpg
#   inflating: bg44/fg_86/overlay/25.jpg
#   inflating: bg44/fg_86/overlay/18.jpg

# %%
cd ../
# Out:
# /content

# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

class DenseDepthDNN2(torch.nn.Module):
    def __init__(self, dropout_value = 0.1):
        """"Constructor of the class"""
        super(DenseDepthDNN2, self).__init__()
        # Input Block
        self.dropout_value = dropout_value
        #Depthwise separate 3 input channels into 3 output channels
        #it's first block uses following code:
        #x1 = Input
        #x2 = Conv(x1)
        #x3 = Conv(x1 + x2)
        #x4 = MaxPooling(x1 + x2 + x3)
        #x5 = Conv(x4)
        #x6 = Conv(x4 + x5)
        #x7 = Conv(x4 + x5 + x6)
        #x8 = MaxPooling(x5 + x6 + x7)
        #x9 = Conv(x8)
        #x10 = Conv (x8 + x9)
        #x11 = Conv (x8 + x9 + x10)
        #x12 = GAP(x11)
        #x13 = FC(x12)
        #Uses ReLU and BN wherever applicable
        #Uses CIFAR10 as the dataset
        #Your target is 75% in less than 40 Epochs
        #self.conv1 = nn.Conv2d(3, 6, 5)  # RF= 
        #self.pool = nn.MaxPool2d(2, 2)
        #self.conv2 = nn.Conv2d(6, 16, 5)
        #self.fc1 = nn.Linear(16 * 5 * 5, 120)
        #self.fc2 = nn.Linear(120, 84)
        #self.fc3 = nn.Linear(84, 10)
        #torch.nn.Conv2d(in_channels, out_channels=k*in_channels, kernel_size, stride=1, padding=0, dilation=1, groups=1, bias=True, padding_mode='zeros')
        
        #self.conv1 = nn.Conv2d(in_channels = 3, out_channels = 32, kernel_size = 3, stride = 1, padding = 1)
        #self.conv2 = nn.Conv2d(in_channels = 32, out_channels = 32, kernel_size = 3, stride = 1, padding = 1)
        #self.conv3 = nn.Conv2d(in_channels = 64, out_channels = 32, kernel_size = 3, stride = 1, padding = 1)
        #self.conv4 = nn.Conv2d(in_channels = 96, out_channels = 32, kernel_size = 3, stride = 1, padding = 1)
        #self.conv5 = nn.Conv2d(in_channels = 128, out_channels = 32, kernel_size = 3, stride = 1, padding = 1)
        #x1 = Input 
        #x2 = Conv(x1)
        #x3 = Conv(x1 + x2)
        #x4 = MaxPooling(x1 + x2 + x3)
        #x5 = Conv(x4)
        #x6 = Conv(x4 + x5)
        #x7 = Conv(x4 + x5 + x6)
        #x8 = MaxPooling(x5 + x6 + x7)
        #x9 = Conv(x8)
        #x10 = Conv (x8 + x9)
        #x11 = Conv (x8 + x9 + x10)
        
        #x1 = Input 3 channels
        #x2 = Conv(x1)

        self.x2 = nn.Sequential( #input 64*64*64, output=64*64*64, RF=2
            nn.Conv2d(in_channels=6, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64)
            #nn.Dropout(dropout_value)
        )
        #x3 = Conv(x1 + x2) , no x1
        self.x3 = nn.Sequential(  #input 64*64*64, output=64*64*64, RF=4
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64)
            #nn.Dropout(dropout_value)
        )
        #x4 maxpool (x1+x2+x3) no x1
        self.x4 = nn.MaxPool2d(2, 2) #input 32*32*128, output=32*32*128, RF=5
        
        #x5 = Conv(x4)
        self.x5 = nn.Sequential( #input 32*32*128, output=32*32*128, RF=10
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128)
            #nn.Dropout(dropout_value)
        )
        
        #x6 = Conv(x4 + x5)
        self.x6 = nn.Sequential( #input 32*32*256, output=32*32*128, RF=12
            nn.Conv2d(in_channels=256, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128)
            #nn.Dropout(dropout_value)
        )

        #x7 = Conv(x4 + x5 + x6)
        self.x7 = nn.Sequential( #input 32*32*64, output=32*32*64, RF=14
            nn.Conv2d(in_channels=384, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128)
            #nn.Dropout(dropout_value)
        )
        #x8 = MaxPooling(x5 + x6 + x7)
        self.x8 = nn.MaxPool2d(2, 2) #input 32*32*384, output_size = (16*16*384), RF=15
        
        #x9 = Conv(x8)
        self.x9 = nn.Sequential( #input 16*16*384, output_size = (16*16*256), RF=30
            nn.Conv2d(in_channels=384, out_channels=256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(256)
            #nn.Dropout(dropout_value)
        )
        #x10 = Conv (x8 + x9)
        self.x10 = nn.Sequential( #input 16*16*640, output_size = (16*16*256), RF=32
            nn.Conv2d(in_channels=640, out_channels=256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(256)
            #nn.Dropout(dropout_value)
        )
        #x11 = Conv (x8 + x9 + x10)
        self.x11 = nn.Sequential( #input 16*16*896, output_size = (16*16*256), RF=34
            nn.Conv2d(in_channels=896, out_channels=256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(256)
            #nn.Dropout(dropout_value)
        )

        #x12 = Conv (x9 + x10 + x11)
        self.x12 = nn.MaxPool2d(2, 2) #input 16*16*384, output_size = (8*8*768), RF=35
        
        #x13 = Conv(x12)
        self.x13 = nn.Sequential( #input 8*8*768, output_size = (8*8*512), RF=70
            nn.Conv2d(in_channels=768, out_channels=512, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(512)
            #nn.Dropout(dropout_value)
        )

        #x14 = Conv(x12 + x13)
        self.x14 = nn.Sequential( #input 8*8*1280, output_size = (8*8*512), RF=72
            nn.Conv2d(in_channels=1280, out_channels=512, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(512)
            #nn.Dropout(dropout_value)
        )

        
        #x15 = Conv(x12 + x13 + x14)
        self.x15 = nn.Sequential( #input 8*8*1792, output_size = (8*8*512), RF=74
            nn.Conv2d(in_channels=1792, out_channels=512, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(512)
            #nn.Dropout(dropout_value)
        )


        """
        # OUTPUT BLOCK -> Add GAP Layer
        self.x12_gap = nn.Sequential( # input 8*8*64, output_size = (1*1*64), Receptive FieldF=42
            nn.AvgPool2d(kernel_size=8)
        )

        self.x13_fc = nn.Sequential(
            nn.Linear(in_features=64, out_features=10)
            # nn.BatchNorm2d(10),
            # nn.ReLU(),
            # nn.Dropout(dropout_value)
        )
        """
        
        #Remove gap layer and add additional conv layers
        
        self.x11_invconv_512_256 = nn.Sequential( #input 16*16*512, output_size = (16*16*256), RF=42
            nn.Conv2d(in_channels=512, out_channels=256, kernel_size=1,padding=0),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            #nn.Dropout(dropout_value)
        )
        self.x11_inconv_256 = nn.Sequential( #input 8*8*64, output_size = (16*16*64), RF=42
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3,padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            #nn.Dropout(dropout_value)
        )
        
        self.x11_invconv_256_128 = nn.Sequential( #input 32*32*256, output_size = (32*32*128), RF=42
            nn.Conv2d(in_channels=256, out_channels=128, kernel_size=1,padding=0),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            #nn.Dropout(dropout_value)
        )

        self.x11_inconv_128 = nn.Sequential( #input 32*32*128, output_size = (32*32*128), RF=42
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3,padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            #nn.Dropout(dropout_value)
        )
        
        self.x11_invconv_128_64 = nn.Sequential( #input 32*32*128, output_size = (32*32*64), RF=42
            nn.Conv2d(in_channels=128, out_channels=64, kernel_size=1,padding=0),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            #nn.Dropout(dropout_value)
        )

        self.x11_inconv_64 = nn.Sequential( #input 64*64*64, output_size = (64*64*64), RF=42
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3,padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            #nn.Dropout(dropout_value)
        )

        self.x11_inconv_32 = nn.Sequential( #input 64*64*64, output_size = (64*64*32), RF=42
            nn.Conv2d(in_channels=64, out_channels=32, kernel_size=3,padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            #nn.Dropout(dropout_value)
        )

        #one for depth and one for mask
        self.x12_conv_1_1 = nn.Sequential( #input 64*64*32, output_size = (64*64*3), RF=42
            nn.Conv2d(in_channels=32, out_channels=1, kernel_size=1)
            #nn.Dropout(dropout_value)
        )
        #self.x13_final = nn.Sequential( #input 8*8*64, output_size = (8*8*64), RF=42
        #    nn.Conv2d(in_channels=3, out_channels=1, kernel_size=3, padding=1)
        #)

        #self.predict_mask4 = nn.Conv2d(512, 1, kernel_size=3, padding=1)
        #self.predict_mask3 = nn.Conv2d(256, 1, kernel_size=3, padding=1)
        #self.predict_mask2 = nn.Conv2d(128, 1, kernel_size=3, padding=1)
        self.predict_mask1 = nn.Conv2d(32, 1, kernel_size=3, padding=1)


    
    def forward(self, x1):
        #x1 = Input 
        #x2 = Conv(x1)
        #x3 = Conv(x1 + x2)
        #x4 = MaxPooling(x1 + x2 + x3)
        #x5 = Conv(x4)
        #x6 = Conv(x4 + x5)
        #x7 = Conv(x4 + x5 + x6)
        #x8 = MaxPooling(x5 + x6 + x7)
        #x9 = Conv(x8)
        #x10 = Conv (x8 + x9)
        #x11 = Conv (x8 + x9 + x10)
        
        #added layers
        #x12 = maxpool(x9 + x10 + x11)
        #x13 = Conv(x12)
        #x14 = Conv(x12 + x13)
        #x15 = Conv(x12 + x13 + x14)

        x2 = self.x2(x1) #                          
        #print('x2=',len(x2))
        #x1_x2 = torch.cat((x1, x2))
        #x1_x2 = torch.add((x1, x2))
        x3 = self.x3(x2)                            #RF2
        #x1_x2_x3 = torch.cat((x2, x3),dim=1) 
        #x1_x2_x3 = x2.add(x3)                       #concatnation
        x4 = self.x4(torch.cat([x2,x3],dim=1))                      #RF3
        x5 = self.x5(x4)                            #RF6
        #print('x5=',len(x5))
        #x4_x5 = torch.cat((x4, x5),dim=1)
        #x4_x5 = x4.add(x5)
        x6 = self.x6(torch.cat([x4,x5],dim=1))  #RF8
        #interpolate
        #x4=torch.nn.functional.interpolate(x4, size=(64,64))                         
        #x5=torch.nn.functional.interpolate(x5, size=(64,64))                        
        #x6=torch.nn.functional.interpolate(x6, size=(64,64))                        
        #print('x6=',len(x6))
        #x5_x6 = torch.cat((x5, x6),dim=1)
        #x5_x6 = x5.add(x6)
        #x4_x5_x6 = torch.cat((x4, x5_x6),dim=1)
        #x4_x5_x6 = x4.add(x5_x6)
        x7 = self.x7(torch.cat([x4,x5,x6],dim=1)) #RF10
        #x5_x6_x7 = torch.cat((x5_x6, x7),dim=1)
        #x5_x6_x7 = x5_x6.add(x7)
        x8 = self.x8(torch.cat([x5,x6,x7],dim=1)) #RF11
        x9 = self.x9(x8) #RF22
        #interpolate 
        #x8=torch.nn.functional.interpolate(x8, size=(64,64))                        
        #x9=torch.nn.functional.interpolate(x9, size=(64,64))                        
        #print('x9=',len(x9))
        #x8_x9 = torch.cat((x8, x9),dim=1)
        #x8_x9 = x8.add(x9)
        x10 = self.x10(torch.cat([x8,x9],dim=1)) #RF24
        
        #print('x10=',len(x10))
        #x8_x9_x10 = torch.cat((x8_x9, x10),dim=1)
        #x8_x9_x10 = x8_x9.add(x10)
        x11 = self.x11(torch.cat([x8,x9,x10],dim=1)) #RF26

        #added layers ->8*8
        x12 = self.x12(torch.cat([x9,x10,x11],dim=1))#512 
        x13 = self.x13(x12)
        x14 = self.x14(torch.cat([x12,x13],dim=1))
        x15 = self.x15(torch.cat([x12,x13,x14],dim=1)) # 512 channels

        #print('x11=',len(x11))
        #----->x12 = self.x12_gap(x11)
        #Now interpolate x15
        xf1=torch.nn.functional.interpolate(x15, size=(8,8),mode = 'bilinear')#512
        x11_invconv_512_256 = self.x11_invconv_512_256(xf1) #RF28, 256 channels

        #print(x11_invconv_512_256.shape,x11.shape)
        x11_inconv_256 = self.x11_inconv_256(x11_invconv_512_256.add(x11)) #256 channels

        xf2=torch.nn.functional.interpolate(x11_inconv_256, size=(16,16),mode = 'bilinear')#256 channels
        x11_invconv_256_128 = self.x11_invconv_256_128(xf2) #RF28, 128 channels
        x11_inconv_128 = self.x11_inconv_128(x11_invconv_256_128.add(x7)) #RF34

        xf3=torch.nn.functional.interpolate(x11_inconv_128, size=(32,32),mode = 'bilinear')#128 channels
        x11_invconv_128_64 = self.x11_invconv_128_64(xf3) #RF28, 64 channels
        x11_inconv_64 = self.x11_inconv_64(x11_invconv_128_64.add(x3)) #RF36

        x11_inconv_32 = self.x11_inconv_32(x11_inconv_64) #RF38
        
        #{{finished upscaling}}
        x12_conv_1_1 = self.x12_conv_1_1(x11_inconv_32)
        #print('x12=',len(x12))
        #----->x12 = x12.view(-1, 64)
        #---->x13 = self.x13_fc(x12)

        #print('x13=',len(x13))
        #x13 = x13.view(-1, 10)
        #print('x13=',len(x13))
        #---->x14 = x13.view(-1, 10)
        #-->return F.log_softmax(x13, dim=-1)
        #x13_final = self.x13_final(x12_conv_1_1) #RF36
        predict_mask1 = torch.nn.functional.sigmoid(self.predict_mask1(x11_inconv_32))
        out_array = []
        out_array.append(x12_conv_1_1)
        out_array.append(predict_mask1)
        #return x12_conv_1_1 , predict_mask1
        return out_array

# %%
from torchsummary import summary
#modal = DisparityDepthnet().cuda() 
modal = DenseDepthDNN2().cuda()
summary(modal, (6,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           3,520
#               ReLU-2           [-1, 64, 32, 32]               0
#        BatchNorm2d-3           [-1, 64, 32, 32]             128
#             Conv2d-4           [-1, 64, 32, 32]          36,928
#               ReLU-5           [-1, 64, 32, 32]               0
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#          MaxPool2d-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,584
#               ReLU-9          [-1, 128, 16, 16]               0
#       BatchNorm2d-10          [-1, 128, 16, 16]             256
#            Conv2d-11          [-1, 128, 16, 16]         295,040
#              ReLU-12          [-1, 128, 16, 16]               0
#       BatchNorm2d-13          [-1, 128, 16, 16]             256
#            Conv2d-14          [-1, 128, 16, 16]         442,496
#              ReLU-15          [-1, 128, 16, 16]               0
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#         MaxPool2d-17            [-1, 384, 8, 8]               0
#            Conv2d-18            [-1, 256, 8, 8]         884,992
#              ReLU-19            [-1, 256, 8, 8]               0
#       BatchNorm2d-20            [-1, 256, 8, 8]             512
#            Conv2d-21            [-1, 256, 8, 8]       1,474,816
#              ReLU-22            [-1, 256, 8, 8]               0
#       BatchNorm2d-23            [-1, 256, 8, 8]             512
#            Conv2d-24            [-1, 256, 8, 8]       2,064,640
#              ReLU-25            [-1, 256, 8, 8]               0
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#         MaxPool2d-27            [-1, 768, 4, 4]               0
#            Conv2d-28            [-1, 512, 4, 4]       3,539,456
#              ReLU-29            [-1, 512, 4, 4]               0
#       BatchNorm2d-30            [-1, 512, 4, 4]           1,024
#            Conv2d-31            [-1, 512, 4, 4]       5,898,752
#              ReLU-32            [-1, 512, 4, 4]               0
#       BatchNorm2d-33            [-1, 512, 4, 4]           1,024
#            Conv2d-34            [-1, 512, 4, 4]       8,258,048
#              ReLU-35            [-1, 512, 4, 4]               0
#       BatchNorm2d-36            [-1, 512, 4, 4]           1,024
#            Conv2d-37            [-1, 256, 8, 8]         131,328
#       BatchNorm2d-38            [-1, 256, 8, 8]             512
#              ReLU-39            [-1, 256, 8, 8]               0
#            Conv2d-40            [-1, 256, 8, 8]         590,080
#       BatchNorm2d-41            [-1, 256, 8, 8]             512
#              ReLU-42            [-1, 256, 8, 8]               0
#            Conv2d-43          [-1, 128, 16, 16]          32,896
#       BatchNorm2d-44          [-1, 128, 16, 16]             256
#              ReLU-45          [-1, 128, 16, 16]               0
#            Conv2d-46          [-1, 128, 16, 16]         147,584
#       BatchNorm2d-47          [-1, 128, 16, 16]             256
#              ReLU-48          [-1, 128, 16, 16]               0
#            Conv2d-49           [-1, 64, 32, 32]           8,256
#       BatchNorm2d-50           [-1, 64, 32, 32]             128
#              ReLU-51           [-1, 64, 32, 32]               0
#            Conv2d-52           [-1, 64, 32, 32]          36,928
#       BatchNorm2d-53           [-1, 64, 32, 32]             128
#              ReLU-54           [-1, 64, 32, 32]               0
#            Conv2d-55           [-1, 32, 32, 32]          18,464
#       BatchNorm2d-56           [-1, 32, 32, 32]              64
#              ReLU-57           [-1, 32, 32, 32]               0
#            Conv2d-58            [-1, 1, 32, 32]              33
#            Conv2d-59            [-1, 1, 32, 32]             289
# ================================================================
# Total params: 24,019,618
# Trainable params: 24,019,618
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 13.48
# Params size (MB): 91.63
# Estimated Total Size (MB): 105.14
# ----------------------------------------------------------------
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2973: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1569: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %%
#import custom_transforms
# Data loading code
import torch
import  torchvision.transforms
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

normalize = transforms.Normalize(mean=[149.17579724, 143.51813416, 136.34473418],
                                        std=[10.918, 10.54722837, 9.7497292])
#train_transform = custom_transforms.Compose([
#    custom_transforms.RandomHorizontalFlip(),
#    custom_transforms.RandomScaleCrop(),
#    custom_transforms.ArrayToTensor(),
#    normalize
#])

train_transform = transforms.Compose([
        transforms.ToTensor()]) 

valid_transform = transforms.Compose([transforms.ToTensor()])
#args.data = "/content/gdrive/My Drive/eva-04/S15A/Dataset_224"
#print("=> fetching scenes in '{}'".format(args.data))

train_set = BackgroundSubtraction_Dataset_Test('/content/Dataset_224/', size = 300000, transform = train_transform)
test_set = BackgroundSubtraction_Dataset_Test('/content/Dataset_224/', size = 100000, test=False, transform = valid_transform)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=1024,
                                          shuffle=False, num_workers=3,pin_memory=False)
val_loader = torch.utils.data.DataLoader(test_set, batch_size=1,
                                         shuffle=False, num_workers=1,pin_memory=False)

# %%
# !pwd
# Out:
# /content

# %%
pip install pytorch-msssim
# Out:
# Collecting pytorch-msssim
#   Downloading https://files.pythonhosted.org/packages/5e/25/2689713351e3fb76fc73ffa936f35c051071826fdec8922614629c3b3926/pytorch_msssim-0.2.0-py3-none-any.whl
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from pytorch-msssim) (1.5.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->pytorch-msssim) (1.18.4)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->pytorch-msssim) (0.16.0)
# Installing collected packages: pytorch-msssim
# Successfully installed pytorch-msssim-0.2.0

# %%
pip install kmeans-pytorch
# Out:
# Collecting kmeans-pytorch
#   Downloading https://files.pythonhosted.org/packages/b5/c9/eb5b82e7e9741e61acf1aff70530a08810aa0c7e2272c534ff7a150fc5bd/kmeans_pytorch-0.3-py3-none-any.whl
# Installing collected packages: kmeans-pytorch
# Successfully installed kmeans-pytorch-0.3

# %%
from kmeans_pytorch import kmeans
# data
#data_size, dims, num_clusters = 1000, 2, 3
#x = np.random.randn(data_size, dims) / 6
#x = torch.from_numpy(x)

# kmeans
#cluster_ids_x, cluster_centers = kmeans(
#    X=x, num_clusters=num_clusters, distance='euclidean', device=torch.device('cuda:0')
#)

def gradient_loss(gen_frames, gt_frames, alpha=1):

    def gradient(x):
        # idea from tf.image.image_gradients(image)
        # https://github.com/tensorflow/tensorflow/blob/r2.1/tensorflow/python/ops/image_ops_impl.py#L3441-L3512
        # x: (b,c,h,w), float32 or float64
        # dx, dy: (b,c,h,w)

        h_x = x.size()[-2]
        w_x = x.size()[-1]
        # gradient step=1
        left = x
        right = F.pad(x, [0, 1, 0, 0])[:, :, :, 1:]
        top = x
        bottom = F.pad(x, [0, 0, 0, 1])[:, :, 1:, :]

        # dx, dy = torch.abs(right - left), torch.abs(bottom - top)
        dx, dy = right - left, bottom - top 
        # dx will always have zeros in the last column, right-left
        # dy will always have zeros in the last row,    bottom-top
        dx[:, :, :, -1] = 0
        dy[:, :, -1, :] = 0

        return dx, dy

    # gradient
    gen_dx, gen_dy = gradient(gen_frames)
    gt_dx, gt_dy = gradient(gt_frames)
    #
    grad_diff_x = torch.abs(gt_dx - gen_dx)
    grad_diff_y = torch.abs(gt_dy - gen_dy)

    # condense into one tensor and avg
    return torch.mean(grad_diff_x ** alpha + grad_diff_y ** alpha)

#with sobel filters
def gradient_loss_function_using_sobel(x):
  a = torch.Tensor([[1, 0, -1],
  [2, 0, -2],
  [1, 0, -1]])

  a = a.view((1,1,3,3))
  G_x = F.conv2d(x, a)

  b = torch.Tensor([[1, 2, 1],
  [0, 0, 0],
  [-1, -2, -1]])

  b = b.view((1,1,3,3))
  G_y = F.conv2d(x, b)

  G = torch.sqrt(torch.pow(G_x,2)+ torch.pow(G_y,2))
  return G

def gradient(x):
      # idea from tf.image.image_gradients(image)
      # https://github.com/tensorflow/tensorflow/blob/r2.1/tensorflow/python/ops/image_ops_impl.py#L3441-L3512
      # x: (b,c,h,w), float32 or float64
      # dx, dy: (b,c,h,w)

      h_x = x.size()[-2]
      w_x = x.size()[-1]
      # gradient step=1
      left = x
      right = F.pad(x, [0, 1, 0, 0])[:, :, :, 1:]
      top = x
      bottom = F.pad(x, [0, 0, 0, 1])[:, :, 1:, :]

      # dx, dy = torch.abs(right - left), torch.abs(bottom - top)
      dx, dy = right - left, bottom - top 
      # dx will always have zeros in the last column, right-left
      # dy will always have zeros in the last row,    bottom-top
      dx[:, :, :, -1] = 0
      dy[:, :, -1, :] = 0

      return dx, dy
from pytorch_msssim import MS_SSIM, ms_ssim, SSIM, ssim
from kmeans_pytorch import kmeans, kmeans_predict

def depth_loss_function(y_true, y_pred, theta=0.1, maxDepthVal=1000.0/10.0):
    
    #Point-wise depth
    data_size, dims, num_clusters = 1024, 2, 6
    
    #l_depth = K.mean(K.abs(y_pred - y_true), axis=-1)

    ldepth_ids_x, cluster_centers = kmeans(X=torch.abs(y_pred - y_true), num_clusters=6, distance='euclidean', device=torch.device('cuda:0'))


    # Edges
    #dy_true, dx_true = tf.image.image_gradients(y_true)
    dx_true,dy_true = gradient(y_true)
    #dy_pred, dx_pred = tf.image.image_gradients(y_pred)
    dx_pred,dy_pred = gradient(y_pred)

    #l_edges = kmeans(K.abs(dy_pred - dy_true) + K.abs(dx_pred - dx_true), axis=-1)
    l_edges_y, cluster_centers_y = kmeans(Y=(torch.abs(dy_pred - dy_true) + torch.abs(dx_pred - dx_true)),num_clusters=6)

    # Structural similarity (SSIM) index
    l_ssim = torch.clamp((1 - ssim(y_true, y_pred, maxDepthVal)) * 0.5, 0, 1)

    # Weights
    w1 = 1.0
    w2 = 1.0
    w3 = theta

    ldepth = kmeans_predict(ldepth_ids_x,cluster_centers)
    ledges = kmeans_predict(l_edges_y,cluster_centers_y)

    #return (w1 * l_ssim) + (w2 * kmean(l_edges)) + (w3 * K.mean(l_depth))
    return (w1 * l_ssim) + (w2 * l_edges) + (w3 * l_depth)

# %% [markdown]
# #Train the Modal

# %%
#import models
import importlib
#importlib.reload(models)
#from tensorboardX import SummaryWriter
#tb_writer = SummaryWriter("runs/experiment_1")
from tqdm import tqdm
#import pytorch_ssim
from pytorch_msssim import MS_SSIM, ms_ssim, SSIM, ssim
#print(pytorch_ssim.ssim(img1, img2))
#from pytorch_msssim import ssim
epoch_size = 1
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

#depth_net = DisparityDepthnet() 
#depth_net.cuda()   

#cudnn.benchmark = True
#depth_net = torch.nn.DataParallel(depth_net)

optim_params = [{'params': modal.parameters(), 'lr': 2e-4}]

#optimizer = torch.optim.Adam(optim_params, lr = 1e-4,weight_decay=0)
optimizer = torch.optim.SGD(optim_params, lr=2e-4, momentum=0.9, weight_decay=1e-4)
#scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer, 1e-4, 0.1, step_size_up=1000, step_size_down=None, mode='triangular', gamma=1.0, scale_fn=None, scale_mode='cycle', cycle_momentum=True, base_momentum=0.8, max_momentum=0.9, last_epoch=-1)

#optimizer.cuda()
#optimizer = tf.train.AdamOptimizer(learning_rate).minimize(-1 * loss_rec)
import logging
logging.basicConfig(filename = "/content/dense32_mask_loss.log",datefmt='%H:%M:%S',level=logging.DEBUG)

epochs = 1
modal.train()
#w = torch.load("/content/latest_model_dense_mse.pth")    
#modal.load_state_dict(w)
import torch     
for epoch in range(epochs):
    correct = 0
    processed = 0
    pbar = tqdm(train_loader)
    preds = np.zeros((1024, 1,300,64), dtype=np.float32)
    labels = np.zeros((1024,1,300,64),dtype=np.float32)
    
    for batch_idx, input_array in enumerate(train_loader):
        optimizer.zero_grad()
        
        bg = input_array[0].to(device)
        fgbg = input_array[1].to(device)
        concat = torch.cat([bg,fgbg],dim=1)
        depth_img = input_array[2].to(device)
        mask_img = input_array[3].to(device)
        #print(bg.shape,fgbg.shape,depth_img.shape,mask_img.shape)

        # compute output
        out_array = modal(concat)#input to depth modal
        #weight_matrix = bg.sub(fgbg)
        #criteria = torch.nn.CrossEntropyLoss(weight=weight_matrix, size_average=None, ignore_index=-100, reduce=None, reduction='mean')
        #criteria = torch.nn.BCELoss(weight=None, size_average=None, reduce=None, reduction='mean')
        depth_pred = torch.nn.functional.interpolate(out_array[0], size=(64, 64), mode='bilinear', align_corners=False)
        mask_pred = torch.nn.functional.interpolate(out_array[1], size=(64, 64), mode='bilinear', align_corners=False)
        
        criteria = torch.nn.MSELoss()
        criteria1 = torch.nn.L1Loss()
        #depth_pred = torch.nn.functional.interpolate(depth_pred, size=(64, 64), mode='bilinear', align_corners=False)
        lossd1 = criteria(depth_pred,depth_img)
        lossd2 = criteria1(depth_pred,depth_img)
        ssim_loss = 1 - ssim(depth_img,depth_pred) 
        grad_loss = gradient_loss(depth_pred,depth_img)

        #loss1 = 0.3 * lossd2 + 0. * grad_loss
        
        #criteria = depth_loss_function()
        #loss1 = depth_loss_function(depth_img,depth_pred)
        #criteria = torch.nn.MSELoss()
        #loss1 = criteria(depth_pred,depth_img)
        loss2 = criteria(mask_pred,mask_img)

        loss = lossd1 + 0.5 * lossd2 + 0.3 * grad_loss + ssim_loss + loss2

        #print(depth_pred.shape,depth_img.shape)
        #print("L:",label.shape,pred.shape)
        # center crop to output size
        #label = label[7:label.shape[0]-7, 29:label.shape[1]-29]
        idx = batch_idx
        # store the label and the corresponding prediction
        #print(label.shape,pred.shape)
        # load label
        #label = np.load(label_path)
        # calculating errors
        if batch_idx < 290:
          pred = depth_pred.cpu().detach().numpy()[:,:,:,-1]
          label = depth_img.cpu().detach().numpy()[:,:,:,-1]
      
          labels[:, :, idx] = label
          preds[:, :, idx] = pred[0, :, :]
          rel_error = np.mean(np.abs(preds - labels)/labels)
          #print('\nMean Absolute Relative Error: {:.6f}'.format(rel_error))        
          rmse = np.sqrt(np.mean((preds - labels)**2))
          #print('Root Mean Squared Error: {:.6f}'.format(rmse))

          log10 = np.mean(np.abs(np.log10(preds) - np.log10(labels)))
          #print('Mean Log10 Error: {:.6f}'.format(log10))

          acc = np.maximum(preds/labels, labels/preds)
          delta1 = np.mean(acc < 1.25)
          #print('Delta1: {:.6f}'.format(delta1))

          delta2 = np.mean(acc < 1.25**2)
          #print('Delta2: {:.6f}'.format(delta2))

          delta3 = np.mean(acc < 1.25**3)
        
        loss.backward()
        optimizer.step()

        if batch_idx % 100 ==0:
          torch.save(modal.state_dict(), 'dense32_depth_mask.pth')

        desc = f'Loss={loss.item()} Epoch={epoch} Batch_id={batch_idx}  MAE={rel_error:0.6f}RMSE={rmse:0.6f} Meanlog10={log10:0.6f} Acc_D1={delta1:0.6f} Acc_D2={delta2:0.6f} Acc_D3={delta3:0.6f}'
        #desc=f'Loss={loss.item()} Epoch={epoch} Batch_id={batch_idx}'
        logging.info(desc)
        #pbar.set_description(desc=f'Loss={loss.item()} Epoch={epoch} Batch_id={batch_idx}  MAE={rel_error:0.6f}RMSE={rmse:0.6f} Meanlog10={log10:0.6f} Acc_D1={delta1:0.6f} Acc_D2={delta2:0.6f} Acc_D3={delta3:0.6f}' )
        pbar.set_description(desc)
    # =====  Save Latest Model  =====
    #print("epoch=",epoch)
    
    #from google.colab import files
    #files.download('/content/bce_loss.log')
    #files.download('/content/latest_model_mce.pth')
# Out:
#   0%|          | 0/293 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2973: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1569: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:95: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:100: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:100: RuntimeWarning: invalid value encountered in subtract
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:103: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:104: RuntimeWarning: invalid value encountered in less
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in less
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:110: RuntimeWarning: invalid value encountered in less
#
#
#
#
#
#
#
#
#
# Loss=0.12575316429138184 Epoch=0 Batch_id=0  MAE=nanRMSE=0.015724 Meanlog10=nan Acc_D1=0.000780 Acc_D2=0.001590 Acc_D3=0.002293:   0%|          | 0/293 [00:08<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12293389439582825 Epoch=0 Batch_id=1  MAE=nanRMSE=0.022044 Meanlog10=nan Acc_D1=0.001593 Acc_D2=0.003254 Acc_D3=0.004654:   0%|          | 0/293 [00:10<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11904105544090271 Epoch=0 Batch_id=2  MAE=nanRMSE=0.026582 Meanlog10=nan Acc_D1=0.002440 Acc_D2=0.004905 Acc_D3=0.007191:   0%|          | 0/293 [00:13<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12240290641784668 Epoch=0 Batch_id=3  MAE=nanRMSE=0.030186 Meanlog10=nan Acc_D1=0.003216 Acc_D2=0.006628 Acc_D3=0.009887:   0%|          | 0/293 [00:15<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1439594328403473 Epoch=0 Batch_id=4  MAE=nanRMSE=0.031726 Meanlog10=nan Acc_D1=0.004076 Acc_D2=0.008839 Acc_D3=0.012852:   0%|          | 0/293 [00:18<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14110347628593445 Epoch=0 Batch_id=5  MAE=nanRMSE=0.033062 Meanlog10=nan Acc_D1=0.004982 Acc_D2=0.011160 Acc_D3=0.015836:   0%|          | 0/293 [00:21<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13672704994678497 Epoch=0 Batch_id=6  MAE=nanRMSE=0.034251 Meanlog10=nan Acc_D1=0.006058 Acc_D2=0.013429 Acc_D3=0.018712:   0%|          | 0/293 [00:23<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1359073519706726 Epoch=0 Batch_id=7  MAE=nanRMSE=0.035579 Meanlog10=nan Acc_D1=0.006919 Acc_D2=0.015636 Acc_D3=0.021695:   0%|          | 0/293 [00:26<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1507319211959839 Epoch=0 Batch_id=8  MAE=nanRMSE=0.037671 Meanlog10=nan Acc_D1=0.007270 Acc_D2=0.017100 Acc_D3=0.024751:   0%|          | 0/293 [00:28<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14456795156002045 Epoch=0 Batch_id=9  MAE=nanRMSE=0.039941 Meanlog10=nan Acc_D1=0.007680 Acc_D2=0.018393 Acc_D3=0.027437:   0%|          | 0/293 [00:31<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14226646721363068 Epoch=0 Batch_id=10  MAE=nanRMSE=0.041649 Meanlog10=nan Acc_D1=0.007973 Acc_D2=0.019902 Acc_D3=0.030491:   0%|          | 0/293 [00:33<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1323051005601883 Epoch=0 Batch_id=11  MAE=nanRMSE=0.044709 Meanlog10=nan Acc_D1=0.008311 Acc_D2=0.020878 Acc_D3=0.033077:   0%|          | 0/293 [00:35<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14775203168392181 Epoch=0 Batch_id=12  MAE=nanRMSE=0.047551 Meanlog10=nan Acc_D1=0.008807 Acc_D2=0.022302 Acc_D3=0.035853:   0%|          | 0/293 [00:38<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.143260657787323 Epoch=0 Batch_id=13  MAE=nanRMSE=0.050281 Meanlog10=nan Acc_D1=0.009320 Acc_D2=0.023912 Acc_D3=0.038549:   0%|          | 0/293 [00:40<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14119213819503784 Epoch=0 Batch_id=14  MAE=nanRMSE=0.053169 Meanlog10=nan Acc_D1=0.009761 Acc_D2=0.025139 Acc_D3=0.041124:   0%|          | 0/293 [00:43<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13904711604118347 Epoch=0 Batch_id=15  MAE=nanRMSE=0.054895 Meanlog10=nan Acc_D1=0.010812 Acc_D2=0.027124 Acc_D3=0.044016:   0%|          | 0/293 [00:45<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15362679958343506 Epoch=0 Batch_id=16  MAE=nanRMSE=0.055265 Meanlog10=nan Acc_D1=0.012532 Acc_D2=0.029997 Acc_D3=0.047221:   0%|          | 0/293 [00:47<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14408482611179352 Epoch=0 Batch_id=17  MAE=nanRMSE=0.055558 Meanlog10=nan Acc_D1=0.014397 Acc_D2=0.033056 Acc_D3=0.050492:   0%|          | 0/293 [00:50<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1447736918926239 Epoch=0 Batch_id=18  MAE=nanRMSE=0.055804 Meanlog10=nan Acc_D1=0.016673 Acc_D2=0.036053 Acc_D3=0.053760:   0%|          | 0/293 [00:52<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1410711407661438 Epoch=0 Batch_id=19  MAE=nanRMSE=0.057106 Meanlog10=nan Acc_D1=0.018071 Acc_D2=0.038269 Acc_D3=0.056655:   0%|          | 0/293 [00:54<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13595718145370483 Epoch=0 Batch_id=20  MAE=nanRMSE=0.058897 Meanlog10=nan Acc_D1=0.018857 Acc_D2=0.040128 Acc_D3=0.059581:   0%|          | 0/293 [00:57<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13019715249538422 Epoch=0 Batch_id=21  MAE=nanRMSE=0.060686 Meanlog10=nan Acc_D1=0.019682 Acc_D2=0.041882 Acc_D3=0.062526:   0%|          | 0/293 [00:59<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12930825352668762 Epoch=0 Batch_id=22  MAE=nanRMSE=0.062181 Meanlog10=nan Acc_D1=0.020580 Acc_D2=0.043890 Acc_D3=0.065562:   0%|          | 0/293 [01:01<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13781826198101044 Epoch=0 Batch_id=23  MAE=nanRMSE=0.063249 Meanlog10=nan Acc_D1=0.021546 Acc_D2=0.045855 Acc_D3=0.068210:   0%|          | 0/293 [01:04<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15319186449050903 Epoch=0 Batch_id=24  MAE=nanRMSE=0.064044 Meanlog10=nan Acc_D1=0.022441 Acc_D2=0.047747 Acc_D3=0.070353:   0%|          | 0/293 [01:06<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1400318294763565 Epoch=0 Batch_id=25  MAE=nanRMSE=0.064880 Meanlog10=nan Acc_D1=0.023329 Acc_D2=0.049593 Acc_D3=0.072506:   0%|          | 0/293 [01:09<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14055538177490234 Epoch=0 Batch_id=26  MAE=nanRMSE=0.065650 Meanlog10=nan Acc_D1=0.024274 Acc_D2=0.051534 Acc_D3=0.074713:   0%|          | 0/293 [01:11<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1268618255853653 Epoch=0 Batch_id=27  MAE=nanRMSE=0.066429 Meanlog10=nan Acc_D1=0.025089 Acc_D2=0.053471 Acc_D3=0.076896:   0%|          | 0/293 [01:14<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12817631661891937 Epoch=0 Batch_id=28  MAE=nanRMSE=0.066977 Meanlog10=nan Acc_D1=0.026168 Acc_D2=0.055349 Acc_D3=0.079082:   0%|          | 0/293 [01:16<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.10984520614147186 Epoch=0 Batch_id=29  MAE=nanRMSE=0.067528 Meanlog10=nan Acc_D1=0.027163 Acc_D2=0.057218 Acc_D3=0.081260:   0%|          | 0/293 [01:18<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.109975665807724 Epoch=0 Batch_id=30  MAE=nanRMSE=0.067996 Meanlog10=nan Acc_D1=0.028239 Acc_D2=0.059134 Acc_D3=0.083539:   0%|          | 0/293 [01:21<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15700577199459076 Epoch=0 Batch_id=31  MAE=nanRMSE=0.069990 Meanlog10=nan Acc_D1=0.028961 Acc_D2=0.060558 Acc_D3=0.085563:   0%|          | 0/293 [01:23<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.17404642701148987 Epoch=0 Batch_id=32  MAE=nanRMSE=0.070888 Meanlog10=nan Acc_D1=0.029965 Acc_D2=0.063148 Acc_D3=0.088862:   0%|          | 0/293 [01:26<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.17234191298484802 Epoch=0 Batch_id=33  MAE=nanRMSE=0.072233 Meanlog10=nan Acc_D1=0.030607 Acc_D2=0.065284 Acc_D3=0.091780:   0%|          | 0/293 [01:28<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1757989525794983 Epoch=0 Batch_id=34  MAE=nanRMSE=0.073105 Meanlog10=nan Acc_D1=0.031557 Acc_D2=0.067922 Acc_D3=0.095097:   0%|          | 0/293 [01:30<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13144074380397797 Epoch=0 Batch_id=35  MAE=nanRMSE=0.074273 Meanlog10=nan Acc_D1=0.032749 Acc_D2=0.070043 Acc_D3=0.097860:   0%|          | 0/293 [01:33<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12877702713012695 Epoch=0 Batch_id=36  MAE=nanRMSE=0.074876 Meanlog10=nan Acc_D1=0.034309 Acc_D2=0.072566 Acc_D3=0.100914:   0%|          | 0/293 [01:35<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12185811996459961 Epoch=0 Batch_id=37  MAE=nanRMSE=0.075466 Meanlog10=nan Acc_D1=0.035769 Acc_D2=0.075190 Acc_D3=0.104068:   0%|          | 0/293 [01:38<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12208375334739685 Epoch=0 Batch_id=38  MAE=nanRMSE=0.076011 Meanlog10=nan Acc_D1=0.037312 Acc_D2=0.077899 Acc_D3=0.107271:   0%|          | 0/293 [01:40<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1917886883020401 Epoch=0 Batch_id=39  MAE=nanRMSE=0.080061 Meanlog10=nan Acc_D1=0.037439 Acc_D2=0.078258 Acc_D3=0.108104:   0%|          | 0/293 [01:43<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1984105408191681 Epoch=0 Batch_id=40  MAE=nanRMSE=0.081549 Meanlog10=nan Acc_D1=0.038312 Acc_D2=0.079365 Acc_D3=0.109330:   0%|          | 0/293 [01:45<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.18686097860336304 Epoch=0 Batch_id=41  MAE=nanRMSE=0.083082 Meanlog10=nan Acc_D1=0.039171 Acc_D2=0.080457 Acc_D3=0.110551:   0%|          | 0/293 [01:47<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1811864823102951 Epoch=0 Batch_id=42  MAE=nanRMSE=0.084218 Meanlog10=nan Acc_D1=0.040067 Acc_D2=0.081616 Acc_D3=0.111813:   0%|          | 0/293 [01:49<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.17602629959583282 Epoch=0 Batch_id=43  MAE=nanRMSE=0.085069 Meanlog10=nan Acc_D1=0.040368 Acc_D2=0.082411 Acc_D3=0.113562:   0%|          | 0/293 [01:52<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.16955383121967316 Epoch=0 Batch_id=44  MAE=nanRMSE=0.085848 Meanlog10=nan Acc_D1=0.040682 Acc_D2=0.083245 Acc_D3=0.115318:   0%|          | 0/293 [01:54<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.165787011384964 Epoch=0 Batch_id=45  MAE=nanRMSE=0.086750 Meanlog10=nan Acc_D1=0.040922 Acc_D2=0.083883 Acc_D3=0.116881:   0%|          | 0/293 [01:57<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1712857186794281 Epoch=0 Batch_id=46  MAE=nanRMSE=0.087791 Meanlog10=nan Acc_D1=0.041110 Acc_D2=0.084347 Acc_D3=0.118072:   0%|          | 0/293 [01:59<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.16513237357139587 Epoch=0 Batch_id=47  MAE=nanRMSE=0.089136 Meanlog10=nan Acc_D1=0.041203 Acc_D2=0.084654 Acc_D3=0.118836:   0%|          | 0/293 [02:01<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15909087657928467 Epoch=0 Batch_id=48  MAE=nanRMSE=0.090076 Meanlog10=nan Acc_D1=0.041429 Acc_D2=0.085240 Acc_D3=0.119880:   0%|          | 0/293 [02:03<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15515542030334473 Epoch=0 Batch_id=49  MAE=nanRMSE=0.091440 Meanlog10=nan Acc_D1=0.041489 Acc_D2=0.085433 Acc_D3=0.120495:   0%|          | 0/293 [02:06<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14888623356819153 Epoch=0 Batch_id=50  MAE=nanRMSE=0.092700 Meanlog10=nan Acc_D1=0.041781 Acc_D2=0.086026 Acc_D3=0.121514:   0%|          | 0/293 [02:08<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12619253993034363 Epoch=0 Batch_id=51  MAE=nanRMSE=0.092923 Meanlog10=nan Acc_D1=0.043087 Acc_D2=0.088450 Acc_D3=0.124592:   0%|          | 0/293 [02:10<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11994574218988419 Epoch=0 Batch_id=52  MAE=nanRMSE=0.093153 Meanlog10=nan Acc_D1=0.044396 Acc_D2=0.091004 Acc_D3=0.127775:   0%|          | 0/293 [02:13<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11646873503923416 Epoch=0 Batch_id=53  MAE=nanRMSE=0.093346 Meanlog10=nan Acc_D1=0.045769 Acc_D2=0.093586 Acc_D3=0.130891:   0%|          | 0/293 [02:15<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12704047560691833 Epoch=0 Batch_id=54  MAE=nanRMSE=0.093905 Meanlog10=nan Acc_D1=0.046681 Acc_D2=0.095332 Acc_D3=0.133101:   0%|          | 0/293 [02:18<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.16592302918434143 Epoch=0 Batch_id=55  MAE=nanRMSE=0.095485 Meanlog10=nan Acc_D1=0.046769 Acc_D2=0.095520 Acc_D3=0.133391:   0%|          | 0/293 [02:20<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15428240597248077 Epoch=0 Batch_id=56  MAE=nanRMSE=0.097246 Meanlog10=nan Acc_D1=0.046828 Acc_D2=0.095637 Acc_D3=0.133579:   0%|          | 0/293 [02:23<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1548648476600647 Epoch=0 Batch_id=57  MAE=nanRMSE=0.098602 Meanlog10=nan Acc_D1=0.046906 Acc_D2=0.095790 Acc_D3=0.133814:   0%|          | 0/293 [02:25<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15076565742492676 Epoch=0 Batch_id=58  MAE=nanRMSE=0.099677 Meanlog10=nan Acc_D1=0.047034 Acc_D2=0.096086 Acc_D3=0.134327:   0%|          | 0/293 [02:27<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1456676572561264 Epoch=0 Batch_id=59  MAE=nanRMSE=0.100322 Meanlog10=nan Acc_D1=0.047244 Acc_D2=0.096605 Acc_D3=0.135259:   0%|          | 0/293 [02:30<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13729676604270935 Epoch=0 Batch_id=60  MAE=nanRMSE=0.100977 Meanlog10=nan Acc_D1=0.047356 Acc_D2=0.096894 Acc_D3=0.135841:   0%|          | 0/293 [02:32<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14162898063659668 Epoch=0 Batch_id=61  MAE=nanRMSE=0.101626 Meanlog10=nan Acc_D1=0.047466 Acc_D2=0.097166 Acc_D3=0.136385:   0%|          | 0/293 [02:34<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14292243123054504 Epoch=0 Batch_id=62  MAE=nanRMSE=0.102066 Meanlog10=nan Acc_D1=0.048127 Acc_D2=0.098360 Acc_D3=0.137835:   0%|          | 0/293 [02:37<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12832105159759521 Epoch=0 Batch_id=63  MAE=nanRMSE=0.102353 Meanlog10=nan Acc_D1=0.048638 Acc_D2=0.099825 Acc_D3=0.140305:   0%|          | 0/293 [02:39<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11999864876270294 Epoch=0 Batch_id=64  MAE=nanRMSE=0.102652 Meanlog10=nan Acc_D1=0.049168 Acc_D2=0.101279 Acc_D3=0.142672:   0%|          | 0/293 [02:41<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12264031916856766 Epoch=0 Batch_id=65  MAE=nanRMSE=0.103012 Meanlog10=nan Acc_D1=0.049662 Acc_D2=0.102541 Acc_D3=0.144863:   0%|          | 0/293 [02:43<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1561821848154068 Epoch=0 Batch_id=66  MAE=nanRMSE=0.104283 Meanlog10=nan Acc_D1=0.049876 Acc_D2=0.103136 Acc_D3=0.145818:   0%|          | 0/293 [02:46<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.18275630474090576 Epoch=0 Batch_id=67  MAE=nanRMSE=0.105973 Meanlog10=nan Acc_D1=0.049899 Acc_D2=0.103200 Acc_D3=0.145947:   0%|          | 0/293 [02:48<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.17167434096336365 Epoch=0 Batch_id=68  MAE=nanRMSE=0.107814 Meanlog10=nan Acc_D1=0.049901 Acc_D2=0.103207 Acc_D3=0.145973:   0%|          | 0/293 [02:51<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.17135843634605408 Epoch=0 Batch_id=69  MAE=nanRMSE=0.109553 Meanlog10=nan Acc_D1=0.049906 Acc_D2=0.103220 Acc_D3=0.146000:   0%|          | 0/293 [02:53<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13076910376548767 Epoch=0 Batch_id=70  MAE=nanRMSE=0.110303 Meanlog10=nan Acc_D1=0.050032 Acc_D2=0.103707 Acc_D3=0.147170:   0%|          | 0/293 [02:55<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12077081203460693 Epoch=0 Batch_id=71  MAE=nanRMSE=0.110690 Meanlog10=nan Acc_D1=0.050201 Acc_D2=0.104401 Acc_D3=0.148871:   0%|          | 0/293 [02:58<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11804883927106857 Epoch=0 Batch_id=72  MAE=nanRMSE=0.110917 Meanlog10=nan Acc_D1=0.050527 Acc_D2=0.105573 Acc_D3=0.151161:   0%|          | 0/293 [03:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1210922971367836 Epoch=0 Batch_id=73  MAE=nanRMSE=0.111120 Meanlog10=nan Acc_D1=0.051146 Acc_D2=0.106997 Acc_D3=0.153552:   0%|          | 0/293 [03:03<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1270163208246231 Epoch=0 Batch_id=74  MAE=nanRMSE=0.111421 Meanlog10=nan Acc_D1=0.052062 Acc_D2=0.108975 Acc_D3=0.156471:   0%|          | 0/293 [03:05<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1346299946308136 Epoch=0 Batch_id=75  MAE=nanRMSE=0.111543 Meanlog10=nan Acc_D1=0.054147 Acc_D2=0.111973 Acc_D3=0.159731:   0%|          | 0/293 [03:07<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12631948292255402 Epoch=0 Batch_id=76  MAE=nanRMSE=0.111711 Meanlog10=nan Acc_D1=0.055764 Acc_D2=0.114892 Acc_D3=0.162976:   0%|          | 0/293 [03:10<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1295764148235321 Epoch=0 Batch_id=77  MAE=nanRMSE=0.111887 Meanlog10=nan Acc_D1=0.057514 Acc_D2=0.117816 Acc_D3=0.166210:   0%|          | 0/293 [03:12<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1135198101401329 Epoch=0 Batch_id=78  MAE=nanRMSE=0.112119 Meanlog10=nan Acc_D1=0.058831 Acc_D2=0.120160 Acc_D3=0.169097:   0%|          | 0/293 [03:14<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.10769499093294144 Epoch=0 Batch_id=79  MAE=nanRMSE=0.112339 Meanlog10=nan Acc_D1=0.060036 Acc_D2=0.122506 Acc_D3=0.171853:   0%|          | 0/293 [03:17<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.09589381515979767 Epoch=0 Batch_id=80  MAE=nanRMSE=0.112572 Meanlog10=nan Acc_D1=0.061267 Acc_D2=0.124676 Acc_D3=0.174459:   0%|          | 0/293 [03:19<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.09347788244485855 Epoch=0 Batch_id=81  MAE=nanRMSE=0.112815 Meanlog10=nan Acc_D1=0.062445 Acc_D2=0.126877 Acc_D3=0.176998:   0%|          | 0/293 [03:22<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12448734045028687 Epoch=0 Batch_id=82  MAE=nanRMSE=0.113015 Meanlog10=nan Acc_D1=0.064119 Acc_D2=0.129072 Acc_D3=0.179424:   0%|          | 0/293 [03:24<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11980857700109482 Epoch=0 Batch_id=83  MAE=nanRMSE=0.113188 Meanlog10=nan Acc_D1=0.065601 Acc_D2=0.131470 Acc_D3=0.182288:   0%|          | 0/293 [03:26<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11158853769302368 Epoch=0 Batch_id=84  MAE=nanRMSE=0.113316 Meanlog10=nan Acc_D1=0.067282 Acc_D2=0.134023 Acc_D3=0.185166:   0%|          | 0/293 [03:29<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11259463429450989 Epoch=0 Batch_id=85  MAE=nanRMSE=0.113524 Meanlog10=nan Acc_D1=0.068532 Acc_D2=0.136125 Acc_D3=0.187712:   0%|          | 0/293 [03:31<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.17760881781578064 Epoch=0 Batch_id=86  MAE=nanRMSE=0.113745 Meanlog10=nan Acc_D1=0.069624 Acc_D2=0.138402 Acc_D3=0.190689:   0%|          | 0/293 [03:34<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1671985387802124 Epoch=0 Batch_id=87  MAE=nanRMSE=0.113905 Meanlog10=nan Acc_D1=0.071009 Acc_D2=0.140640 Acc_D3=0.193521:   0%|          | 0/293 [03:36<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1601564735174179 Epoch=0 Batch_id=88  MAE=nanRMSE=0.114022 Meanlog10=nan Acc_D1=0.072710 Acc_D2=0.143210 Acc_D3=0.196534:   0%|          | 0/293 [03:38<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15900669991970062 Epoch=0 Batch_id=89  MAE=nanRMSE=0.114165 Meanlog10=nan Acc_D1=0.074160 Acc_D2=0.145509 Acc_D3=0.199345:   0%|          | 0/293 [03:40<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.17574231326580048 Epoch=0 Batch_id=90  MAE=nanRMSE=0.114479 Meanlog10=nan Acc_D1=0.074889 Acc_D2=0.146970 Acc_D3=0.201471:   0%|          | 0/293 [03:43<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.17281070351600647 Epoch=0 Batch_id=91  MAE=nanRMSE=0.114810 Meanlog10=nan Acc_D1=0.075521 Acc_D2=0.148327 Acc_D3=0.203442:   0%|          | 0/293 [03:45<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.16927340626716614 Epoch=0 Batch_id=92  MAE=nanRMSE=0.115152 Meanlog10=nan Acc_D1=0.076037 Acc_D2=0.149488 Acc_D3=0.205229:   0%|          | 0/293 [03:48<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15924720466136932 Epoch=0 Batch_id=93  MAE=nanRMSE=0.115550 Meanlog10=nan Acc_D1=0.076695 Acc_D2=0.150840 Acc_D3=0.207258:   0%|          | 0/293 [03:50<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1590351164340973 Epoch=0 Batch_id=94  MAE=nanRMSE=0.116393 Meanlog10=nan Acc_D1=0.077483 Acc_D2=0.152528 Acc_D3=0.209429:   0%|          | 0/293 [03:52<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14950788021087646 Epoch=0 Batch_id=95  MAE=nanRMSE=0.117310 Meanlog10=nan Acc_D1=0.078236 Acc_D2=0.154164 Acc_D3=0.211532:   0%|          | 0/293 [03:55<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14621706306934357 Epoch=0 Batch_id=96  MAE=nanRMSE=0.118022 Meanlog10=nan Acc_D1=0.079349 Acc_D2=0.156095 Acc_D3=0.213850:   0%|          | 0/293 [03:57<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1340019255876541 Epoch=0 Batch_id=97  MAE=nanRMSE=0.118536 Meanlog10=nan Acc_D1=0.080801 Acc_D2=0.158234 Acc_D3=0.216317:   0%|          | 0/293 [04:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12368322163820267 Epoch=0 Batch_id=98  MAE=nanRMSE=0.118612 Meanlog10=nan Acc_D1=0.082783 Acc_D2=0.160964 Acc_D3=0.219344:   0%|          | 0/293 [04:02<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11320459097623825 Epoch=0 Batch_id=99  MAE=nanRMSE=0.118685 Meanlog10=nan Acc_D1=0.084704 Acc_D2=0.163688 Acc_D3=0.222390:   0%|          | 0/293 [04:04<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11468286067247391 Epoch=0 Batch_id=100  MAE=nanRMSE=0.118763 Meanlog10=nan Acc_D1=0.086520 Acc_D2=0.166364 Acc_D3=0.225414:   0%|          | 0/293 [04:07<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13841646909713745 Epoch=0 Batch_id=101  MAE=nanRMSE=0.118980 Meanlog10=nan Acc_D1=0.087896 Acc_D2=0.168766 Acc_D3=0.228476:   0%|          | 0/293 [04:09<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.17193542420864105 Epoch=0 Batch_id=102  MAE=nanRMSE=0.119341 Meanlog10=nan Acc_D1=0.088884 Acc_D2=0.170823 Acc_D3=0.231582:   0%|          | 0/293 [04:12<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15412603318691254 Epoch=0 Batch_id=103  MAE=nanRMSE=0.119726 Meanlog10=nan Acc_D1=0.089928 Acc_D2=0.172848 Acc_D3=0.234591:   0%|          | 0/293 [04:14<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1536310762166977 Epoch=0 Batch_id=104  MAE=nanRMSE=0.120043 Meanlog10=nan Acc_D1=0.091076 Acc_D2=0.175052 Acc_D3=0.237772:   0%|          | 0/293 [04:17<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.18224972486495972 Epoch=0 Batch_id=105  MAE=nanRMSE=0.121723 Meanlog10=nan Acc_D1=0.091571 Acc_D2=0.176005 Acc_D3=0.239148:   0%|          | 0/293 [04:19<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1970643252134323 Epoch=0 Batch_id=106  MAE=nanRMSE=0.123256 Meanlog10=nan Acc_D1=0.091809 Acc_D2=0.176770 Acc_D3=0.240871:   0%|          | 0/293 [04:22<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.18719838559627533 Epoch=0 Batch_id=107  MAE=nanRMSE=0.124900 Meanlog10=nan Acc_D1=0.092041 Acc_D2=0.177418 Acc_D3=0.242283:   0%|          | 0/293 [04:24<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1898125410079956 Epoch=0 Batch_id=108  MAE=nanRMSE=0.126615 Meanlog10=nan Acc_D1=0.092242 Acc_D2=0.177968 Acc_D3=0.243587:   0%|          | 0/293 [04:27<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.24338924884796143 Epoch=0 Batch_id=109  MAE=nanRMSE=0.127433 Meanlog10=nan Acc_D1=0.092831 Acc_D2=0.179548 Acc_D3=0.246156:   0%|          | 0/293 [04:29<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.236789733171463 Epoch=0 Batch_id=110  MAE=nanRMSE=0.127833 Meanlog10=nan Acc_D1=0.093628 Acc_D2=0.181785 Acc_D3=0.249302:   0%|          | 0/293 [04:32<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.2362426072359085 Epoch=0 Batch_id=111  MAE=nanRMSE=0.128159 Meanlog10=nan Acc_D1=0.094581 Acc_D2=0.184229 Acc_D3=0.252455:   0%|          | 0/293 [04:34<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.23108628392219543 Epoch=0 Batch_id=112  MAE=nanRMSE=0.128387 Meanlog10=nan Acc_D1=0.096253 Acc_D2=0.187084 Acc_D3=0.255630:   0%|          | 0/293 [04:36<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.2330934852361679 Epoch=0 Batch_id=113  MAE=nanRMSE=0.128934 Meanlog10=nan Acc_D1=0.096804 Acc_D2=0.188450 Acc_D3=0.257680:   0%|          | 0/293 [04:39<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1998271644115448 Epoch=0 Batch_id=114  MAE=nanRMSE=0.129316 Meanlog10=nan Acc_D1=0.097582 Acc_D2=0.190079 Acc_D3=0.260002:   0%|          | 0/293 [04:41<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.18652725219726562 Epoch=0 Batch_id=115  MAE=nanRMSE=0.129694 Meanlog10=nan Acc_D1=0.098328 Acc_D2=0.191646 Acc_D3=0.262321:   0%|          | 0/293 [04:44<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.18573281168937683 Epoch=0 Batch_id=116  MAE=nanRMSE=0.130149 Meanlog10=nan Acc_D1=0.099096 Acc_D2=0.193059 Acc_D3=0.264514:   0%|          | 0/293 [04:46<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.17200471460819244 Epoch=0 Batch_id=117  MAE=nanRMSE=0.130585 Meanlog10=nan Acc_D1=0.099412 Acc_D2=0.193857 Acc_D3=0.265992:   0%|          | 0/293 [04:49<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.17437449097633362 Epoch=0 Batch_id=118  MAE=nanRMSE=0.130955 Meanlog10=nan Acc_D1=0.099657 Acc_D2=0.194582 Acc_D3=0.267671:   0%|          | 0/293 [04:51<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1630197912454605 Epoch=0 Batch_id=119  MAE=nanRMSE=0.131323 Meanlog10=nan Acc_D1=0.099860 Acc_D2=0.195194 Acc_D3=0.269429:   0%|          | 0/293 [04:53<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1622624546289444 Epoch=0 Batch_id=120  MAE=nanRMSE=0.131841 Meanlog10=nan Acc_D1=0.099968 Acc_D2=0.195609 Acc_D3=0.270763:   0%|          | 0/293 [04:56<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.124689981341362 Epoch=0 Batch_id=121  MAE=nanRMSE=0.132295 Meanlog10=nan Acc_D1=0.100264 Acc_D2=0.196353 Acc_D3=0.272131:   0%|          | 0/293 [04:58<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11379043757915497 Epoch=0 Batch_id=122  MAE=nanRMSE=0.132558 Meanlog10=nan Acc_D1=0.100725 Acc_D2=0.197301 Acc_D3=0.273688:   0%|          | 0/293 [05:01<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.10374077409505844 Epoch=0 Batch_id=123  MAE=nanRMSE=0.132746 Meanlog10=nan Acc_D1=0.101255 Acc_D2=0.198373 Acc_D3=0.275535:   0%|          | 0/293 [05:03<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1020660251379013 Epoch=0 Batch_id=124  MAE=nanRMSE=0.132926 Meanlog10=nan Acc_D1=0.101750 Acc_D2=0.199382 Acc_D3=0.277346:   0%|          | 0/293 [05:06<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15675801038742065 Epoch=0 Batch_id=125  MAE=nanRMSE=0.133755 Meanlog10=nan Acc_D1=0.101774 Acc_D2=0.199442 Acc_D3=0.277462:   0%|          | 0/293 [05:08<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1478104442358017 Epoch=0 Batch_id=126  MAE=nanRMSE=0.134451 Meanlog10=nan Acc_D1=0.101804 Acc_D2=0.199511 Acc_D3=0.277587:   0%|          | 0/293 [05:11<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1386345624923706 Epoch=0 Batch_id=127  MAE=nanRMSE=0.135085 Meanlog10=nan Acc_D1=0.101830 Acc_D2=0.199567 Acc_D3=0.277681:   0%|          | 0/293 [05:13<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13403859734535217 Epoch=0 Batch_id=128  MAE=nanRMSE=0.135721 Meanlog10=nan Acc_D1=0.101977 Acc_D2=0.199868 Acc_D3=0.278037:   0%|          | 0/293 [05:15<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13847549259662628 Epoch=0 Batch_id=129  MAE=nanRMSE=0.135818 Meanlog10=nan Acc_D1=0.104324 Acc_D2=0.202854 Acc_D3=0.281237:   0%|          | 0/293 [05:18<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13080738484859467 Epoch=0 Batch_id=130  MAE=nanRMSE=0.135886 Meanlog10=nan Acc_D1=0.106751 Acc_D2=0.205907 Acc_D3=0.284483:   0%|          | 0/293 [05:20<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12807340919971466 Epoch=0 Batch_id=131  MAE=nanRMSE=0.135941 Meanlog10=nan Acc_D1=0.109241 Acc_D2=0.209025 Acc_D3=0.287762:   0%|          | 0/293 [05:23<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11821755021810532 Epoch=0 Batch_id=132  MAE=nanRMSE=0.136095 Meanlog10=nan Acc_D1=0.111330 Acc_D2=0.211864 Acc_D3=0.290918:   0%|          | 0/293 [05:25<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14409752190113068 Epoch=0 Batch_id=133  MAE=nanRMSE=0.136465 Meanlog10=nan Acc_D1=0.112574 Acc_D2=0.214278 Acc_D3=0.293992:   0%|          | 0/293 [05:28<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1379793882369995 Epoch=0 Batch_id=134  MAE=nanRMSE=0.136860 Meanlog10=nan Acc_D1=0.113659 Acc_D2=0.216541 Acc_D3=0.296973:   0%|          | 0/293 [05:30<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12702076137065887 Epoch=0 Batch_id=135  MAE=nanRMSE=0.137241 Meanlog10=nan Acc_D1=0.114660 Acc_D2=0.218687 Acc_D3=0.299868:   0%|          | 0/293 [05:32<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1246550902724266 Epoch=0 Batch_id=136  MAE=nanRMSE=0.137544 Meanlog10=nan Acc_D1=0.115878 Acc_D2=0.221127 Acc_D3=0.302940:   0%|          | 0/293 [05:35<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1398104876279831 Epoch=0 Batch_id=137  MAE=nanRMSE=0.137910 Meanlog10=nan Acc_D1=0.117221 Acc_D2=0.223187 Acc_D3=0.305751:   0%|          | 0/293 [05:37<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1285293698310852 Epoch=0 Batch_id=138  MAE=nanRMSE=0.138167 Meanlog10=nan Acc_D1=0.118551 Acc_D2=0.225643 Acc_D3=0.308762:   0%|          | 0/293 [05:40<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12500929832458496 Epoch=0 Batch_id=139  MAE=nanRMSE=0.138386 Meanlog10=nan Acc_D1=0.120156 Acc_D2=0.228237 Acc_D3=0.311872:   0%|          | 0/293 [05:42<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11953450739383698 Epoch=0 Batch_id=140  MAE=nanRMSE=0.138557 Meanlog10=nan Acc_D1=0.121761 Acc_D2=0.230893 Acc_D3=0.315019:   0%|          | 0/293 [05:45<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11855755001306534 Epoch=0 Batch_id=141  MAE=nanRMSE=0.138705 Meanlog10=nan Acc_D1=0.123235 Acc_D2=0.233431 Acc_D3=0.318060:   0%|          | 0/293 [05:47<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.10516482591629028 Epoch=0 Batch_id=142  MAE=nanRMSE=0.138796 Meanlog10=nan Acc_D1=0.124873 Acc_D2=0.236129 Acc_D3=0.321137:   0%|          | 0/293 [05:50<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.10485948622226715 Epoch=0 Batch_id=143  MAE=nanRMSE=0.138885 Meanlog10=nan Acc_D1=0.126509 Acc_D2=0.238824 Acc_D3=0.324194:   0%|          | 0/293 [05:52<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12507879734039307 Epoch=0 Batch_id=144  MAE=nanRMSE=0.139179 Meanlog10=nan Acc_D1=0.127726 Acc_D2=0.240887 Acc_D3=0.327049:   0%|          | 0/293 [05:54<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1592998504638672 Epoch=0 Batch_id=145  MAE=nanRMSE=0.139527 Meanlog10=nan Acc_D1=0.128642 Acc_D2=0.243172 Acc_D3=0.329952:   0%|          | 0/293 [05:57<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14680621027946472 Epoch=0 Batch_id=146  MAE=nanRMSE=0.139951 Meanlog10=nan Acc_D1=0.129057 Acc_D2=0.244827 Acc_D3=0.332783:   0%|          | 0/293 [05:59<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14714108407497406 Epoch=0 Batch_id=147  MAE=nanRMSE=0.140298 Meanlog10=nan Acc_D1=0.129976 Acc_D2=0.246928 Acc_D3=0.335689:   0%|          | 0/293 [06:02<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13859988749027252 Epoch=0 Batch_id=148  MAE=nanRMSE=0.140611 Meanlog10=nan Acc_D1=0.130989 Acc_D2=0.249194 Acc_D3=0.338633:   0%|          | 0/293 [06:04<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1589755117893219 Epoch=0 Batch_id=149  MAE=nanRMSE=0.140908 Meanlog10=nan Acc_D1=0.132206 Acc_D2=0.251491 Acc_D3=0.341625:   0%|          | 0/293 [06:06<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14887745678424835 Epoch=0 Batch_id=150  MAE=nanRMSE=0.141125 Meanlog10=nan Acc_D1=0.133879 Acc_D2=0.254261 Acc_D3=0.344793:   0%|          | 0/293 [06:09<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15132388472557068 Epoch=0 Batch_id=151  MAE=nanRMSE=0.141599 Meanlog10=nan Acc_D1=0.134696 Acc_D2=0.255871 Acc_D3=0.347152:   0%|          | 0/293 [06:12<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12410202622413635 Epoch=0 Batch_id=152  MAE=nanRMSE=0.141925 Meanlog10=nan Acc_D1=0.135402 Acc_D2=0.257715 Acc_D3=0.349850:   0%|          | 0/293 [06:14<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12765179574489594 Epoch=0 Batch_id=153  MAE=nanRMSE=0.142156 Meanlog10=nan Acc_D1=0.136084 Acc_D2=0.259781 Acc_D3=0.352306:   0%|          | 0/293 [06:17<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11495408415794373 Epoch=0 Batch_id=154  MAE=nanRMSE=0.142364 Meanlog10=nan Acc_D1=0.136841 Acc_D2=0.262016 Acc_D3=0.354774:   0%|          | 0/293 [06:19<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11718524992465973 Epoch=0 Batch_id=155  MAE=nanRMSE=0.142640 Meanlog10=nan Acc_D1=0.137519 Acc_D2=0.263871 Acc_D3=0.357218:   0%|          | 0/293 [06:21<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.10959085077047348 Epoch=0 Batch_id=156  MAE=nanRMSE=0.142815 Meanlog10=nan Acc_D1=0.138747 Acc_D2=0.266178 Acc_D3=0.360006:   0%|          | 0/293 [06:24<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.10226646065711975 Epoch=0 Batch_id=157  MAE=nanRMSE=0.142886 Meanlog10=nan Acc_D1=0.140869 Acc_D2=0.268842 Acc_D3=0.362861:   0%|          | 0/293 [06:26<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.09258724749088287 Epoch=0 Batch_id=158  MAE=nanRMSE=0.142956 Meanlog10=nan Acc_D1=0.142840 Acc_D2=0.271517 Acc_D3=0.365710:   0%|          | 0/293 [06:29<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.09021390974521637 Epoch=0 Batch_id=159  MAE=nanRMSE=0.143003 Meanlog10=nan Acc_D1=0.145066 Acc_D2=0.274290 Acc_D3=0.368592:   0%|          | 0/293 [06:31<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14402885735034943 Epoch=0 Batch_id=160  MAE=nanRMSE=0.143335 Meanlog10=nan Acc_D1=0.145999 Acc_D2=0.276365 Acc_D3=0.371663:   0%|          | 0/293 [06:34<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15467345714569092 Epoch=0 Batch_id=161  MAE=nanRMSE=0.143574 Meanlog10=nan Acc_D1=0.147161 Acc_D2=0.279216 Acc_D3=0.374962:   0%|          | 0/293 [06:36<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1508735567331314 Epoch=0 Batch_id=162  MAE=nanRMSE=0.143829 Meanlog10=nan Acc_D1=0.148109 Acc_D2=0.281992 Acc_D3=0.378260:   0%|          | 0/293 [06:39<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14777947962284088 Epoch=0 Batch_id=163  MAE=nanRMSE=0.144067 Meanlog10=nan Acc_D1=0.149167 Acc_D2=0.284898 Acc_D3=0.381568:   0%|          | 0/293 [06:41<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15978962182998657 Epoch=0 Batch_id=164  MAE=nanRMSE=0.144299 Meanlog10=nan Acc_D1=0.150258 Acc_D2=0.287652 Acc_D3=0.384817:   0%|          | 0/293 [06:44<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15332214534282684 Epoch=0 Batch_id=165  MAE=nanRMSE=0.144514 Meanlog10=nan Acc_D1=0.151718 Acc_D2=0.290401 Acc_D3=0.388057:   0%|          | 0/293 [06:47<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14620859920978546 Epoch=0 Batch_id=166  MAE=nanRMSE=0.144701 Meanlog10=nan Acc_D1=0.153387 Acc_D2=0.293224 Acc_D3=0.391268:   0%|          | 0/293 [06:49<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14385154843330383 Epoch=0 Batch_id=167  MAE=nanRMSE=0.144834 Meanlog10=nan Acc_D1=0.155287 Acc_D2=0.296281 Acc_D3=0.394554:   0%|          | 0/293 [06:51<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13597404956817627 Epoch=0 Batch_id=168  MAE=nanRMSE=0.145241 Meanlog10=nan Acc_D1=0.156412 Acc_D2=0.298780 Acc_D3=0.397639:   0%|          | 0/293 [06:54<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1317889541387558 Epoch=0 Batch_id=169  MAE=nanRMSE=0.145597 Meanlog10=nan Acc_D1=0.157802 Acc_D2=0.301429 Acc_D3=0.400737:   0%|          | 0/293 [06:56<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12874650955200195 Epoch=0 Batch_id=170  MAE=nanRMSE=0.145935 Meanlog10=nan Acc_D1=0.159349 Acc_D2=0.304028 Acc_D3=0.403942:   0%|          | 0/293 [06:59<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12778306007385254 Epoch=0 Batch_id=171  MAE=nanRMSE=0.146277 Meanlog10=nan Acc_D1=0.160902 Acc_D2=0.306638 Acc_D3=0.406965:   0%|          | 0/293 [07:01<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1476144790649414 Epoch=0 Batch_id=172  MAE=nanRMSE=0.146518 Meanlog10=nan Acc_D1=0.161913 Acc_D2=0.308475 Acc_D3=0.409044:   0%|          | 0/293 [07:04<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13962863385677338 Epoch=0 Batch_id=173  MAE=nanRMSE=0.146789 Meanlog10=nan Acc_D1=0.162942 Acc_D2=0.310308 Acc_D3=0.411105:   0%|          | 0/293 [07:06<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13459208607673645 Epoch=0 Batch_id=174  MAE=nanRMSE=0.146991 Meanlog10=nan Acc_D1=0.164101 Acc_D2=0.312119 Acc_D3=0.413158:   0%|          | 0/293 [07:09<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13985797762870789 Epoch=0 Batch_id=175  MAE=nanRMSE=0.147218 Meanlog10=nan Acc_D1=0.165447 Acc_D2=0.314071 Acc_D3=0.415405:   0%|          | 0/293 [07:11<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11587682366371155 Epoch=0 Batch_id=176  MAE=nanRMSE=0.147308 Meanlog10=nan Acc_D1=0.167954 Acc_D2=0.317313 Acc_D3=0.418725:   0%|          | 0/293 [07:14<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11079294979572296 Epoch=0 Batch_id=177  MAE=nanRMSE=0.147443 Meanlog10=nan Acc_D1=0.170075 Acc_D2=0.320406 Acc_D3=0.422035:   0%|          | 0/293 [07:16<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.10714876651763916 Epoch=0 Batch_id=178  MAE=nanRMSE=0.147498 Meanlog10=nan Acc_D1=0.173017 Acc_D2=0.323707 Acc_D3=0.425366:   0%|          | 0/293 [07:19<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1143438071012497 Epoch=0 Batch_id=179  MAE=nanRMSE=0.147661 Meanlog10=nan Acc_D1=0.175321 Acc_D2=0.326423 Acc_D3=0.428328:   0%|          | 0/293 [07:21<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14489531517028809 Epoch=0 Batch_id=180  MAE=nanRMSE=0.148096 Meanlog10=nan Acc_D1=0.176003 Acc_D2=0.327858 Acc_D3=0.430470:   0%|          | 0/293 [07:24<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13420265913009644 Epoch=0 Batch_id=181  MAE=nanRMSE=0.148563 Meanlog10=nan Acc_D1=0.176646 Acc_D2=0.329260 Acc_D3=0.432604:   0%|          | 0/293 [07:27<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1360151767730713 Epoch=0 Batch_id=182  MAE=nanRMSE=0.149037 Meanlog10=nan Acc_D1=0.177211 Acc_D2=0.330573 Acc_D3=0.434699:   0%|          | 0/293 [07:29<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12229233235120773 Epoch=0 Batch_id=183  MAE=nanRMSE=0.149593 Meanlog10=nan Acc_D1=0.177687 Acc_D2=0.331705 Acc_D3=0.436533:   0%|          | 0/293 [07:32<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11629977822303772 Epoch=0 Batch_id=184  MAE=nanRMSE=0.149933 Meanlog10=nan Acc_D1=0.178225 Acc_D2=0.332766 Acc_D3=0.438022:   0%|          | 0/293 [07:35<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.0983012467622757 Epoch=0 Batch_id=185  MAE=nanRMSE=0.150451 Meanlog10=nan Acc_D1=0.178521 Acc_D2=0.333544 Acc_D3=0.439311:   0%|          | 0/293 [07:37<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.10107121616601944 Epoch=0 Batch_id=186  MAE=nanRMSE=0.150761 Meanlog10=nan Acc_D1=0.179062 Acc_D2=0.334656 Acc_D3=0.440750:   0%|          | 0/293 [07:39<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.10513515770435333 Epoch=0 Batch_id=187  MAE=nanRMSE=0.151064 Meanlog10=nan Acc_D1=0.179720 Acc_D2=0.336008 Acc_D3=0.442657:   0%|          | 0/293 [07:42<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12668967247009277 Epoch=0 Batch_id=188  MAE=nanRMSE=0.151373 Meanlog10=nan Acc_D1=0.180222 Acc_D2=0.337212 Acc_D3=0.444812:   0%|          | 0/293 [07:44<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11819054186344147 Epoch=0 Batch_id=189  MAE=nanRMSE=0.151757 Meanlog10=nan Acc_D1=0.180523 Acc_D2=0.338075 Acc_D3=0.446638:   0%|          | 0/293 [07:47<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11987847089767456 Epoch=0 Batch_id=190  MAE=nanRMSE=0.152146 Meanlog10=nan Acc_D1=0.180741 Acc_D2=0.338787 Acc_D3=0.448435:   0%|          | 0/293 [07:49<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.10449621081352234 Epoch=0 Batch_id=191  MAE=nanRMSE=0.152542 Meanlog10=nan Acc_D1=0.181374 Acc_D2=0.339842 Acc_D3=0.449974:   0%|          | 0/293 [07:52<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.10624243319034576 Epoch=0 Batch_id=192  MAE=nanRMSE=0.152729 Meanlog10=nan Acc_D1=0.182411 Acc_D2=0.341313 Acc_D3=0.451832:   0%|          | 0/293 [07:54<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.08946936577558517 Epoch=0 Batch_id=193  MAE=nanRMSE=0.152934 Meanlog10=nan Acc_D1=0.183508 Acc_D2=0.342748 Acc_D3=0.453585:   0%|          | 0/293 [07:57<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.09125030785799026 Epoch=0 Batch_id=194  MAE=nanRMSE=0.153091 Meanlog10=nan Acc_D1=0.184583 Acc_D2=0.344230 Acc_D3=0.455462:   0%|          | 0/293 [07:59<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1215021088719368 Epoch=0 Batch_id=195  MAE=nanRMSE=0.153263 Meanlog10=nan Acc_D1=0.185438 Acc_D2=0.345562 Acc_D3=0.457298:   0%|          | 0/293 [08:02<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13767248392105103 Epoch=0 Batch_id=196  MAE=nanRMSE=0.153718 Meanlog10=nan Acc_D1=0.185999 Acc_D2=0.346504 Acc_D3=0.458631:   0%|          | 0/293 [08:04<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1247059777379036 Epoch=0 Batch_id=197  MAE=nanRMSE=0.154123 Meanlog10=nan Acc_D1=0.186514 Acc_D2=0.347346 Acc_D3=0.459797:   0%|          | 0/293 [08:07<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12511436641216278 Epoch=0 Batch_id=198  MAE=nanRMSE=0.154501 Meanlog10=nan Acc_D1=0.187056 Acc_D2=0.348204 Acc_D3=0.460971:   0%|          | 0/293 [08:10<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15362383425235748 Epoch=0 Batch_id=199  MAE=nanRMSE=0.154752 Meanlog10=nan Acc_D1=0.188485 Acc_D2=0.350678 Acc_D3=0.463710:   0%|          | 0/293 [08:12<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15362438559532166 Epoch=0 Batch_id=200  MAE=nanRMSE=0.155008 Meanlog10=nan Acc_D1=0.189085 Acc_D2=0.352882 Acc_D3=0.466942:   0%|          | 0/293 [08:15<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1454544961452484 Epoch=0 Batch_id=201  MAE=nanRMSE=0.155244 Meanlog10=nan Acc_D1=0.189788 Acc_D2=0.355401 Acc_D3=0.470126:   0%|          | 0/293 [08:17<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14421236515045166 Epoch=0 Batch_id=202  MAE=nanRMSE=0.155411 Meanlog10=nan Acc_D1=0.191175 Acc_D2=0.358040 Acc_D3=0.473305:   0%|          | 0/293 [08:20<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1173403263092041 Epoch=0 Batch_id=203  MAE=nanRMSE=0.155652 Meanlog10=nan Acc_D1=0.192142 Acc_D2=0.360195 Acc_D3=0.475917:   0%|          | 0/293 [08:22<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.10639087855815887 Epoch=0 Batch_id=204  MAE=nanRMSE=0.155865 Meanlog10=nan Acc_D1=0.193256 Acc_D2=0.362315 Acc_D3=0.478707:   0%|          | 0/293 [08:24<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.09508991986513138 Epoch=0 Batch_id=205  MAE=nanRMSE=0.156084 Meanlog10=nan Acc_D1=0.194367 Acc_D2=0.364410 Acc_D3=0.481519:   0%|          | 0/293 [08:27<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.09379152953624725 Epoch=0 Batch_id=206  MAE=nanRMSE=0.156287 Meanlog10=nan Acc_D1=0.195533 Acc_D2=0.366524 Acc_D3=0.484279:   0%|          | 0/293 [08:30<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1428341418504715 Epoch=0 Batch_id=207  MAE=nanRMSE=0.156611 Meanlog10=nan Acc_D1=0.196259 Acc_D2=0.367947 Acc_D3=0.486208:   0%|          | 0/293 [08:32<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14010265469551086 Epoch=0 Batch_id=208  MAE=nanRMSE=0.156845 Meanlog10=nan Acc_D1=0.197153 Acc_D2=0.369506 Acc_D3=0.488440:   0%|          | 0/293 [08:35<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1318601369857788 Epoch=0 Batch_id=209  MAE=nanRMSE=0.157095 Meanlog10=nan Acc_D1=0.198076 Acc_D2=0.371026 Acc_D3=0.490619:   0%|          | 0/293 [08:38<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13157261908054352 Epoch=0 Batch_id=210  MAE=nanRMSE=0.157458 Meanlog10=nan Acc_D1=0.198748 Acc_D2=0.372214 Acc_D3=0.492347:   0%|          | 0/293 [08:40<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.17149755358695984 Epoch=0 Batch_id=211  MAE=nanRMSE=0.157877 Meanlog10=nan Acc_D1=0.199022 Acc_D2=0.372806 Acc_D3=0.493292:   0%|          | 0/293 [08:42<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.16649265587329865 Epoch=0 Batch_id=212  MAE=nanRMSE=0.158430 Meanlog10=nan Acc_D1=0.199203 Acc_D2=0.373223 Acc_D3=0.493978:   0%|          | 0/293 [08:45<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.16048185527324677 Epoch=0 Batch_id=213  MAE=nanRMSE=0.158759 Meanlog10=nan Acc_D1=0.199332 Acc_D2=0.373534 Acc_D3=0.494569:   0%|          | 0/293 [08:48<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.16372638940811157 Epoch=0 Batch_id=214  MAE=nanRMSE=0.159441 Meanlog10=nan Acc_D1=0.199448 Acc_D2=0.373817 Acc_D3=0.495109:   0%|          | 0/293 [08:50<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.16395975649356842 Epoch=0 Batch_id=215  MAE=nanRMSE=0.160377 Meanlog10=nan Acc_D1=0.199793 Acc_D2=0.375040 Acc_D3=0.497861:   0%|          | 0/293 [08:53<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15741419792175293 Epoch=0 Batch_id=216  MAE=nanRMSE=0.161338 Meanlog10=nan Acc_D1=0.200257 Acc_D2=0.376333 Acc_D3=0.500314:   0%|          | 0/293 [08:56<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15222227573394775 Epoch=0 Batch_id=217  MAE=nanRMSE=0.162284 Meanlog10=nan Acc_D1=0.200737 Acc_D2=0.377753 Acc_D3=0.502738:   0%|          | 0/293 [08:58<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1594787836074829 Epoch=0 Batch_id=218  MAE=nanRMSE=0.162926 Meanlog10=nan Acc_D1=0.201523 Acc_D2=0.379638 Acc_D3=0.505370:   0%|          | 0/293 [09:01<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15245872735977173 Epoch=0 Batch_id=219  MAE=nanRMSE=0.163251 Meanlog10=nan Acc_D1=0.202114 Acc_D2=0.380889 Acc_D3=0.507546:   0%|          | 0/293 [09:03<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14178401231765747 Epoch=0 Batch_id=220  MAE=nanRMSE=0.163594 Meanlog10=nan Acc_D1=0.202495 Acc_D2=0.382008 Acc_D3=0.509405:   0%|          | 0/293 [09:06<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1387302279472351 Epoch=0 Batch_id=221  MAE=nanRMSE=0.163926 Meanlog10=nan Acc_D1=0.202842 Acc_D2=0.383066 Acc_D3=0.511601:   0%|          | 0/293 [09:08<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13713698089122772 Epoch=0 Batch_id=222  MAE=nanRMSE=0.164275 Meanlog10=nan Acc_D1=0.203265 Acc_D2=0.384112 Acc_D3=0.513438:   0%|          | 0/293 [09:10<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1067412793636322 Epoch=0 Batch_id=223  MAE=nanRMSE=0.164371 Meanlog10=nan Acc_D1=0.204385 Acc_D2=0.386100 Acc_D3=0.516142:   0%|          | 0/293 [09:13<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.09162525087594986 Epoch=0 Batch_id=224  MAE=nanRMSE=0.164492 Meanlog10=nan Acc_D1=0.205345 Acc_D2=0.387834 Acc_D3=0.518485:   0%|          | 0/293 [09:16<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.09350243955850601 Epoch=0 Batch_id=225  MAE=nanRMSE=0.164586 Meanlog10=nan Acc_D1=0.206424 Acc_D2=0.389613 Acc_D3=0.521075:   0%|          | 0/293 [09:18<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11585214734077454 Epoch=0 Batch_id=226  MAE=nanRMSE=0.165030 Meanlog10=nan Acc_D1=0.207286 Acc_D2=0.391376 Acc_D3=0.523513:   0%|          | 0/293 [09:20<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.17058800160884857 Epoch=0 Batch_id=227  MAE=nanRMSE=0.165455 Meanlog10=nan Acc_D1=0.208500 Acc_D2=0.393548 Acc_D3=0.526283:   0%|          | 0/293 [09:23<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15774445235729218 Epoch=0 Batch_id=228  MAE=nanRMSE=0.165745 Meanlog10=nan Acc_D1=0.209958 Acc_D2=0.396009 Acc_D3=0.529290:   0%|          | 0/293 [09:26<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.16179360449314117 Epoch=0 Batch_id=229  MAE=nanRMSE=0.166057 Meanlog10=nan Acc_D1=0.211361 Acc_D2=0.398389 Acc_D3=0.532237:   0%|          | 0/293 [09:28<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12973475456237793 Epoch=0 Batch_id=230  MAE=nanRMSE=0.166390 Meanlog10=nan Acc_D1=0.212362 Acc_D2=0.400622 Acc_D3=0.535233:   0%|          | 0/293 [09:31<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14740562438964844 Epoch=0 Batch_id=231  MAE=nanRMSE=0.166774 Meanlog10=nan Acc_D1=0.213298 Acc_D2=0.402572 Acc_D3=0.538225:   0%|          | 0/293 [09:33<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13495087623596191 Epoch=0 Batch_id=232  MAE=nanRMSE=0.167189 Meanlog10=nan Acc_D1=0.214211 Acc_D2=0.404486 Acc_D3=0.541085:   0%|          | 0/293 [09:36<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13552814722061157 Epoch=0 Batch_id=233  MAE=nanRMSE=0.167534 Meanlog10=nan Acc_D1=0.215143 Acc_D2=0.406637 Acc_D3=0.544212:   0%|          | 0/293 [09:38<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13492700457572937 Epoch=0 Batch_id=234  MAE=nanRMSE=0.168463 Meanlog10=nan Acc_D1=0.215724 Acc_D2=0.407791 Acc_D3=0.546140:   0%|          | 0/293 [09:41<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14143598079681396 Epoch=0 Batch_id=235  MAE=nanRMSE=0.169382 Meanlog10=nan Acc_D1=0.216126 Acc_D2=0.408796 Acc_D3=0.548491:   0%|          | 0/293 [09:44<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12917549908161163 Epoch=0 Batch_id=236  MAE=nanRMSE=0.170027 Meanlog10=nan Acc_D1=0.216820 Acc_D2=0.410347 Acc_D3=0.551695:   0%|          | 0/293 [09:46<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12884657084941864 Epoch=0 Batch_id=237  MAE=nanRMSE=0.170895 Meanlog10=nan Acc_D1=0.217325 Acc_D2=0.411514 Acc_D3=0.554128:   0%|          | 0/293 [09:48<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1265566498041153 Epoch=0 Batch_id=238  MAE=nanRMSE=0.171441 Meanlog10=nan Acc_D1=0.217872 Acc_D2=0.413200 Acc_D3=0.557149:   0%|          | 0/293 [09:51<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13132013380527496 Epoch=0 Batch_id=239  MAE=nanRMSE=0.171800 Meanlog10=nan Acc_D1=0.218758 Acc_D2=0.415553 Acc_D3=0.560378:   0%|          | 0/293 [09:53<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12258268147706985 Epoch=0 Batch_id=240  MAE=nanRMSE=0.172109 Meanlog10=nan Acc_D1=0.219706 Acc_D2=0.418090 Acc_D3=0.563655:   0%|          | 0/293 [09:56<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12367122620344162 Epoch=0 Batch_id=241  MAE=nanRMSE=0.172402 Meanlog10=nan Acc_D1=0.220665 Acc_D2=0.420663 Acc_D3=0.566931:   0%|          | 0/293 [09:58<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12627871334552765 Epoch=0 Batch_id=242  MAE=nanRMSE=0.172752 Meanlog10=nan Acc_D1=0.221458 Acc_D2=0.422291 Acc_D3=0.569248:   0%|          | 0/293 [10:01<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1381741166114807 Epoch=0 Batch_id=243  MAE=nanRMSE=0.173048 Meanlog10=nan Acc_D1=0.222174 Acc_D2=0.423730 Acc_D3=0.571525:   0%|          | 0/293 [10:04<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12291453778743744 Epoch=0 Batch_id=244  MAE=nanRMSE=0.173422 Meanlog10=nan Acc_D1=0.222746 Acc_D2=0.424974 Acc_D3=0.573559:   0%|          | 0/293 [10:06<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12003723531961441 Epoch=0 Batch_id=245  MAE=nanRMSE=0.173817 Meanlog10=nan Acc_D1=0.223270 Acc_D2=0.426140 Acc_D3=0.575564:   0%|          | 0/293 [10:09<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13747359812259674 Epoch=0 Batch_id=246  MAE=nanRMSE=0.174127 Meanlog10=nan Acc_D1=0.223791 Acc_D2=0.427404 Acc_D3=0.577607:   0%|          | 0/293 [10:11<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12972824275493622 Epoch=0 Batch_id=247  MAE=nanRMSE=0.174312 Meanlog10=nan Acc_D1=0.224320 Acc_D2=0.428776 Acc_D3=0.580110:   0%|          | 0/293 [10:14<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11553807556629181 Epoch=0 Batch_id=248  MAE=nanRMSE=0.174505 Meanlog10=nan Acc_D1=0.224791 Acc_D2=0.429984 Acc_D3=0.582607:   0%|          | 0/293 [10:17<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11493505537509918 Epoch=0 Batch_id=249  MAE=nanRMSE=0.174676 Meanlog10=nan Acc_D1=0.225387 Acc_D2=0.431378 Acc_D3=0.585143:   0%|          | 0/293 [10:19<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14661695063114166 Epoch=0 Batch_id=250  MAE=nanRMSE=0.174990 Meanlog10=nan Acc_D1=0.226377 Acc_D2=0.433286 Acc_D3=0.587699:   0%|          | 0/293 [10:21<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14736777544021606 Epoch=0 Batch_id=251  MAE=nanRMSE=0.175324 Meanlog10=nan Acc_D1=0.227270 Acc_D2=0.435061 Acc_D3=0.590185:   0%|          | 0/293 [10:24<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14184452593326569 Epoch=0 Batch_id=252  MAE=nanRMSE=0.175712 Meanlog10=nan Acc_D1=0.228086 Acc_D2=0.436777 Acc_D3=0.592579:   0%|          | 0/293 [10:26<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14402171969413757 Epoch=0 Batch_id=253  MAE=nanRMSE=0.176015 Meanlog10=nan Acc_D1=0.229049 Acc_D2=0.438722 Acc_D3=0.595171:   0%|          | 0/293 [10:29<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1399000883102417 Epoch=0 Batch_id=254  MAE=nanRMSE=0.176157 Meanlog10=nan Acc_D1=0.230827 Acc_D2=0.441345 Acc_D3=0.598157:   0%|          | 0/293 [10:31<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13394370675086975 Epoch=0 Batch_id=255  MAE=nanRMSE=0.176275 Meanlog10=nan Acc_D1=0.232736 Acc_D2=0.444051 Acc_D3=0.601195:   0%|          | 0/293 [10:34<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1281813234090805 Epoch=0 Batch_id=256  MAE=nanRMSE=0.176457 Meanlog10=nan Acc_D1=0.234214 Acc_D2=0.446501 Acc_D3=0.604129:   0%|          | 0/293 [10:36<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12810762226581573 Epoch=0 Batch_id=257  MAE=nanRMSE=0.176704 Meanlog10=nan Acc_D1=0.235577 Acc_D2=0.448716 Acc_D3=0.606814:   0%|          | 0/293 [10:39<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13160155713558197 Epoch=0 Batch_id=258  MAE=nanRMSE=0.177040 Meanlog10=nan Acc_D1=0.235998 Acc_D2=0.449971 Acc_D3=0.608815:   0%|          | 0/293 [10:42<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13042880594730377 Epoch=0 Batch_id=259  MAE=nanRMSE=0.177351 Meanlog10=nan Acc_D1=0.236409 Acc_D2=0.451273 Acc_D3=0.611159:   0%|          | 0/293 [10:44<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12745152413845062 Epoch=0 Batch_id=260  MAE=nanRMSE=0.177685 Meanlog10=nan Acc_D1=0.236773 Acc_D2=0.452521 Acc_D3=0.613308:   0%|          | 0/293 [10:47<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12834453582763672 Epoch=0 Batch_id=261  MAE=nanRMSE=0.177883 Meanlog10=nan Acc_D1=0.237740 Acc_D2=0.454403 Acc_D3=0.615828:   0%|          | 0/293 [10:49<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13979776203632355 Epoch=0 Batch_id=262  MAE=nanRMSE=0.177939 Meanlog10=nan Acc_D1=0.240344 Acc_D2=0.457583 Acc_D3=0.619127:   0%|          | 0/293 [10:52<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13221266865730286 Epoch=0 Batch_id=263  MAE=nanRMSE=0.177988 Meanlog10=nan Acc_D1=0.242911 Acc_D2=0.460819 Acc_D3=0.622444:   0%|          | 0/293 [10:54<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13114652037620544 Epoch=0 Batch_id=264  MAE=nanRMSE=0.178035 Meanlog10=nan Acc_D1=0.245524 Acc_D2=0.464047 Acc_D3=0.625759:   0%|          | 0/293 [10:57<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1278318613767624 Epoch=0 Batch_id=265  MAE=nanRMSE=0.178206 Meanlog10=nan Acc_D1=0.247156 Acc_D2=0.466622 Acc_D3=0.628636:   0%|          | 0/293 [10:59<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11362888664007187 Epoch=0 Batch_id=266  MAE=nanRMSE=0.178431 Meanlog10=nan Acc_D1=0.248503 Acc_D2=0.468773 Acc_D3=0.631031:   0%|          | 0/293 [11:02<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.10143214464187622 Epoch=0 Batch_id=267  MAE=nanRMSE=0.178631 Meanlog10=nan Acc_D1=0.249804 Acc_D2=0.470781 Acc_D3=0.633517:   0%|          | 0/293 [11:04<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.10655765980482101 Epoch=0 Batch_id=268  MAE=nanRMSE=0.178822 Meanlog10=nan Acc_D1=0.251173 Acc_D2=0.472899 Acc_D3=0.635956:   0%|          | 0/293 [11:07<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1170729398727417 Epoch=0 Batch_id=269  MAE=nanRMSE=0.178983 Meanlog10=nan Acc_D1=0.252700 Acc_D2=0.475217 Acc_D3=0.638685:   0%|          | 0/293 [11:10<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1441589593887329 Epoch=0 Batch_id=270  MAE=nanRMSE=0.179130 Meanlog10=nan Acc_D1=0.254664 Acc_D2=0.478147 Acc_D3=0.641907:   0%|          | 0/293 [11:12<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13538460433483124 Epoch=0 Batch_id=271  MAE=nanRMSE=0.179205 Meanlog10=nan Acc_D1=0.257116 Acc_D2=0.481327 Acc_D3=0.645208:   0%|          | 0/293 [11:15<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13801416754722595 Epoch=0 Batch_id=272  MAE=nanRMSE=0.179285 Meanlog10=nan Acc_D1=0.259581 Acc_D2=0.484483 Acc_D3=0.648512:   0%|          | 0/293 [11:18<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.15211515128612518 Epoch=0 Batch_id=273  MAE=nanRMSE=0.179492 Meanlog10=nan Acc_D1=0.261096 Acc_D2=0.486600 Acc_D3=0.651197:   0%|          | 0/293 [11:20<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.16923359036445618 Epoch=0 Batch_id=274  MAE=nanRMSE=0.179591 Meanlog10=nan Acc_D1=0.262338 Acc_D2=0.488992 Acc_D3=0.653878:   0%|          | 0/293 [11:23<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.16118407249450684 Epoch=0 Batch_id=275  MAE=nanRMSE=0.179901 Meanlog10=nan Acc_D1=0.262920 Acc_D2=0.490355 Acc_D3=0.656096:   0%|          | 0/293 [11:25<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.16403746604919434 Epoch=0 Batch_id=276  MAE=nanRMSE=0.180020 Meanlog10=nan Acc_D1=0.264035 Acc_D2=0.492590 Acc_D3=0.658692:   0%|          | 0/293 [11:28<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13642576336860657 Epoch=0 Batch_id=277  MAE=nanRMSE=0.180283 Meanlog10=nan Acc_D1=0.264942 Acc_D2=0.494652 Acc_D3=0.661573:   0%|          | 0/293 [11:30<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1381721943616867 Epoch=0 Batch_id=278  MAE=nanRMSE=0.180723 Meanlog10=nan Acc_D1=0.265856 Acc_D2=0.496246 Acc_D3=0.664107:   0%|          | 0/293 [11:33<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12434051930904388 Epoch=0 Batch_id=279  MAE=nanRMSE=0.181082 Meanlog10=nan Acc_D1=0.266876 Acc_D2=0.498057 Acc_D3=0.667023:   0%|          | 0/293 [11:35<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12418684363365173 Epoch=0 Batch_id=280  MAE=nanRMSE=0.181451 Meanlog10=nan Acc_D1=0.267926 Acc_D2=0.499927 Acc_D3=0.669800:   0%|          | 0/293 [11:38<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.11086657643318176 Epoch=0 Batch_id=281  MAE=nanRMSE=0.181665 Meanlog10=nan Acc_D1=0.268962 Acc_D2=0.502055 Acc_D3=0.672534:   0%|          | 0/293 [11:41<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.1057610958814621 Epoch=0 Batch_id=282  MAE=nanRMSE=0.181864 Meanlog10=nan Acc_D1=0.270151 Acc_D2=0.504110 Acc_D3=0.675008:   0%|          | 0/293 [11:43<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.09536518901586533 Epoch=0 Batch_id=283  MAE=nanRMSE=0.182001 Meanlog10=nan Acc_D1=0.271626 Acc_D2=0.506314 Acc_D3=0.677527:   0%|          | 0/293 [11:45<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.09684610366821289 Epoch=0 Batch_id=284  MAE=nanRMSE=0.182146 Meanlog10=nan Acc_D1=0.273075 Acc_D2=0.508491 Acc_D3=0.680031:   0%|          | 0/293 [11:48<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12872329354286194 Epoch=0 Batch_id=285  MAE=nanRMSE=0.182558 Meanlog10=nan Acc_D1=0.273471 Acc_D2=0.509154 Acc_D3=0.681092:   0%|          | 0/293 [11:50<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.13493002951145172 Epoch=0 Batch_id=286  MAE=nanRMSE=0.182850 Meanlog10=nan Acc_D1=0.273659 Acc_D2=0.509619 Acc_D3=0.682151:   0%|          | 0/293 [11:53<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12248876690864563 Epoch=0 Batch_id=287  MAE=nanRMSE=0.183065 Meanlog10=nan Acc_D1=0.273903 Acc_D2=0.510292 Acc_D3=0.683470:   0%|          | 0/293 [11:55<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.12040168046951294 Epoch=0 Batch_id=288  MAE=nanRMSE=0.183281 Meanlog10=nan Acc_D1=0.274135 Acc_D2=0.510938 Acc_D3=0.684728:   0%|          | 0/293 [11:57<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:100: RuntimeWarning: invalid value encountered in log10
#
#
#
#
#
#
#
#
#
# Loss=0.14789369702339172 Epoch=0 Batch_id=289  MAE=nanRMSE=0.183640 Meanlog10=nan Acc_D1=0.275567 Acc_D2=0.513143 Acc_D3=0.687347:   0%|          | 0/293 [11:59<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14942553639411926 Epoch=0 Batch_id=290  MAE=nanRMSE=0.183640 Meanlog10=nan Acc_D1=0.275567 Acc_D2=0.513143 Acc_D3=0.687347:   0%|          | 0/293 [12:01<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14361883699893951 Epoch=0 Batch_id=291  MAE=nanRMSE=0.183640 Meanlog10=nan Acc_D1=0.275567 Acc_D2=0.513143 Acc_D3=0.687347:   0%|          | 0/293 [12:02<?, ?it/s]
#
#
#
#
#
#
#
#
# Loss=0.14346528053283691 Epoch=0 Batch_id=292  MAE=nanRMSE=0.183640 Meanlog10=nan Acc_D1=0.275567 Acc_D2=0.513143 Acc_D3=0.687347:   0%|          | 0/293 [12:03<?, ?it/s]

# %%
# !cp "/content/densedepth_dnn_mse.pth"

# %% [markdown]
# #Test the Modal

# %%
modal.eval()
test_loss = 0
correct = 0
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow
#import cv2_utils
from torchvision import transforms
"""
input_array = []
bg = "/content/gdrive/My Drive/eva-04/S15A/Dataset_224/bg/bg1.jpg"
overlay = "/content/gdrive/My Drive/eva-04/S15A/Dataset_224/bg1/fg_1/overlay/14.jpg"
depth = "/content/gdrive/My Drive/eva-04/S15A/Dataset_224/bg1/fg_1/depth/14.jpg"
mask = "/content/gdrive/My Drive/eva-04/S15A/Dataset_224/bg1/fg_1/mask/14.jpg"

bg_image = Image.open(bg).convert('RGB') # even grey scale images will be converted to RGB with 3 channels
bg_image = bg_image.resize((64,64)) 
overlay_image = Image.open(overlay).convert('RGB') # even grey scale images will be converted to RGB with 3 channels
overlay_image = overlay_image.resize((64,64))
depth_image = Image.open(depth) # even grey scale images will be converted to RGB with 3 channels
depth_image = depth_image.resize((64,64))
mask_image = Image.open(mask)
mask_image = mask_image.resize((64,64))

tr = transforms.ToTensor()
bg_image = tr(bg_image)
overlay_image = tr(overlay_image)
mask_image = tr(mask_image)
depth_image = tr(depth_image)

input_array.append(bg_image)
input_array.append(overlay_image)
input_array.append(depth_image)
input_array.append(mask_image)
"""
count = 0
#w = torch.load("/content/unet_mse.pth")
#print(modal.layer_name.weight)
#modal.load_state_dict(w)
import time      
im_array = []
bg_array = []
fgbg_array = []
depth_array = []
mask_array =[] 
with torch.no_grad(): 
  #preds = np.zeros((1,1,2350,64), dtype=np.float32)
  #labels = np.zeros((1,1,2350,64),dtype=np.float32)
    
  for input_array1 in val_loader:
      count = count + 1
      #print(input_array1[0])
      bg = input_array1[0].to(device)
      fgbg = input_array1[1].to(device)
      depth_img = input_array1[2].to(device)
      mask_img = input_array1[3].to(device)

      #print('file=',input_array1[4])
      #load modal stats
      #for p in modal.parameters():
      #  print(p.data)  
      
      #print(modal.layer_name.weight)
      #fgbg = fgbg.add(bg)
      concat = torch.cat([bg,fgbg],dim=1)
      output = modal(concat)
      
      bg = bg.cpu()
      fgbg = fgbg.cpu()
      
      img = output[0].cpu()
      img = F.interpolate(img, size=(64, 64),mode='bilinear',align_corners=False)
      mask = output[1].cpu()
      mask = F.interpolate(mask, size=(64, 64),mode='bilinear',align_corners=False)
      depth_array.append(img)
      mask_array.append(mask)
      bg = F.interpolate(bg, size=(64, 64),mode='bilinear',align_corners=False)
      fgbg = F.interpolate(fgbg, size=(64, 64),mode='bilinear',align_corners=False)
      bg_array.append(bg)
      fgbg_array.append(fgbg)

      #pred = pred.cpu().numpy()
      label = depth_img.cpu()
      depth_img = depth_img.cpu() 
      
      
    
      # center crop to output size
      #label = label[7:label.shape[0]-7, 29:label.shape[1]-29]
      # store the label and the corresponding prediction
      #labels[:, :, idx] = label
      #preds[:, :, idx] = pred[0, 0, :, :]
      # load label
      #label = np.load(label_path)
      # calculating errors
      """
      rel_error = np.mean(np.abs(preds - labels)/labels)
      print('\nMean Absolute Relative Error: {:.6f}'.format(rel_error))

      rmse = np.sqrt(np.mean((preds - labels)**2))
      print('Root Mean Squared Error: {:.6f}'.format(rmse))

      log10 = np.mean(np.abs(np.log10(preds) - np.log10(labels)))
      print('Mean Log10 Error: {:.6f}'.format(log10))

      acc = np.maximum(preds/labels, labels/preds)
      delta1 = np.mean(acc < 1.25)
      print('Delta1: {:.6f}'.format(delta1))

      delta2 = np.mean(acc < 1.25**2)
      print('Delta2: {:.6f}'.format(delta2))

      delta3 = np.mean(acc < 1.25**3)
      print('Delta3: {:.6f}'.format(delta3))
      """
      #cv2_imshow(pred)
      #cv2_imshow(pred)
  
    #fgbg = fgbg.cpu()
      #print(out_numpy)
      #cv2_imshow(out_numpy)
      #img=img.resize((224,224))
      """
      if count == 10:
        trans = transforms.ToPILImage(mode=None)
        print(img.squeeze())
        print(label.squeeze())
        print("img:sum",torch.sum(img.squeeze()))
        print("pred:sum",torch.sum(label.squeeze()))
        #diff =   label.squeeze()-img.squeeze()
        #print("diff:",diff)
        #plt.imshow(trans(diff).convert('LA'))

        plt.imshow(trans(img.squeeze()).convert('LA'))
        #plt.imshow(trans(mask.squeeze()).convert('LA'))
        break
      """
      if count == 10:
        break
      #cv2.imwrite("/content/prediction/img1.jpg",img)
      
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
import numpy as np

#im1 = np.arange(100).reshape((10, 10))
#im2 = im1.T
#im3 = np.flipud(im1)
#im4 = np.fliplr(im2)
trans = transforms.ToPILImage(mode=None)
        
for im in bg_array:
  im_array.append(trans(im.squeeze()))

for im in fgbg_array:
  im_array.append(trans(im.squeeze()))

for im in depth_array:
  im_array.append(trans(im.squeeze()).convert('LA'))

for im in mask_array:
  im_array.append(trans(im.squeeze()).convert('LA'))

fig = plt.figure(figsize=(64,64))
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(4, 10),  # creates 2x2 grid of axes
                 axes_pad=0.1,  # pad between axes in inch.
                 )

for ax, im in zip(grid, im_array):
    # Iterating over the grid returns the Axes.
    ax.imshow(im)

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2973: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1569: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

class DenseDepthDNN(torch.nn.Module):
    def __init__(self, dropout_value = 0.1):
        """"Constructor of the class"""
        super(DenseDepthDNN, self).__init__()
        # Input Block
        self.dropout_value = dropout_value
        #Depthwise separate 3 input channels into 3 output channels
        #it's first block uses following code:
        #x1 = Input
        #x2 = Conv(x1)
        #x3 = Conv(x1 + x2)
        #x4 = MaxPooling(x1 + x2 + x3)
        #x5 = Conv(x4)
        #x6 = Conv(x4 + x5)
        #x7 = Conv(x4 + x5 + x6)
        #x8 = MaxPooling(x5 + x6 + x7)
        #x9 = Conv(x8)
        #x10 = Conv (x8 + x9)
        #x11 = Conv (x8 + x9 + x10)
        #x12 = GAP(x11)
        #x13 = FC(x12)
        #Uses ReLU and BN wherever applicable
        #Uses CIFAR10 as the dataset
        #Your target is 75% in less than 40 Epochs
        #self.conv1 = nn.Conv2d(3, 6, 5)  # RF= 
        #self.pool = nn.MaxPool2d(2, 2)
        #self.conv2 = nn.Conv2d(6, 16, 5)
        #self.fc1 = nn.Linear(16 * 5 * 5, 120)
        #self.fc2 = nn.Linear(120, 84)
        #self.fc3 = nn.Linear(84, 10)
        #torch.nn.Conv2d(in_channels, out_channels=k*in_channels, kernel_size, stride=1, padding=0, dilation=1, groups=1, bias=True, padding_mode='zeros')
        
        #self.conv1 = nn.Conv2d(in_channels = 3, out_channels = 32, kernel_size = 3, stride = 1, padding = 1)
        #self.conv2 = nn.Conv2d(in_channels = 32, out_channels = 32, kernel_size = 3, stride = 1, padding = 1)
        #self.conv3 = nn.Conv2d(in_channels = 64, out_channels = 32, kernel_size = 3, stride = 1, padding = 1)
        #self.conv4 = nn.Conv2d(in_channels = 96, out_channels = 32, kernel_size = 3, stride = 1, padding = 1)
        #self.conv5 = nn.Conv2d(in_channels = 128, out_channels = 32, kernel_size = 3, stride = 1, padding = 1)
        #x1 = Input 
        #x2 = Conv(x1)
        #x3 = Conv(x1 + x2)
        #x4 = MaxPooling(x1 + x2 + x3)
        #x5 = Conv(x4)
        #x6 = Conv(x4 + x5)
        #x7 = Conv(x4 + x5 + x6)
        #x8 = MaxPooling(x5 + x6 + x7)
        #x9 = Conv(x8)
        #x10 = Conv (x8 + x9)
        #x11 = Conv (x8 + x9 + x10)
        
        #x1 = Input 3 channels
        #x2 = Conv(x1)
        self.x2 = nn.Sequential( #input 32*32*64, output=32*32*64, RF=4
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64)
            #nn.Dropout(dropout_value)
        )
        #x3 = Conv(x1 + x2) , no x1
        self.x3 = nn.Sequential(  #input 32*32*64, output=32*32*64, RF=6
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64)
            #nn.Dropout(dropout_value)
        )
        #x4 maxpool (x1+x2+x3) no x1
        self.x4 = nn.MaxPool2d(2, 2) #input 32*32*128, output=16*16*128, RF=7
        
        #x5 = Conv(x4)
        self.x5 = nn.Sequential( #input 16*16*128, output=16*16*128, RF=14
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128)
            #nn.Dropout(dropout_value)
        )
        
        #x6 = Conv(x4 + x5)
        self.x6 = nn.Sequential( #input 16*16*256, output=16*16*128, RF=16
            nn.Conv2d(in_channels=256, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128)
            #nn.Dropout(dropout_value)
        )

        #x7 = Conv(x4 + x5 + x6)
        self.x7 = nn.Sequential( #input 16*16*64, output=16*16*64, RF=18
            nn.Conv2d(in_channels=384, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128)
            #nn.Dropout(dropout_value)
        )
        #x8 = MaxPooling(x5 + x6 + x7)
        self.x8 = nn.MaxPool2d(2, 2) #input 16*16*384, output_size = (8*8*384), RF=19
        
        #x9 = Conv(x8)
        self.x9 = nn.Sequential( #input 8*8*384, output_size = (8*8*128), RF=38
            nn.Conv2d(in_channels=384, out_channels=256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(256)
            #nn.Dropout(dropout_value)
        )
        #x10 = Conv (x8 + x9)
        self.x10 = nn.Sequential( #input 8*8*128, output_size = (8*8*64), RF=40
            nn.Conv2d(in_channels=640, out_channels=256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(256)
            #nn.Dropout(dropout_value)
        )
        #x11 = Conv (x8 + x9 + x10)
        self.x11 = nn.Sequential( #input 8*8*64, output_size = (8*8*64), RF=42
            nn.Conv2d(in_channels=896, out_channels=256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(256)
            #nn.Dropout(dropout_value)
        )
        
        """
        # OUTPUT BLOCK -> Add GAP Layer
        self.x12_gap = nn.Sequential( # input 8*8*64, output_size = (1*1*64), Receptive FieldF=42
            nn.AvgPool2d(kernel_size=8)
        )

        self.x13_fc = nn.Sequential(
            nn.Linear(in_features=64, out_features=10)
            # nn.BatchNorm2d(10),
            # nn.ReLU(),
            # nn.Dropout(dropout_value)
        )
        """
        
        #Remove gap layer and add additional conv layers
        self.x11_conv_256 = nn.Sequential( #input 8*8*64, output_size = (8*8*64), RF=42
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3,padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            #nn.Dropout(dropout_value)
        )
        self.x11_conv_512 = nn.Sequential( #input 8*8*64, output_size = (8*8*64), RF=42
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            #nn.Dropout(dropout_value)
        )
        self.x11_inconv_256 = nn.Sequential( #input 8*8*64, output_size = (8*8*64), RF=42
            nn.Conv2d(in_channels=512, out_channels=256, kernel_size=3,padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            #nn.Dropout(dropout_value)
        )
        
        self.x11_inconv_128 = nn.Sequential( #input 8*8*64, output_size = (8*8*64), RF=42
            nn.Conv2d(in_channels=256, out_channels=128, kernel_size=3,padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            #nn.Dropout(dropout_value)
        )
        
        self.x11_inconv_64 = nn.Sequential( #input 8*8*64, output_size = (8*8*64), RF=42
            nn.Conv2d(in_channels=128, out_channels=64, kernel_size=3,padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            #nn.Dropout(dropout_value)
        )

        self.x11_inconv_32 = nn.Sequential( #input 8*8*64, output_size = (8*8*64), RF=42
            nn.Conv2d(in_channels=64, out_channels=32, kernel_size=3,padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            #nn.Dropout(dropout_value)
        )

        self.x11_inconv_16 = nn.Sequential( #input 8*8*64, output_size = (8*8*64), RF=42
            nn.Conv2d(in_channels=32, out_channels=16, kernel_size=3,padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            #nn.Dropout(dropout_value)
        )

        self.x12_conv_1_1 = nn.Sequential( #input 8*8*64, output_size = (8*8*64), RF=42
            nn.Conv2d(in_channels=16, out_channels=3, kernel_size=1)
            #nn.Dropout(dropout_value)
        )
        self.x13_final = nn.Sequential( #input 8*8*64, output_size = (8*8*64), RF=42
            nn.Conv2d(in_channels=3, out_channels=1, kernel_size=3, padding=1)
        )

        self.dropout = nn.Dropout(self.dropout_value)

    
    def forward(self, x1):
        #x1 = Input 
        #x2 = Conv(x1)
        #x3 = Conv(x1 + x2)
        #x4 = MaxPooling(x1 + x2 + x3)
        #x5 = Conv(x4)
        #x6 = Conv(x4 + x5)
        #x7 = Conv(x4 + x5 + x6)
        #x8 = MaxPooling(x5 + x6 + x7)
        #x9 = Conv(x8)
        #x10 = Conv (x8 + x9)
        #x11 = Conv (x8 + x9 + x10)
        
        x2 = self.x2(x1) #                          
        #print('x2=',len(x2))
        #x1_x2 = torch.cat((x1, x2))
        #x1_x2 = torch.add((x1, x2))
        x3 = self.x3(x2)                            #RF2
        x1_x2_x3 = torch.cat((x2, x3),dim=1) 
        #x1_x2_x3 = x2.add(x3)                       #concatnation
        x4 = self.x4(x1_x2_x3)                      #RF3
        x5 = self.x5(x4)                            #RF6
        #print('x5=',len(x5))
        x4_x5 = torch.cat((x4, x5),dim=1)
        #x4_x5 = x4.add(x5)
        x6 = self.x6(x4_x5)  #RF8
        #interpolate
        x4=torch.nn.functional.interpolate(x4, size=(64,64))                         
        x5=torch.nn.functional.interpolate(x5, size=(64,64))                        
        x6=torch.nn.functional.interpolate(x6, size=(64,64))                        
        #print('x6=',len(x6))
        x5_x6 = torch.cat((x5, x6),dim=1)
        #x5_x6 = x5.add(x6)
        x4_x5_x6 = torch.cat((x4, x5_x6),dim=1)
        #x4_x5_x6 = x4.add(x5_x6)
        x7 = self.x7(x4_x5_x6) #RF10
        x5_x6_x7 = torch.cat((x5_x6, x7),dim=1)
        #x5_x6_x7 = x5_x6.add(x7)
        x8 = self.x8(x5_x6_x7) #RF11
        x9 = self.x9(x8) #RF22
        #interpolate 
        x8=torch.nn.functional.interpolate(x8, size=(64,64))                        
        x9=torch.nn.functional.interpolate(x9, size=(64,64))                        
        #print('x9=',len(x9))
        x8_x9 = torch.cat((x8, x9),dim=1)
        #x8_x9 = x8.add(x9)
        x10 = self.x10(x8_x9) #RF24
        
        #print('x10=',len(x10))
        x8_x9_x10 = torch.cat((x8_x9, x10),dim=1)
        #x8_x9_x10 = x8_x9.add(x10)
        x11 = self.x11(x8_x9_x10) #RF26
        #print('x11=',len(x11))
        #----->x12 = self.x12_gap(x11)
        #increase the channels
        x11_conv_256 = self.x11_conv_256(x11) #RF28
        x11_conv_512 = self.x11_conv_512(x11_conv_256) #RF30
        x11_inconv_256 = self.x11_inconv_256(x11_conv_512) #RF32
        x11_inconv_128 = self.x11_inconv_128(x11_inconv_256) #RF34
        x11_inconv_64 = self.x11_inconv_64(x11_inconv_128) #RF36
        x11_inconv_32 = self.x11_inconv_32(x11_inconv_64) #RF38
        x11_inconv_16 = self.x11_inconv_16(x11_inconv_32) #RF40

        #{{}}

        x12_conv_1_1 = self.x12_conv_1_1(x11_inconv_16)
        #print('x12=',len(x12))
        #----->x12 = x12.view(-1, 64)
        #---->x13 = self.x13_fc(x12)

        #print('x13=',len(x13))
        #x13 = x13.view(-1, 10)
        #print('x13=',len(x13))
        #---->x14 = x13.view(-1, 10)
        #-->return F.log_softmax(x13, dim=-1)
        x13_final = self.x13_final(x12_conv_1_1) #RF36
        return x13_final
